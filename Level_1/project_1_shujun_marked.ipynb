# %% [markdown]
# <div style="border: 1px solid thistle; padding: 5px 20px 10px 20px;">
#     <h2><font color = "77658f" style=";">Feedback</font></h2><br>
#     <font color = "77658f">Generally very thorough and comprehensive. Very good presentation of technical report, except for the presentation of the top states for participation rates/scores. Good visuals too!<br><br>
#         • Project Organisation: <b>Meet Portfolio Expectations</b> <br>
#         • Python Syntax and Control Flow: <b>Meet Requirement</b><br>
#         • Data Cleaning and EDA: <b>Meet Requirement</b><br>
#         • Visualisations: <b>Meet Requirement</b><br>
#         • Research and Conceptual Understanding: <b>Meet Portfolio Expectations</b><br>
#     </font>
# </div>

# %% [markdown]
# # Analysis of College Admission (SAT & ACT) Standardised Test Data

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# To conduct data analysis and statistical inference to generate recommendations for the College Board to improve overall SAT participation rates, by targeting states with low participation rates in 2017-2018.

# %% [markdown]
# ## Executive Summary
#
# ### Contents:
# - [2017 Data Import & Cleaning](#2017-Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %%
# Import libraries
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
sat2017 = pd.read_csv('../data/sat_2017.csv')
act2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
sat2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
sat2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
act2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# The sat2017 data consists of participation rates, evidence-based reading and writing (ERW) scores, math scores and total scores for each state. There are 51 counts of data in total. The mean ERW score is 569.12, with a standard deviation of 45.67. The mean math score is 547.63, with a standard deviation of 84.91.
#
# The act2017 data consists of participation rates, english, math, reading, science and composite scores for each state. There are 52 counts of data in total (51 states + national average). The composite score is the average of the scores on each test for english, math, reading and science.The describe() function is inaccurate because it includes the data for the first row 'National'.

# %% [markdown]
# > <font size = 3 color = red> Good and clear description! You could also include information such as size of dataframe, number of rows, shape of dataframe etc.</font>

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Based on online research, there should be an essay component (optional) in both the SAT and ACT, but the scores for this component were not provided in the dataset.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# For SAT subtest, min score = 400, max score = 1600. Total score is computed by the sum of the subtest scores.
#
# For ACT, min score = 1, max score = 36. Composite score is computed by the average of the subtest scores.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# Discrepancies were identified (Maryland and Wyoming) by comparing the datasets provided with online sources. 
# This was done using an excel match function.
act2017.loc[51,'Composite'] = 20.2
act2017.loc[21,'Science'] = 23.2
sat2017.loc[20,'Math'] = 524

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# For both SAT and ACT, the 'Participation' column data type should be *int* instead of *object*. For ACT, the 'Composite' values should be *float*.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# Function to convert string objects from 'Participation' column to integer values (consistent with 2018 dataset). 
# Need to remove % before conversion.
def convertStrToInt(x):
    if type(x)==str:
        return int(x.replace('%',''))    

# Function to convert string objects to float.
def convertStrToFloat(x):
    return float(x)

# %% [markdown]
# > <font size = 3 color = red> Float function abit redundant in general cases, but you have to create one to use the map/apply function. </font>

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
sat2017['Participation'] = sat2017['Participation'].apply(convertStrToInt)
act2017['Participation'] = act2017['Participation'].apply(convertStrToInt)
act2017['Composite'] = act2017['Composite'].apply(convertStrToFloat)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
print(sat2017.dtypes)
sat2017.head()
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama              5                                 593   572   1165
# 1      Alaska             38                                 547   533   1080
# 2     Arizona             30                                 563   553   1116
# 3    Arkansas              3                                 614   594   1208
# 4  California             53                                 531   524   1055

# %%
print(act2017.dtypes)
act2017.head()
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National             60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama            100     18.9  18.4     19.7     19.4       19.2
# 2    Alaska             65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona             62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas            100     18.9  19.0     19.7     19.5       19.4

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
# Function to rename column names in unique format: testType_colName_year
# Check that colName is str type, and that the column name has not been already renamed previously.
def renameCols(colName,testType,year):
    if type(colName) == str and colName[:3] != testType and colName[:-4] != year:
        colName = (testType + ' ' + colName.lower() + ' ' + year).replace(' ','_')
    return colName

# %%
sat2017.columns = [renameCols(i,'sat','2017') for i in sat2017.columns]
act2017.columns = [renameCols(i,'act','2017') for i in act2017.columns]

# %% [markdown]
# #### 8. Create a data dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |sat_state_2017|*object*|SAT|SAT State|
# |sat_participation_2017|*int*|SAT|SAT Participation Rate|
# |sat_evidence-based_reading_and_writing_2017|*int*|SAT|SAT Evidence-based Reading and Writing (ERW) Scores|
# |sat_math_2017|*int*|SAT|SAT Math Scores|
# |sat_total_2017|*int*|SAT|SAT Total Scores|
# |act_state_2017|*object*|ACT|ACT State|
# |act_participation_2017|*int*|ACT|ACT Participation Rate|
# |act_english_2017|*float*|ACT|ACT English Scores|
# |act_math_2017|*float*|ACT|ACT Math Scores|
# |act_reading_2017|*float*|ACT|ACT Reading Scores|
# |act_science_2017|*float*|ACT|ACT Science Scores|
# |act_composite_2017|*float*|ACT|ACT Composite Scores|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# Remove ACT row for 'National'
act2017.drop([0],inplace=True)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# Set index of both SAT and ACT dataframes to the 'State'
sat2017.set_index('sat_state_2017', inplace=True)
act2017.set_index('act_state_2017', inplace=True)

# %%
# Join() function combines both SAT and ACT dataframes by their index by default
combinedDf = sat2017.join(act2017)
combinedDf.index.names = ['state']

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
combinedDf.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# Import 2018 SAT and ACT csv datasets using relative path.
sat2018 = pd.read_csv('../data/sat_2018.csv')
act2018 = pd.read_csv('../data/act_2018_updated.csv')

# %%
# Check data types to identify errors.
sat2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act2018.dtypes
# Out:
# State                             object
# Percentage of Students Tested      int64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
# For the 2018 ACT data, the data types for 'Percentage of Students Tested' and 'Average Composite Score'
# are already int and float respectively, so we don't have do conversion for these columns.
sat2018['Participation'] = sat2018['Participation'].apply(convertStrToInt)

# Rename columns using the same function as for the 2017 data
sat2018.columns = [renameCols(i,'sat','2018') for i in sat2018.columns]
act2018.columns = [renameCols(i,'act','2018') for i in act2018.columns]

# Join the 2018 SAT and ACT dataframes
sat2018.set_index('sat_state_2018', inplace=True)
act2018.set_index('act_state_2018', inplace=True)

combinedDf2018 = sat2018.join(act2018)
combinedDf2018.head()

combinedDf2018.to_csv('../data/combinedDf2018.csv')

# %%
# Discrepancies were identified by comparing the csv dataset provided with online sources, using an excel match function.
# There were errors identified for Florida, Hawaii, Indiana, Utah, South Dakota, Delaware.

combinedDf2018.loc['Delaware','act_average_composite_score_2018'] = 23.8

combinedDf2018.loc['Florida','sat_participation_2018'] = 97
combinedDf2018.loc['Florida','sat_evidence-based_reading_and_writing_2018'] = 522
combinedDf2018.loc['Florida','sat_math_2018'] = 493
combinedDf2018.loc['Florida','sat_total_2018'] = 1014

combinedDf2018.loc['Hawaii','sat_evidence-based_reading_and_writing_2018'] = 550
combinedDf2018.loc['Hawaii','sat_math_2018'] = 549
combinedDf2018.loc['Hawaii','sat_total_2018'] = 1099

combinedDf2018.loc['Indiana','sat_participation_2018'] = 67
combinedDf2018.loc['Indiana','sat_evidence-based_reading_and_writing_2018'] = 546
combinedDf2018.loc['Indiana','sat_math_2018'] = 539
combinedDf2018.loc['Indiana','sat_total_2018'] = 1086

combinedDf2018.loc['South Dakota','sat_total_2018'] = 1241

combinedDf2018.loc['Utah','sat_evidence-based_reading_and_writing_2018'] = 618
combinedDf2018.loc['Utah','sat_math_2018'] = 612
combinedDf2018.loc['Utah','sat_total_2018'] = 1230

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# Join the 2017 and 2018 dataframes
final = combinedDf.join(combinedDf2018)
final.head()
# Out:
#             sat_participation_2017  \
# state
# Alabama                          5
# Alaska                          38
# Arizona                         30
# Arkansas                         3
# California                      53
#
#             sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Alabama                                             593            572
# Alaska                                              547            533
# Arizona                                             563            553
# Arkansas                                            614            594
# California                                          531            524
#
#             sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Alabama               1165                     100              18.9
# Alaska                1080                      65              18.7
# Arizona               1116                      62              18.6
# ...

# %%
# Save the combined dataframe to csv
final.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# Use the describe function for quick overview of each numeric feature, then transpose.
final.describe().transpose()
# Out:
#                                              count         mean        std  \
# sat_participation_2017                        51.0    39.803922  35.276632
# sat_evidence-based_reading_and_writing_2017   51.0   569.117647  45.666901
# sat_math_2017                                 51.0   556.882353  47.121395
# sat_total_2017                                51.0  1126.098039  92.494812
# act_participation_2017                        51.0    65.254902  32.140842
# act_english_2017                              51.0    20.931373   2.353677
# act_math_2017                                 51.0    21.182353   1.981989
# act_reading_2017                              51.0    22.013725   2.067271
# act_science_2017                              51.0    21.450980   1.739353
# act_composite_2017                            51.0    21.519608   2.020695
# sat_participation_2018                        51.0    46.627451  38.014187
# ...

# %% [markdown]
# > <font size = 3 color = red> Or you can just use dataframe.T instead of dataframe.transpose() </font>

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
# Calculate standard deviation of the feature 'sat_participation_2017', using the formula above.
diffSum = 0
meanSum = final['sat_participation_2017'].mean()

for i in final['sat_participation_2017']:
    diffSum = diffSum + ((i-meanSum)**2)
    
standardDev = np.sqrt(diffSum/(len(final['sat_participation_2017'])))

# Print standard deviation of the feature 'sat_participation_2017', derived from 3 different methods: pandas, numpy, formula
print('Std using df.std:', final['sat_participation_2017'].std())
print('Std using np.std:', np.std(final['sat_participation_2017']))
print('Std using manual formula calculation:', standardDev)
# Out:
# Std using df.std: 35.276632270013046
# Std using np.std: 34.92907076664508
# Std using manual formula calculation: 34.92907076664508

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# Using apply function, without for loops.
def calculateStdDev(column):
    return(column.std(ddof=0))
    
sd = final.apply(calculateStdDev,axis=0).to_dict()
print(sd)
# Out:
# {'sat_participation_2017': 34.92907076664508, 'sat_evidence-based_reading_and_writing_2017': 45.21697020437866, 'sat_math_2017': 46.65713364485503, 'sat_total_2017': 91.58351056778743, 'act_participation_2017': 31.824175751231806, 'act_english_2017': 2.3304876369363363, 'act_math_2017': 1.9624620273436781, 'act_reading_2017': 2.0469029314842646, 'act_science_2017': 1.7222161451443676, 'act_composite_2017': 2.000786081581989, 'sat_participation_2018': 37.63965409204986, 'sat_evidence-based_reading_and_writing_2018': 44.87118561762388, 'sat_math_2018': 48.40589946919447, 'sat_total_2018': 92.94372462792965, 'act_percentage_of_students_tested_2018': 33.745194881997506, 'act_average_composite_score_2018': 2.0968220768561987, 'act_average_english_score_2018': 2.4222536143202795, 'act_average_math_score_2018': 2.015707255555717, 'act_average_reading_score_2018': 2.145891884510421, 'act_average_science_score_2018': 1.8516885484833543}

# %%
# ALternative method using dict comprehension.
def stdDev(value):
    diffSum = 0
    meanSum = 0
    count = 0
    for k, v in value.items():
        meanSum = meanSum + v
        count+=1
    meanSum = meanSum/count
    for k, v in value.items():
        diffSum = diffSum + ((v-meanSum)**2)
    return np.sqrt(diffSum/count)
    
sd = final.to_dict()
sd = {k:stdDev(v) for (k,v) in sd.items()}
sd
# Out:
# {'sat_participation_2017': 34.92907076664508,
#  'sat_evidence-based_reading_and_writing_2017': 45.21697020437866,
#  'sat_math_2017': 46.65713364485503,
#  'sat_total_2017': 91.58351056778743,
#  'act_participation_2017': 31.824175751231806,
#  'act_english_2017': 2.3304876369363363,
#  'act_math_2017': 1.9624620273436781,
#  'act_reading_2017': 2.0469029314842646,
#  'act_science_2017': 1.7222161451443676,
#  'act_composite_2017': 2.000786081581989,
#  'sat_participation_2018': 37.63965409204986,
#  'sat_evidence-based_reading_and_writing_2018': 44.87118561762388,
#  'sat_math_2018': 48.40589946919447,
#  'sat_total_2018': 92.94372462792965,
#  'act_percentage_of_students_tested_2018': 33.745194881997506,
#  'act_average_composite_score_2018': 2.0968220768561987,
#  'act_average_english_score_2018': 2.4222536143202795,
#  'act_average_math_score_2018': 2.015707255555717,
#  'act_average_reading_score_2018': 2.145891884510421,
# ...

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
#
# No, the manually calculated standard deviations do not match up with the output from pandas describe() function. This is because the pandas describe() function has the default input ddof=1, where the divisor used = N-ddof (N represents the number of elements). This is different from the formula which uses divisor = N. Numpy's std method gives the same standard deviation as the formula, because the default value for ddof=0.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# **Feature Engineering**

# %%
# Create additional columns to analyse changes in the SAT participation rates and test scores from 2017 to 2018.
final['sat_participation_improvement'] = final['sat_participation_2018'] - final['sat_participation_2017']
final['sat_erw_improvement'] = (final['sat_evidence-based_reading_and_writing_2018'] - 
                                final['sat_evidence-based_reading_and_writing_2017'])
final['sat_math_improvement'] = final['sat_math_2018'] - final['sat_math_2017']
final['sat_total_improvement'] = final['sat_total_2018'] - final['sat_total_2017']

# %%
# Create additional columns to analyse changes in the ACT participation rates and test scores from 2017 to 2018.
final['act_participation_improvement'] = final['act_percentage_of_students_tested_2018'] - final['act_participation_2017']
final['act_english_improvement'] = final['act_average_english_score_2018'] - final['act_english_2017']
final['act_math_improvement'] = final['act_average_math_score_2018'] - final['act_math_2017']
final['act_reading_improvement'] = final['act_average_reading_score_2018'] - final['act_reading_2017']
final['act_science_improvement'] = final['act_average_science_score_2018'] - final['act_science_2017']
final['act_composite_improvement'] = final['act_average_composite_score_2018'] - final['act_composite_2017']

# %% [markdown]
# **SAT Participation Rates**

# %% [markdown]
# > <font size = 3 color = red> Please remove unnecessary columns. E.g. When displaying the top states for partipation rates, remove the rest of the scores</font>

# %%
# Filter dataframe to include states with more than 95% SAT Participation Rates in 2017.
# Compute the means for 2017 ERW, Math and Total Scores.
# Sort and print data of top 5 states with highest SAT Participation Rates in 2017.
print('SAT Average Scores for States with more than 95% Participation Rate in 2017:')
print('ERW:', final[final['sat_participation_2017'] > 95]['sat_evidence-based_reading_and_writing_2017'].mean())
print('Math:',final[final['sat_participation_2017'] > 95]['sat_math_2017'].mean())
print('Total:',final[final['sat_participation_2017'] > 95]['sat_total_2017'].mean(),'\n')
print('Top 5 States with Highest SAT Participation Rates in 2017:')
final.sort_values(by='sat_participation_2017', ascending=False).head()
# Out:
# SAT Average Scores for States with more than 95% Participation Rate in 2017:
# ERW: 511.2
# Math: 497.4
# Total: 1008.8
#
# Top 5 States with Highest SAT Participation Rates in 2017:
#                       sat_participation_2017  \
# state
# District of Columbia                     100
# Michigan                                 100
# Connecticut                              100
# Delaware                                 100
# New Hampshire                             96
#
#                       sat_evidence-based_reading_and_writing_2017  \
# state
# District of Columbia                                          482
# Michigan                                                      509
# Connecticut                                                   530
# Delaware                                                      503
# New Hampshire                                                 532
#
#                       sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# ...

# %%
# Filter dataframe to include states with less than 5% SAT Participation Rates in 2017.
# Compute the means for 2017 ERW, Math and Total Scores.
# Sort and print data of bottom 5 states with lowest SAT Participation Rates in 2017.
print('SAT Average Scores for States with less than 5% Participation Rate in 2017:')
print('ERW:', final[final['sat_participation_2017'] < 5]['sat_evidence-based_reading_and_writing_2017'].mean())
print('Math:',final[final['sat_participation_2017'] < 5]['sat_math_2017'].mean())
print('Total:',final[final['sat_participation_2017'] < 5]['sat_total_2017'].mean(),'\n')
print('Bottom 5 States with Lowest SAT Participation Rates in 2017:')
final.sort_values(by='sat_participation_2017', ascending=False).tail()
# Out:
# SAT Average Scores for States with less than 5% Participation Rate in 2017:
# ERW: 629.6428571428571
# Math: 618.8571428571429
# Total: 1248.5714285714287
#
# Bottom 5 States with Lowest SAT Participation Rates in 2017:
#               sat_participation_2017  \
# state
# Arkansas                           3
# Wyoming                            3
# North Dakota                       2
# Mississippi                        2
# Iowa                               2
#
#               sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Arkansas                                              614            594
# Wyoming                                               626            604
# North Dakota                                          635            621
# Mississippi                                           634            607
# Iowa                                                  641            635
#
# ...

# %%
# Sort and print data of top 5 states with highest SAT Participation Rates in 2018.
print('Top 5 States with Highest SAT Participation Rates in 2018:')
final.sort_values(by='sat_participation_2018', ascending=False).head()
# Out:
# Top 5 States with Highest SAT Participation Rates in 2018:
#              sat_participation_2017  \
# state
# Colorado                         11
# Connecticut                     100
# Delaware                        100
# Michigan                        100
# Idaho                            93
#
#              sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Colorado                                             606            595
# Connecticut                                          530            512
# Delaware                                             503            492
# Michigan                                             509            495
# Idaho                                                513            493
#
#              sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Colorado               1201                     100              20.1
# Connecticut            1041                      31              25.5
# ...

# %%
# Sort and print data of bottom 5 states with lowest SAT Participation Rates in 2018.
print('Bottom 5 States with Lowest SAT Participation Rates in 2018:')
final.sort_values(by='sat_participation_2018', ascending=False).tail()
# Out:
# Bottom 5 States with Lowest SAT Participation Rates in 2018:
#               sat_participation_2017  \
# state
# Mississippi                        2
# Iowa                               2
# Wisconsin                          3
# Wyoming                            3
# North Dakota                       2
#
#               sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Mississippi                                           634            607
# Iowa                                                  641            635
# Wisconsin                                             642            649
# Wyoming                                               626            604
# North Dakota                                          635            621
#
#               sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Mississippi             1242                     100              18.2
# ...

# %%
# Filter dataframe to include states with increase in SAT participation rates from 2017 to 2018.
# Compute the means for changes in ERW, Math and Total Scores, as well as ACT participation rates.
# Sort and print data of top 5 states with highest increases in SAT Participation Rates.
print('Average Change in SAT Scores for States with Increase in Participation Rates from 2017 to 2018:')
print('ERW:', final[final['sat_participation_improvement'] > 0]['sat_erw_improvement'].mean())
print('Math:',final[final['sat_participation_improvement'] > 0]['sat_math_improvement'].mean())
print('Total:',final[final['sat_participation_improvement'] > 0]['sat_total_improvement'].mean())
print('Average Change in SAT Participation Rates:', 
      final[final['sat_participation_improvement'] > 0]['sat_participation_improvement'].mean())
print('Average Change in ACT Participation Rates:', 
      final[final['sat_participation_improvement'] > 0]['act_participation_improvement'].mean())
print('Number of States:',final[final['sat_participation_improvement'] > 0]['sat_participation_improvement'].count(),'\n')
print('Top 5 States with Highest Increases in SAT Participation Rates from 2017 to 2018:')
final.sort_values(by='sat_participation_improvement', ascending=False).head()
# Out:
# Average Change in SAT Scores for States with Increase in Participation Rates from 2017 to 2018:
# ERW: -4.885714285714286
# Math: -3.4
# Total: -8.257142857142858
# Average Change in SAT Participation Rates: 10.285714285714286
# Average Change in ACT Participation Rates: -5.257142857142857
# Number of States: 35
#
# Top 5 States with Highest Increases in SAT Participation Rates from 2017 to 2018:
#                sat_participation_2017  \
# state
# Illinois                            9
# Colorado                           11
# Rhode Island                       71
# Florida                            83
# West Virginia                      14
#
#                sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Illinois                                               559            556
# Colorado                                               606            595
# Rhode Island                                           539            524
# ...

# %% [markdown]
# These suggest negative correlations between improvements in SAT participation rates with improvements in SAT component and total scores, as well as ACT participation rates.

# %%
# Filter dataframe to include states with no increase in participation rates from 2017 to 2018.
# Compute the means for changes in ERW, Math and Total Scores, as well as ACT participation rates.
# Sort and print data of bottom 5 states with highest decreases in SAT Participation Rates.
print('Average Change in SAT States with No Increase in Participation Rates from 2017 to 2018:')
print('ERW:', final[final['sat_participation_improvement'] <= 0]['sat_erw_improvement'].mean())
print('Math:',final[final['sat_participation_improvement'] <= 0]['sat_math_improvement'].mean())
print('Total:',final[final['sat_participation_improvement'] <= 0]['sat_total_improvement'].mean())
print('Average Change in SAT Participation Rates:', 
      final[final['sat_participation_improvement'] <= 0]['sat_participation_improvement'].mean())
print('Average Change in ACT Participation Rates:', 
      final[final['sat_participation_improvement'] <= 0]['act_participation_improvement'].mean())
print('Number of States:',final[final['sat_participation_improvement'] <= 0]['sat_participation_improvement'].count(),'\n')
print('Bottom 5 States with Highest Decreases in SAT Participation Rates from 2017 to 2018:')
final.sort_values(by='sat_participation_improvement', ascending=False).tail()
# Out:
# Average Change in SAT States with No Increase in Participation Rates from 2017 to 2018:
# ERW: 4.875
# Math: 8.625
# Total: 13.5
# Average Change in SAT Participation Rates: -0.75
# Average Change in ACT Participation Rates: 0.0
# Number of States: 16
#
# Bottom 5 States with Highest Decreases in SAT Participation Rates from 2017 to 2018:
#                       sat_participation_2017  \
# state
# Nebraska                                   3
# Wyoming                                    3
# Arizona                                   30
# Nevada                                    26
# District of Columbia                     100
#
#                       sat_evidence-based_reading_and_writing_2017  \
# state
# Nebraska                                                      629
# Wyoming                                                       626
# Arizona                                                       563
# Nevada                                                        563
# ...

# %%
# Filter dataframe to include states with <50% SAT participation rates in 2017, 
# and with further decrease in participation rates in 2018.
print('States with <50% SAT Participation Rates in 2017 and further decrease in 2018:')
final[(final['sat_participation_2017']<50) & (final['sat_participation_improvement']<0)]
# Out:
# States with <50% SAT Participation Rates in 2017 and further decrease in 2018:
#          sat_participation_2017  sat_evidence-based_reading_and_writing_2017  \
# state
# Arizona                      30                                          563
# Nevada                       26                                          563
#
#          sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# Arizona            553            1116                      62
# Nevada             553            1116                     100
#
#          act_english_2017  act_math_2017  act_reading_2017  act_science_2017  \
# state
# Arizona              18.6           19.8              20.1              19.8
# Nevada               16.3           18.0              18.1              18.2
#
#          act_composite_2017  ...  sat_participation_improvement  \
# state                        ...
# Arizona                19.7  ...                             -1
# ...

# %% [markdown]
# **ACT Participation Rates**

# %%
# Filter dataframe to include states with more than 95% ACT Participation Rates in 2017.
# Compute the means for 2017 English, Math, Reading, Science and Composite Scores.
# Sort and print data of top 5 states with highest ACT Participation Rates in 2017.
print('ACT Average Scores for States with more than 95% Participation Rate in 2017:')
print('English:', final[final['act_participation_2017'] > 95]['act_english_2017'].mean())
print('Math:',final[final['act_participation_2017'] > 95]['act_math_2017'].mean())
print('Reading:',final[final['act_participation_2017'] > 95]['act_reading_2017'].mean())
print('Science:',final[final['act_participation_2017'] > 95]['act_science_2017'].mean())
print('Composite:',final[final['act_participation_2017'] > 95]['act_composite_2017'].mean(),'\n')
print('Top 5 States with Highest ACT Participation Rates in 2017:')
final.sort_values(by='act_participation_2017', ascending=False).head()
# Out:
# ACT Average Scores for States with more than 95% Participation Rate in 2017:
# English: 18.97222222222222
# Math: 19.444444444444443
# Reading: 20.16666666666667
# Science: 19.97222222222222
# Composite: 19.766666666666666
#
# Top 5 States with Highest ACT Participation Rates in 2017:
#            sat_participation_2017  \
# state
# Alabama                         5
# Kentucky                        4
# Wisconsin                       3
# Utah                            3
# Tennessee                       5
#
#            sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Alabama                                            593            572
# Kentucky                                           631            616
# Wisconsin                                          642            649
# Utah                                               624            614
# Tennessee                                          623            604
#
# ...

# %%
# Filter dataframe to include states with less than 25% ACT Participation Rates in 2017.
# Compute the means for 2017 English, Math, Reading, Science and Composite Scores.
# Sort and print data of bottom 5 states with lowest ACT Participation Rates in 2017.
print('ACT Average Scores for States with less than 25% Participation Rate in 2017:')
print('English:', final[final['act_participation_2017'] < 25]['act_english_2017'].mean())
print('Math:',final[final['act_participation_2017'] < 25]['act_math_2017'].mean())
print('Reading:',final[final['act_participation_2017'] < 25]['act_reading_2017'].mean())
print('Science:',final[final['act_participation_2017'] < 25]['act_science_2017'].mean())
print('Composite:',final[final['act_participation_2017'] < 25]['act_composite_2017'].mean(),'\n')
print('Bottom 5 States with Lowest ACT Participation Rates in 2017:')
final.sort_values(by='act_participation_2017', ascending=False).tail()
# Out:
# ACT Average Scores for States with less than 25% Participation Rate in 2017:
# English: 24.22
# Math: 23.84
# Reading: 24.9
# Science: 23.779999999999994
# Composite: 24.32
#
# Bottom 5 States with Lowest ACT Participation Rates in 2017:
#                sat_participation_2017  \
# state
# Pennsylvania                       65
# Rhode Island                       71
# Delaware                          100
# New Hampshire                      96
# Maine                              95
#
#                sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Pennsylvania                                           540            531
# Rhode Island                                           539            524
# Delaware                                               503            492
# New Hampshire                                          532            520
# Maine                                                  513            499
#
# ...

# %%
# Sort and print data of top 5 states with highest ACT Participation Rates in 2018.
print('Top 5 States with Highest ACT Participation Rates in 2018:')
final.sort_values(by='act_percentage_of_students_tested_2018', ascending=False).head()
# Out:
# Top 5 States with Highest ACT Participation Rates in 2018:
#            sat_participation_2017  \
# state
# Alabama                         5
# Kentucky                        4
# Wisconsin                       3
# Utah                            3
# Tennessee                       5
#
#            sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Alabama                                            593            572
# Kentucky                                           631            616
# Wisconsin                                          642            649
# Utah                                               624            614
# Tennessee                                          623            604
#
#            sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Alabama              1165                     100              18.9
# Kentucky             1247                     100              19.6
# ...

# %%
# Sort and print data of bottom 5 states with lowest ACT Participation Rates in 2018.
print('Bottom 5 States with Lowest ACT Participation Rates in 2018:')
final.sort_values(by='act_percentage_of_students_tested_2018', ascending=False).tail()
# Out:
# Bottom 5 States with Lowest ACT Participation Rates in 2018:
#                sat_participation_2017  \
# state
# Pennsylvania                       65
# Delaware                          100
# New Hampshire                      96
# Rhode Island                       71
# Maine                              95
#
#                sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Pennsylvania                                           540            531
# Delaware                                               503            492
# New Hampshire                                          532            520
# Rhode Island                                           539            524
# Maine                                                  513            499
#
#                sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Pennsylvania             1071                      23              23.4
# ...

# %%
# Sort and print data of top 5 states with highest increases in ACT Participation Rates from 2017 to 2018.
print('Top 5 States with Highest Increases in ACT Participation Rates from 2017 to 2018:')
final.sort_values(by='act_participation_improvement', ascending=False).head()
# Out:
# Top 5 States with Highest Increases in ACT Participation Rates from 2017 to 2018:
#           sat_participation_2017  sat_evidence-based_reading_and_writing_2017  \
# state
# Ohio                          12                                          578
# Nebraska                       3                                          629
# Arizona                       30                                          563
# Maryland                      69                                          536
# Oregon                        43                                          560
#
#           sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# Ohio                570            1149                      75
# Nebraska            625            1253                      84
# Arizona             553            1116                      62
# Maryland            524            1060                      28
# Oregon              548            1108                      40
#
# ...

# %% [markdown]
# **SAT Total Scores**

# %%
# Sort and print data of top 5 states with highest SAT total scores in 2017.
print('Top 5 States with Highest SAT Total Scores in 2017:')
final.sort_values(by='sat_total_2017', ascending=False).head()
# Out:
# Top 5 States with Highest SAT Total Scores in 2017:
#            sat_participation_2017  \
# state
# Minnesota                       3
# Wisconsin                       3
# Iowa                            2
# Missouri                        3
# Kansas                          4
#
#            sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Minnesota                                          644            651
# Wisconsin                                          642            649
# Iowa                                               641            635
# Missouri                                           640            631
# Kansas                                             632            628
#
#            sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Minnesota            1295                     100              20.4
# Wisconsin            1291                     100              19.7
# ...

# %%
# Sort and print data of bottom 5 states with lowest SAT total scores in 2017.
print('Bottom 5 States with Lowest SAT Total Scores in 2017:')
final.sort_values(by='sat_total_2017', ascending=False).tail()
# Out:
# Bottom 5 States with Lowest SAT Total Scores in 2017:
#                       sat_participation_2017  \
# state
# Maine                                     95
# Idaho                                     93
# Michigan                                 100
# Delaware                                 100
# District of Columbia                     100
#
#                       sat_evidence-based_reading_and_writing_2017  \
# state
# Maine                                                         513
# Idaho                                                         513
# Michigan                                                      509
# Delaware                                                      503
# District of Columbia                                          482
#
#                       sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# Maine                           499            1012                       8
# ...

# %%
# Sort and print data of top 5 states with highest SAT total scores in 2018.
print('Top 5 States with Highest SAT Total Scores in 2018:')
final.sort_values(by='sat_total_2018', ascending=False).head()
# Out:
# Top 5 States with Highest SAT Total Scores in 2018:
#               sat_participation_2017  \
# state
# Minnesota                          3
# Wisconsin                          3
# North Dakota                       2
# Iowa                               2
# Kansas                             4
#
#               sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Minnesota                                             644            651
# Wisconsin                                             642            649
# North Dakota                                          635            621
# Iowa                                                  641            635
# Kansas                                                632            628
#
#               sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Minnesota               1295                     100              20.4
# Wisconsin               1291                     100              19.7
# ...

# %%
# Sort and print data of bottom 5 states with lowest SAT total scores in 2018.
print('Bottom 5 States with Lowest SAT Total Scores in 2018:')
final.sort_values(by='sat_total_2018', ascending=False).tail()
# Out:
# Bottom 5 States with Lowest SAT Total Scores in 2018:
#                       sat_participation_2017  \
# state
# Michigan                                 100
# Idaho                                     93
# West Virginia                             14
# Delaware                                 100
# District of Columbia                     100
#
#                       sat_evidence-based_reading_and_writing_2017  \
# state
# Michigan                                                      509
# Idaho                                                         513
# West Virginia                                                 558
# Delaware                                                      503
# District of Columbia                                          482
#
#                       sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# Michigan                        495            1005                      29
# ...

# %% [markdown]
# **ACT Composite Scores**

# %%
# Sort and print data of top 5 states with highest ACT composite scores in 2017.
print('Top 5 States with Highest ACT Composite Scores in 2017:')
final.sort_values(by='act_composite_2017', ascending=False).head()
# Out:
# Top 5 States with Highest ACT Composite Scores in 2017:
#                       sat_participation_2017  \
# state
# New Hampshire                             96
# Massachusetts                             76
# Connecticut                              100
# Maine                                     95
# District of Columbia                     100
#
#                       sat_evidence-based_reading_and_writing_2017  \
# state
# New Hampshire                                                 532
# Massachusetts                                                 555
# Connecticut                                                   530
# Maine                                                         513
# District of Columbia                                          482
#
#                       sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# New Hampshire                   520            1052                      18
# ...

# %%
# Sort and print data of bottom 5 states with lowest ACT composite scores in 2017.
print('Bottom 5 States with Lowest ACT Composite Scores in 2017:')
final.sort_values(by='act_composite_2017', ascending=False).tail()
# Out:
# Bottom 5 States with Lowest ACT Composite Scores in 2017:
#                 sat_participation_2017  \
# state
# North Carolina                      49
# Hawaii                              55
# South Carolina                      50
# Mississippi                          2
# Nevada                              26
#
#                 sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# North Carolina                                          546            535
# Hawaii                                                  544            541
# South Carolina                                          543            521
# Mississippi                                             634            607
# Nevada                                                  563            553
#
#                 sat_total_2017  act_participation_2017  act_english_2017  \
# state
# North Carolina            1081                     100              17.8
# ...

# %%
# Sort and print data of top 5 states with highest ACT composite scores in 2018.
print('Top 5 States with Highest ACT Composite Scores in 2018:')
final.sort_values(by='act_average_composite_score_2018', ascending=False).head()
# Out:
# Top 5 States with Highest ACT Composite Scores in 2018:
#                sat_participation_2017  \
# state
# Connecticut                       100
# Massachusetts                      76
# New Hampshire                      96
# New York                           67
# Michigan                          100
#
#                sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Connecticut                                            530            512
# Massachusetts                                          555            551
# New Hampshire                                          532            520
# New York                                               528            523
# Michigan                                               509            495
#
#                sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Connecticut              1041                      31              25.5
# ...

# %%
# Sort and print data of bottom 5 states with lowest ACT total scores in 2018.
print('Bottom 5 States with Lowest ACT Total Scores in 2018:')
final.sort_values(by='act_average_composite_score_2018', ascending=False).tail()
# Out:
# Bottom 5 States with Lowest ACT Total Scores in 2018:
#                 sat_participation_2017  \
# state
# Alabama                              5
# Hawaii                              55
# Mississippi                          2
# South Carolina                      50
# Nevada                              26
#
#                 sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Alabama                                                 593            572
# Hawaii                                                  544            541
# Mississippi                                             634            607
# South Carolina                                          543            521
# Nevada                                                  563            553
#
#                 sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Alabama                   1165                     100              18.9
# ...

# %% [markdown]
# **Additional Data**

# %%
# Filter dataframe to include states with 100% SAT participation rates in 2017, then print.
print('States with 100% SAT participation rates in 2017:')
final[final['sat_participation_2017']==100]
# Out:
# States with 100% SAT participation rates in 2017:
#                       sat_participation_2017  \
# state
# Connecticut                              100
# Delaware                                 100
# District of Columbia                     100
# Michigan                                 100
#
#                       sat_evidence-based_reading_and_writing_2017  \
# state
# Connecticut                                                   530
# Delaware                                                      503
# District of Columbia                                          482
# Michigan                                                      509
#
#                       sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# Connecticut                     512            1041                      31
# Delaware                        492             996                      18
# District of Columbia            468             950                      32
# ...

# %%
# Filter dataframe to include states with 100% SAT participation rates in 2018, then print.
print('States with 100% SAT participation rates in 2018:')
final[final['sat_participation_2018']==100]
# Out:
# States with 100% SAT participation rates in 2018:
#              sat_participation_2017  \
# state
# Colorado                         11
# Connecticut                     100
# Delaware                        100
# Idaho                            93
# Michigan                        100
#
#              sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Colorado                                             606            595
# Connecticut                                          530            512
# Delaware                                             503            492
# Idaho                                                513            493
# Michigan                                             509            495
#
#              sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Colorado               1201                     100              20.1
# Connecticut            1041                      31              25.5
# ...

# %%
# Filter dataframe to include states with 100% ACT participation rates in 2017, then print.
print('States with 100% ACT participation rates in 2017:')
final[final['act_participation_2017']==100]
# Out:
# States with 100% ACT participation rates in 2017:
#                 sat_participation_2017  \
# state
# Alabama                              5
# Arkansas                             3
# Colorado                            11
# Kentucky                             4
# Louisiana                            4
# Minnesota                            3
# Mississippi                          2
# Missouri                             3
# Montana                             10
# Nevada                              26
# North Carolina                      49
# Oklahoma                             7
# South Carolina                      50
# Tennessee                            5
# Utah                                 3
# Wisconsin                            3
# Wyoming                              3
#
#                 sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Alabama                                                 593            572
# ...

# %%
# Filter dataframe to include states with 100% ACT participation rates in 2018, then print.
print('States with 100% ACT participation rates in 2018:')
final[final['act_percentage_of_students_tested_2018']==100]
# Out:
# States with 100% ACT participation rates in 2018:
#                 sat_participation_2017  \
# state
# Alabama                              5
# Arkansas                             3
# Kentucky                             4
# Louisiana                            4
# Mississippi                          2
# Missouri                             3
# Montana                             10
# Nebraska                             3
# Nevada                              26
# North Carolina                      49
# Ohio                                12
# Oklahoma                             7
# South Carolina                      50
# Tennessee                            5
# Utah                                 3
# Wisconsin                            3
# Wyoming                              3
#
#                 sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Alabama                                                 593            572
# ...

# %%
# Filter dataframe to include states with >50% for both SAT and ACT participation rates in 2017, then print.
print('States with >50% for both SAT and ACT Participation Rates in 2017:')
final[(final['sat_participation_2017']>50) & (final['act_participation_2017']>50)]
# Out:
# States with >50% for both SAT and ACT Participation Rates in 2017:
#          sat_participation_2017  sat_evidence-based_reading_and_writing_2017  \
# state
# Florida                      83                                          520
# Georgia                      61                                          535
# Hawaii                       55                                          544
#
#          sat_math_2017  sat_total_2017  act_participation_2017  \
# state
# Florida            497            1017                      73
# Georgia            515            1050                      55
# Hawaii             541            1085                      90
#
#          act_english_2017  act_math_2017  act_reading_2017  act_science_2017  \
# state
# Florida              19.0           19.4              21.0              19.4
# Georgia              21.0           20.9              22.0              21.3
# Hawaii               17.8           19.2              19.2              19.3
#
# ...

# %%
# Filter dataframe to include states with >50% for both SAT and ACT participation rates in 2018, then print.
print('States with >50% for both SAT and ACT Participation Rates in 2018:')
final[(final['sat_participation_2018']>50) & (final['act_percentage_of_students_tested_2018']>50)]
# Out:
# States with >50% for both SAT and ACT Participation Rates in 2018:
#                 sat_participation_2017  \
# state
# Florida                             83
# Georgia                             61
# Hawaii                              55
# North Carolina                      49
# South Carolina                      50
#
#                 sat_evidence-based_reading_and_writing_2017  sat_math_2017  \
# state
# Florida                                                 520            497
# Georgia                                                 535            515
# Hawaii                                                  544            541
# North Carolina                                          546            535
# South Carolina                                          543            521
#
#                 sat_total_2017  act_participation_2017  act_english_2017  \
# state
# Florida                   1017                      73              19.0
# ...

# %%
# Filter dataframe to include states with <70% for both SAT and ACT participation rates in both 2017 and 2018, then print.
print('States with <70% for both SAT and ACT Participation Rates in 2017 or 2018:')
statesOfInterest = final[(final['sat_participation_2017']<70) & (final['act_participation_2017']<70) & 
                        (final['sat_participation_2018']<70) & (final['act_percentage_of_students_tested_2018']<70)]
columnsOfInterest = ['sat_participation_2017','act_participation_2017','sat_participation_2018',
                     'act_percentage_of_students_tested_2018']
statesOfInterest[columnsOfInterest]
# Out:
# States with <70% for both SAT and ACT Participation Rates in 2017 or 2018:
#                sat_participation_2017  act_participation_2017  \
# state
# Alaska                             38                      65
# Arizona                            30                      62
# California                         53                      31
# Indiana                            63                      35
# Iowa                                2                      67
# New Mexico                         11                      66
# Oregon                             43                      40
# Texas                              62                      45
# Vermont                            60                      29
# Virginia                           65                      29
# Washington                         64                      29
# West Virginia                      14                      69
#
# ...

# %% [markdown]
# ### Insights from EDA
#
# For increasing SAT participation, the state of **California** was identified since it has relatively lower participation rates in both SAT and ACT (<70%), which suggests that the state has not yet been "monopolised" by either the SAT or ACT, so there is potential for the College Board to expand its presence and significantly improve participation rates. California was also chosen because it has the largest population, hence effecting recommendations to target the state could impact a greater number of students, such that even a small increase in participation rate would have great impact on increasing the overall country's SAT participation rate.
#
# In 2017, there were 17 states with 100% participation rate for ACT. However, there were only 4 states with 100% participation rate for the SAT.
#
# In 2017, there were only 3 states (Florida, Georgia, Hawaii) with > 50% participation rates for both SAT and ACT.
# In 2018, there were 2 additional states (North Carolina, South Carolina) with > 50% participation rates for both SAT and ACT.
#
# The states which had large increases in SAT participation rates from 2017 to 2018 are also identified:
# 1. Illinois
# 2. Colorado
#
# Analysing these states would also enable us to find insights on how they generated the increase in participation.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# Find correlations of variables in dataframe, then use seaborn heat map to plot.
final_correlations = final.corr()

# Set figure size to ensure it is large enough to display all variables in dataframe clearly.
plt.figure(figsize = (20,20))

# Set annot=True to include correlation values within each box for better understanding of plot.
ax = sns.heatmap(final_correlations,xticklabels=True, yticklabels=True, annot=True,linewidths=.5, cmap="Blues")

# Code to add space at top and bottom of heat map - default settings will cut off plot at top and bottom.
bottom, top = ax.get_ylim()
ax.set_title('Heat Map for Correlations between variables in dataframe')
ax.set_ylim(bottom + 0.5, top - 0.5);

# %% [markdown]
# This heatmap is informative and useful for identifying relationships, but can be intimidating and confusing because it consists many different variables. Hence, it is important to filter and focus on the important parameters that could help provide more insights with regards to the initial problem statement.

# %%
# Since our problem statement focuses on improving SAT participation rates, we are interested to find out the
# correlations with respect to the improvement of SAT participation rates from 2017-2018.
# Filter the datasets to only include the feature engineering columns which show the changes over 2017-2018.
columnsFeature = ['sat_participation_improvement','sat_erw_improvement','sat_math_improvement','sat_total_improvement',
                  'act_participation_improvement','act_english_improvement','act_math_improvement',
                 'act_reading_improvement','act_science_improvement','act_composite_improvement']

final_correlations = final[columnsFeature].corr()
plt.figure(figsize = (10,5))
ax = sns.heatmap(final_correlations,xticklabels=True, yticklabels=True, annot=True,linewidths=.5, cmap="Blues")

bottom, top = ax.get_ylim()
ax.set_title('Heat Map for Correlations between variables in dataframe')
ax.set_ylim(bottom + 0.5, top - 0.5);

# %% [markdown]
# Based on the heatmaps generated, the 'sat_partipation_improvement' variable is highly negatively correlated to the variable 'act_participation_improvement', with a correlation of -0.84. This suggests that states with increase in SAT participation rates likely had a corresponding decrease in ACT participation rates from 2017 to 2018.
#
# The 'sat_participation_2017' variable is highly positively correlated to the 'sat_participation_2018' variable, with a correlation of 0.89. This suggests that states with high SAT participation rates in 2017 are likely to have high SAT participation rates in 2018 as well.
#
# The SAT participation rates are negatively correlated to the SAT subject and total scores, and positively correlated to the ACT subject and composite scores, for 2017 and 2018.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles=0, list_of_xlabels=0):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2,figsize=(8,5),sharey=True)
    plt.subplots_adjust(wspace=0.3, hspace=0.7)
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Histogram subplots of SAT and ACT participation rates for 2017 and 2018.
list_of_titles = ['SAT 2017 Participation Rates (%)','SAT 2018 Participation Rates (%)',
                  'ACT 2017 Participation Rates (%)','ACT 2018 Participation Rates (%)']
list_of_xlabels = ['SAT 2017','SAT 2018','ACT 2017','SAT 2018']
list_of_columns = ['sat_participation_2017','sat_participation_2018',
                    'act_participation_2017','act_percentage_of_students_tested_2018']
subplot_histograms(final, list_of_columns, list_of_titles,list_of_xlabels)

# %%
list_of_titles = ['SAT 2017 Math Scores','SAT 2018 Math Scores',
                  'ACT 2017 Math Scores','ACT 2018 Math Scores']
list_of_xlabels = ['SAT Math 2017','SAT Math 2018','ACT Math 2017','ACT Math 2018']
list_of_columns = ['sat_math_2017','sat_math_2018','act_math_2017','act_average_math_score_2018']
subplot_histograms(final, list_of_columns, list_of_titles,list_of_xlabels)

# %%
list_of_titles = ['SAT 2017 ERW Scores','SAT 2018 ERW Scores',
                  'ACT 2017 Reading Scores','ACT 2018 Reading Scores']
list_of_xlabels = ['SAT ERW 2017','SAT ERW 2018','ACT Reading 2017','ACT Reading 2018']
list_of_columns = ['sat_evidence-based_reading_and_writing_2017','sat_evidence-based_reading_and_writing_2018',
                   'act_reading_2017','act_average_reading_score_2018']
subplot_histograms(final, list_of_columns, list_of_titles,list_of_xlabels)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Scatter plot of SAT vs ACT math scores for 2017.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_math_2017', y='act_math_2017', data=final, s=100)
plt.title('SAT vs. ACT Math Scores for 2017')
plt.xlabel('SAT Math Scores 2017');
plt.ylabel('ACT Math Scores 2017');

# %% [markdown]
# There is a negative correlation (-0.42), which suggests that states which had better SAT math scores were likely to have lower ACT math scores.

# %%
# Scatter plot of SAT vs ACT reading & writing scores for 2017.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_evidence-based_reading_and_writing_2017', y='act_reading_2017', data=final, s=100)
plt.title('SAT vs. ACT Reading & Writing Scores for 2017')
plt.xlabel('SAT ERW Scores 2017');
plt.ylabel('ACT Reading Scores 2017');

# %% [markdown]
# There is a negative correlation (-0.49), which suggests that states which had better SAT reading/writing scores were likely to have lower ACT reading scores.

# %%
# Scatter plot for SAT vs ACT total/composite scores for 2017.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_total_2017', y='act_composite_2017', data=final, s=100)
plt.title('SAT vs. ACT Total/Composite Scores for 2017')
plt.xlabel('SAT Total Scores 2017');
plt.ylabel('ACT Composite Scores 2017');

# %% [markdown]
# There is a negative correlation (-0.45), which suggests that states which had better SAT total scores were likely to have lower ACT composite scores.

# %%
# Scatter plot for SAT total scores in 2017 vs 2018
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_total_2017', y='sat_total_2018', data=final, s=100)
plt.title('Total Scores for SAT 2017 vs. 2018')
plt.xlabel('SAT Total Scores 2017');
plt.ylabel('SAT Total Scores 2018');

# %% [markdown]
# There is a strong positive correlation (0.92), which suggests that states with high SAT total scores in 2017 are likely to have high SAT total scores in 2018 as well.

# %%
# Scatter plot for ACT composite scores in 2017 vs 2018.
plt.figure(figsize = (10,5))
sns.scatterplot(x='act_composite_2017', y='act_average_composite_score_2018', data=final, s=100)
plt.title('Composite scores for ACT 2017 vs. 2018')
plt.xlabel('ACT Composite Scores 2017');
plt.ylabel('ACT Composite Scores 2018');

# %% [markdown]
# There is a strong positive correlation (0.94), which suggests that states with high ACT composite scores in 2017 are likely to have high ACT composite scores in 2018 as well.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Plot SAT and ACT participation rates on a single boxplot, since they are of the same relative scale (0-100%).
columnsParticipation = ['sat_participation_2017','sat_participation_2018',
                        'act_participation_2017','act_percentage_of_students_tested_2018']
dataParticipation = final[columnsParticipation]
dataParticipation.columns = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']

plt.figure(figsize = (8,5))
sns.boxplot(data=dataParticipation).set_title('SAT and ACT Participation Rates (%) in 2017 and 2018');

# %%
print('SAT 2017 average participation rate (%):', dataParticipation['SAT 2017'].mean())
print('SAT 2018 average participation rate (%):', dataParticipation['SAT 2018'].mean())
print('ACT 2017 average participation rate (%):', dataParticipation['ACT 2017'].mean())
print('ACT 2018 average participation rate (%):', dataParticipation['ACT 2018'].mean())
# Out:
# SAT 2017 average participation rate (%): 39.80392156862745
# SAT 2018 average participation rate (%): 46.627450980392155
# ACT 2017 average participation rate (%): 65.25490196078431
# ACT 2018 average participation rate (%): 61.64705882352941

# %% [markdown]
# Overall, the ACT participation rates are generally higher than the SAT participation rates for 2017 and 2018. However, average SAT participation rates increased from 2017 to 2018, while average ACT participation rates decreased.
#
# For SAT, the values in the IQR are close to the minimum value, which suggests that the bottom 25% of the states have similar participation rates.
#
# For ACT, the values in the IQR are close to the maximum value, which suggests that the top 25% of the states have similar participation rates.

# %%
# Plot SAT component scores for 2017 and 2018 on a single boxplot, since they are of the same relative scale (0-800).
columnsSATComponentScores = ['sat_evidence-based_reading_and_writing_2017','sat_math_2017',
                        'sat_evidence-based_reading_and_writing_2018','sat_math_2018']
dataSATComponentScores = final[columnsSATComponentScores]
dataSATComponentScores.columns = ['ERW 2017','Math 2017','ERW 2018','Math 2018']

plt.figure(figsize = (8,5))
sns.boxplot(data=dataSATComponentScores).set_title('SAT Component Scores in 2017 and 2018');

# %% [markdown]
# Overall, the median values for each SAT component test are closer to the 25%, which suggests that states in the 25-50th percentile have similar scores, as compared to states in the 50th to 75% percentile.
#
# The SAT math scores for both 2017 and 2018 seem to have slightly lower mean, and slightly higher standard deviation as compared to the ERW scores.

# %%
# Plot SAT total scores for 2017 and 2018 on a single boxplot, since they are of the same relative scale (0-1600).
columnsSATTotalScores = ['sat_total_2017', 'sat_total_2018']
dataSATTotalScores = final[columnsSATTotalScores]
dataSATTotalScores.columns = ['2017','2018']

plt.figure(figsize = (4,5))
sns.boxplot(data=dataSATTotalScores).set_title('SAT Total Scores in 2017 and 2018');

# %% [markdown]
# In 2018, both the minimum and maximum total SAT scores improved as compared to 2017.

# %%
# Plot ACT component and composite scores for 2017 and 2018 on a single boxplot, 
# since they are of the same relative scale (1-36)
columnsACTScores = ['act_english_2017','act_math_2017','act_reading_2017', 'act_science_2017','act_composite_2017',
                    'act_average_english_score_2018','act_average_math_score_2018','act_average_reading_score_2018', 
                    'act_average_science_score_2018','act_average_composite_score_2018']
dataACTScores = final[columnsACTScores]
dataACTScores.columns = ['English 2017','Math 2017','Reading 2017', 'Science 2017','Composite 2017', 
                         'English 2018','Math 2018','Reading 2018', 'Science 2018','Composite 2018']

plt.figure(figsize = (16,5))
sns.boxplot(data=dataACTScores).set_title('ACT Component and Composite Scores in 2017 and 2018');

# %% [markdown]
# The boxplots for each component/composite ACT tests have similar characteristics in both 2017 and 2018.
#
# In general, ACT reading scores are higher than english, math or science scores.

# %% [markdown]
# #### Feel free to do additional plots below
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# **Further analyse relationships and correlations between variables using scatterplots:**

# %%
# Plot scatterplot of SAT vs ACT participation rates in 2017, with the hue representing the SAT total scores.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_participation_2017', y='act_participation_2017', hue='sat_total_2017', data=final, 
                s=100).set_title('SAT vs ACT Participation Rates in 2017, Hue = SAT Total Scores in 2017');

# %% [markdown]
# There is a negative correlation between the SAT and ACT participation rates in 2017, which suggests that states with high SAT participation rates are likely to have low ACT participation rates, and vice versa.
#
# There is also a negative correlation between the SAT participation rates and the SAT total scores in 2017, which suggests that states with high SAT participation rates are likely to have low SAT total scores, and vice versa.

# %%
# Plot scatterplot of SAT vs ACT participation rates in 2018, with the hue representing the SAT total scores.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_participation_2018', y='act_percentage_of_students_tested_2018', hue='sat_total_2018', data=final, 
                s=100).set_title('SAT vs ACT Participation Rates in 2018, Hue = SAT Total Scores in 2018');

# %% [markdown]
# Similar to the data distribution for the 2017 plot, there are negative correlations between the SAT and ACT participation rates in 2018, as well as between the SAT participation rates and SAT total scores in 2018.

# %%
# Plot scatterplot of SAT vs ACT participation improvement from 2017 to 2018.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_participation_improvement', y='act_participation_improvement', data=final, 
                s=100).set_title('SAT vs ACT Participation Improvements from 2017 to 2018, corr = -0.84');

# %% [markdown]
# The scatterplot gives more details on how the SAT and ACT participation improvements are negatively correlated. The 2 data points at the bottom right corner are from the states of Illinois and Colorado, which showed highest improvement in SAT participation rates, which corresponded to large decreases in ACT participation from 2017 to 2018.

# %%
# Plot scatterplot of 2017 SAT participation rates vs 2018 SAT participation rates.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_participation_2017', y='sat_participation_2018', data=final, 
                s=100).set_title('SAT Participation Rates for 2017 vs 2018');

# %%
# Plot scatterplot of SAT participation improvements from 2017 to 2018 vs SAT total scores in 2017.
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_participation_improvement', y='sat_total_2017', data=final,
                s=100).set_title('SAT Participation Improvements from 2017 to 2018 vs SAT Total Scores in 2017');

# %%
# Plot scatterplot of SAT participation improvements from 2017 to 2018 vs ACT composite scores in 2017
plt.figure(figsize = (10,5))
sns.scatterplot(x='sat_participation_improvement', y='act_composite_2017', data=final,
                s=100).set_title('SAT Participation Improvements from 2017 to 2018 vs ACT Composite Scores in 2017');

# %% [markdown]
# There are no clear correlations between the SAT participation improvements and the SAT total scores or ACT composite scores in 2017. This suggests that students generally did not decide to switch from ACT to SAT in 2018 or vice versa because of their scores in 2017.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# **sat_participation_2017**: Mean = 39.8, Std = 35.3, Min = 2, 25% = 4, 50% = 38, 75% = 66, Max = 100. The data has a large spread, based on the high standard deviation with respect to the magnitude of the mean. The bottom 25% of states have participation rates between 2% to 4%.
#
#
# **sat_evidence-based_reading_and_writing_2017**: Mean = 569.1, Std = 45.7, Min = 482, 25% = 533.5, 50% = 559, 75% = 613, Max = 644. The distribution is slightly right-skewed, since the mean (569.1) is larger than the median (559). The data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **sat_math_2017**: Mean = 556.9, Std = 47.1, Min = 468, 25% = 523.5, 50% = 548, 75% = 599, Max = 651. The distribution is slightly right-skewed, since the mean (556.9) is larger than the median (548). The data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **sat_total_2017**: Mean = 1126.1, Std = 92.5, Min = 950, 25% = 1056, 50% = 1107, 75% = 1212, Max = 1295. This variable is the computed using the sum of the 'sat_evidence-based_reading_and_writing_2017' and 'sat_math_2017'. The distribution is similar to 'sat_evidence-based_reading_and_writing_2017' and 'sat_math_2017' as well.
#
#
# **sat_participation_2018**: Mean = 46.6, Std = 38.0, Min = 2, 25% = 4.5, 50% = 52, 75% = 79.5, Max = 100. The data has a large spread, based on the high standard deviation with respect to the magnitude of the mean. As compared to 'sat_participation_2017', the mean is higher. However, the bottom 25% of states still have low participation rates, between 2% to 4.5%.
#
#
# **sat_evidence-based_reading_and_writing_2018**: Mean = 567.3, Std = 45.3, Min = 497, 25% = 535, 50% = 552, 75% = 616.5, Max = 643. The distribution is slightly right-skewed, since the mean (563.7) is larger than the median (552). The data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **sat_math_2018**: Mean = 557.3, Std = 48.9, Min = 480, 25% = 521.5, 50% = 547, 75% = 600.5, Max = 655. The distribution is slightly right-skewed, since the mean (556.2) is larger than the median (544). The data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **sat_total_2018**: Mean = 1124.7, Std = 93.9, Min = 977, 25% = 1062.5, 50% = 1099, 75% = 1220, Max = 1298. This variable is the computed using the sum of the 'sat_evidence-based_reading_and_writing_2018' and 'sat_math_2018'. The distribution is similar to 'sat_evidence-based_reading_and_writing_2018' and 'sat_math_2018' as well.
#
#
# **act_participation_2017**: Mean = 65.3, Std = 32.1, Min = 8, 25% = 31, 50% = 69, 75% = 100, Max = 100. The data has a large spread, given the high standard deviation with respect to the magnitude of the mean. The top 25% of states have 100% ACT participation rates in 2017.
#
#
# **act_english_2017**: Mean = 20.9, Std = 2.4, Min = 16.3, 25% = 19, 50% = 20.7, 75% = 23.3, Max = 25.5. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_math_2017**: Mean = 21.2, Std = 2.0, Min = 18, 25% = 19.4, 50% = 20.9, 75% = 23.1, Max = 25.3. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_reading_2017**: Mean = 22.0, Std = 2.1, Min = 18.1, 25% = 20.5, 50% = 21.8, 75% = 24.2, Max = 26. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_science_2017**: Mean = 21.5, Std = 1.7, Min = 18.2, 25% = 20, 50% = 21.3, 75% = 23.2, Max = 24.9. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_composite_2017**: Mean = 21.5, Std = 2.0, Min = 17.8, 25% = 19.8, 50% = 21.4, 75% = 23.6, Max = 25.5. This variable is the computed using the sum of the ACT english, math, reading and science scores. The distribution is similar to those as well.
#
#
# **act_percentage_of_students_tested_2018**: Mean = 61.6, Std = 34.1, Min = 7, 25% = 28.5, 50% = 66, 75% = 100, Max = 100. The data has a large spread, given the high standard deviation with respect to the magnitude of the mean. The top 25% of states have 100% ACT participation rates in 2017.
#
#
# **act_average_english_score_2018**: Mean = 21.0, Std = 2.4, Min = 16.6, 25% = 19.1, 50% = 20.2, 75% = 23.7, Max = 26. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_average_math_score_2018**: Mean = 21.2, Std = 2.0, Min = 17.8, 25% = 19.4, 50% = 20.7, 75% = 23.2, Max = 25.2. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_average_reading_score_2018**: Mean = 22.0, Std = 2.2, Min = 18, 25% = 20.5, 50% = 21.6, 75% = 24.1, Max = 26.1. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_average_science_score_2018**: Mean = 21.3, Std = 1.9, Min = 17.9, 25% = 19.9, 50% = 21.1, 75% = 23.1, Max = 24.9. The value of the mean is close to the median, and the data has a small spread, since the standard deviation is low with respect to the magnitude of the mean.
#
#
# **act_average_composite_score_2018**: Mean = 21.5, Std = 2.1, Min = 17.7, 25% = 20.0, 50% = 21.3, 75% = 23.7, Max = 25.6. This variable is the computed using the sum of the ACT english, math, reading and science scores. The distribution is similar to those as well.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %%
def subplot_histograms_all(dataframe, list_of_columns, list_of_titles):
    nrows = int(np.ceil(len(list_of_columns)/5)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=5,figsize=(30,30)) 
    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    ax = ax.ravel()
    for i, column in enumerate(list_of_columns): 
        ax[i].hist(dataframe[column])
        ax[i].set_title(list_of_titles[i])

finalToPlot = final.iloc[:,:20]
subplot_histograms_all(finalToPlot, finalToPlot.columns, finalToPlot.columns)

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: No, the distributions are non-normal. This suggests that estimates made from mean, median, standard deviation, etc. might not be representative of the data itself.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# Since the data is non-normal, it does not make much sense to conduct statistical inference. The aggregation of data, such as computing the mean and standard deviation of the distribution, might not give valuable insights to the data, since most of the data might not lie at, or close to the mean.
#
# Aggregation of values would also be biased due to the differences in population size for each state. For example, when calculating the mean of a particular variable e.g. 'sat_participation_2017' or 'act_participation_2017', we use the formula **sum(all rows)/numOfStates** for that particular column. However, this does not take into account the fact that some states have much larger in population than others, which means that the mean of the states' 'sat_participation_2017' or 'act_participation_2017' is likely not the same as the actual population mean.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: It is not appropriate to compare them directly, since the SAT (1-800) and ACT (1-36) math scores are on different scales. To compare directly, the scores should be normalised first.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Answer:
#
# In 2018, the SAT overtook the ACT to reclaim its long-held position as the most widely used college admission test in the US. Based on research, the following reasons have been identified for the switch from the ACT to the SAT, as the College Board, which owns the SAT, pushed to expand its market share:
#
# 1. **Revision of SAT in 2016** to remove "tricky vocabulary" as well as the "guessing penalty", a feature that deducted points for wrong answers.This made the SAT "more straightforward and approachable", as compared to the older version that was seen "narrowly as a test for advanced kids."
#
#
# 2. **Entering contracts with numerous states and school systems** (e.g. Colorado, Illinois) for provision of the exam. For example, after years as an ACT state, in 2017, Illinois began providing the SAT tests for free to all juniors in public high schools. This largely increased the SAT participation rates, from 9% in 2017 to 99% in 2018. On the other hand, the ACT participation rates decreased from 93% in 2017 to 43% in 2018. Illinois reported a "testing contract with the College Board that will cost $59.8 million over six years". Similarly, SAT usage also spiked in Colorado because of a contract with the College Board. The SAT participation rates increased from 11% to 100%, while the ACT participation rates dropped from 100% to 30%.
#
#     a) The assessment landscape remains fluid because when contract expire, states regularly asks for bids, and business can switch.
#
#     b) Currently, what tests students took largely depended on where they lived - the SAT is strongest on the coasts and the ACT in the Midwest and South. In 2017, 16 states give the ACT free to students state-wide and another 4 fund ACT test-taking on a district-optional basis. In Winsconsin, the state's official high school test is now the ACT (100% participation rate), to motivate students because the results can go on their college applications.
#
#
# 3. **Delivery of SAT on school days**, a programme which allows students to take the SAT in their own schools on a weekday, instead of taking it on a Saturday in another school.
#
#
# **References**
#
# Adams, C. (2017, May 24). *In Race for Test-Takers, ACT Outscores SAT-for Now*. Retrieved from http://www.edweek.org/ew/articles/2017/05/24/in-race-for-test-takers-act-outscores-sat--for.html
#
# Anderson, N. (2018, Oct 24). *SAT reclaims title of most widely used college admission test*. Retrieved from https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answer:
#
# **Observation from data:**
# 1. The state of California was chosen since it has relatively lower participation rates in both SAT and ACT (<70%), which suggests that the state has not yet been "monopolised" by either the SAT or ACT, so there is potential for the College Board to expand its presence and significantly improve participation rates. California was also chosen because it has the largest population, hence effecting recommendations to target the state could impact a greater number of students, and even a small increase in participation rate would have great impact on increasing the overall country's SAT participation rate.
# 2. There is a strong negative correlation between overall improvements in the SAT participation rates and improvements in the ACT participation rates. This suggests that, in order to increase SAT participation rates, it is necessary to reduce ACT participation rates, by incentivising students to make the switch from ACT to SAT.
# 3. There is negligible correlation between improvements in SAT participation rates and the 2017 SAT/ACT total scores. This suggests that students in each state likely did not switch from ACT to SAT due to low ACT scores, or high SAT scores in the previous year.
#
# **Recommendations:**
# 1. Sign contract with the state, or schools in California to provide the SAT for free to students (just like in Illinois and Colorado).
#
# **Additional data to better inform investigations:**
# 1. Efforts in College Board's marketing in each state, to promote the use of SAT over ACT.
# 2. Types of schools that students who take SAT or ACT apply to.
# 3. Percentage of students eligible for fee waivers.
