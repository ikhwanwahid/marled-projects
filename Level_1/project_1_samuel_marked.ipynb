# %% [markdown]
# <div style="border: 1px solid thistle; padding: 5px 20px 10px 20px;">
#     <h2><font color = "77658f" style=";">Feedback</font></h2><br>
#     <font color = "77658f">Good practice of using relative path variables. Plots can be much better improved (i.e. scatter plots and box plots). Good algorithm thought process. No citations for the report.<br><br>
#         • Project Organisation: <b>Meet Requirement</b> <br>
#         • Python Syntax and Control Flow: <b>Meet Requirement</b><br>
#         • Data Cleaning and EDA: <b>Meet Requirement</b><br>
#         • Visualisations: <b>Meet Minimum Requirement</b><br>
#         • Research and Conceptual Understanding: <b>Meet Requirement</b><br>
#     </font>
# </div>

# %% [markdown]
# # Analysis on SAT and ACT scores
#
# ### Problem Statement
#
#
# #### The new format for the SAT was released in March 2016. As an employee of the College Board - the organization that administers the SAT - we will like to recommend where money is best spent to improve SAT participation rates. Using the provided data and outside research to make recommendations about how the College Board might work to increase the participation rate in a **state of your choice**.

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ## [Contents:](#Contents:)
# [2017 Data Import and Cleaning](#2017-Data-Import-and-Cleaning) |
# [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning) |
# [Exploratory Data Analysis](#Exploratory-Data-Analysis) |
# [Data Visualization](#Data-Visualization) |
# [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics) |
# [Outside Research](#Outside-Research) |
# [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## [2017 Data Import and Cleaning](#Data-Import-and-Cleaning)
# [Content Page](#Contents:)

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code for sat_2017:
pd_sat2017 = pd.read_csv('../data/sat_2017.csv')
#Code for act_2017:
pd_act2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code for first 10 rows of sat2017:
pd_sat2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#Code for first 10 rows of act2017:
pd_act2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# ## SAT
# State - represent US 51 States by name
#
# Participation - participation rate of students taking SAT
#
# Evidence-Based Reading and Writing, Math - score for individul test subject taken
#
# Total - Combine score of Evidence-Based Reading and Writing & Math
#
# ## ACT
# State - represent US 51 States by name and "National" in ACT Dataset means the national standard for that particular column
#
# Participation - participation rate of students taking ACT
#
# English, Math, Reading, Science - score for individul test subject taken
#
# Composite - average(mean) score of the test subjects taken

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: We lack information pertaining to how many percent of students from each state scored above or below their state's average score.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# ## SAT
#
# There is no minimum possible value for each test. However, the current Evidence-Based Reading and Writing benchmark score is 480, and the current Math benchmark score is 530. The benchmarks aim to predict a 75% likelihood of achieving at least a C in a college level course. The College Board specifically warns that benchmarks are not good indicators of appropriate academic tracks so, even if one do not meet the benchmarks, he/she should not be discouraged from applying to college or participating in challenging courses.
#
# The maximum possible value for SAT is out of a total of 1600 and this score is a combination of a Math score up to 800 points and an Evidence-Based Reading and Writing score up to 800 points.
#
# ## ACT
#
# Each ACT subject and the overall composite score are scored between 1 and 36.

# %%
#Maryland - Science 2.3 however source's data is 23.2
pd_act2017.sort_values(['Science']).head()
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 21        Maryland           28%     23.3  23.1     24.2      2.3      23.6
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1

# %%
#Maryland - Math 52 however source's data is 524
pd_sat2017.sort_values(['Math']).head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           69%                                 536
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005

# %%
#Wyoming - Composite 20.2x however source's data is 20.2
pd_act2017.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code to fix the error in dataframe
pd_act2017.loc[21,'Science'] = 23.2
pd_sat2017.loc[20, 'Math'] = 524

# %%
pd_act2017.loc[21]
# Out:
# State            Maryland
# Participation         28%
# English              23.3
# Math                 23.1
# Reading              24.2
# Science              23.2
# Composite            23.6
# Name: 21, dtype: object

# %%
pd_sat2017.loc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code to display the data types
pd_act2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
#code to display the data types
pd_sat2017.dtypes

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# #### Answer: Convert ['Participation'] to integer data type and ['Composite'] to float type

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code to convert participation to numeric type
def toNumeric (val):
    val = val.rstrip('%')
    return int(val)
    #val['Participation'] = val['Participation'].str[:-1].astype(np.int64)
    #val['Participation'] = val['Participation'].str.rstrip('%').astype(np.int64)
    #return val

# %%
def toFloat (val):
    return float(val)

# %% [markdown]
# <font size = 3 color = red>Abit redundant to define a function that is already predefined in Python float() in most other cases. In this assignment you will need it when you apply the map function.</font>

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
pd_act2017.loc[51,'Composite'] = 20.2

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
pd_act2017['Participation'] = pd_act2017['Participation'].apply(toNumeric)
pd_sat2017['Participation'] = pd_sat2017['Participation'].apply(toNumeric)
#code   
#toNumeric (pd_act2017)
#toNumeric (pd_sat2017)

# %%
pd_act2017['Composite'] = pd_act2017['Composite'].apply(toFloat)
#toFloat (pd_act2017)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
pd_act2017.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
pd_sat2017.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code to rename columns
pd_act2017.columns = ['state', 'participation_act', 'eng_act', 'math_act', 'read_act', 'sci_act',
       'composite_act']
pd_act2017.head()
# Out:
#       state  participation_act  eng_act  math_act  read_act  sci_act  \
# 0  National                 60     20.3      20.7      21.4     21.0
# 1   Alabama                100     18.9      18.4      19.7     19.4
# 2    Alaska                 65     18.7      19.8      20.4     19.9
# 3   Arizona                 62     18.6      19.8      20.1     19.8
# 4  Arkansas                100     18.9      19.0      19.7     19.5
#
#    composite_act
# 0           21.0
# 1           19.2
# 2           19.8
# 3           19.7
# 4           19.4

# %%
#code to rename columns
pd_sat2017.columns = ['state', 'participation_sat', 'evidence_based_read_write', 'math_sat',
       'total']
pd_sat2017.head()
# Out:
#         state  participation_sat  evidence_based_read_write  math_sat  total
# 0     Alabama                  5                        593       572   1165
# 1      Alaska                 38                        547       533   1080
# 2     Arizona                 30                        563       553   1116
# 3    Arkansas                  3                        614       594   1208
# 4  California                 53                        531       524   1055

# %% [markdown]
# <font size = 3 color = red>You have to write a function that rename all column names at once i.e. 'no repeated singular name changes'.<br>You should try a function that loops through all column names and replace " " with "_"</font>

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|Represent US 51 States by name|
# |participation_act|int|ACT|Participation rate of students taking ACT|
# |eng_act, math_act, read_act, sci_act|float|ACT|Score for individul test subject taken|
# |composite_act|float|ACT|Average(mean) score of the test subjects taken|
# |participation_sat|int|SAT|Participation rate of students taking SAT|
# |evidence_based_read_write, math_sat|float|SAT|Score for individul test subject taken|
# |total|int|SAT|Combine score of Evidence-Based Reading and Writing & Math|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
#pd_act2017.drop(pd_act2017.index[0],inplace=True)
pd_act2017 = pd_act2017[pd_act2017.state != 'National']
pd_act2017.head()
# Out:
#         state  participation_act  eng_act  math_act  read_act  sci_act  \
# 1     Alabama                100     18.9      18.4      19.7     19.4
# 2      Alaska                 65     18.7      19.8      20.4     19.9
# 3     Arizona                 62     18.6      19.8      20.1     19.8
# 4    Arkansas                100     18.9      19.0      19.7     19.5
# 5  California                 31     22.5      22.7      23.1     22.2
#
#    composite_act
# 1           19.2
# 2           19.8
# 3           19.7
# 4           19.4
# 5           22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code for merging 2017 ACT and SAT dataframes
pd_merge_2017 = pd.merge(left = pd_act2017, right = pd_sat2017, on='state')
pd_merge_2017.head()
# Out:
#         state  participation_act  eng_act  math_act  read_act  sci_act  \
# 0     Alabama                100     18.9      18.4      19.7     19.4
# 1      Alaska                 65     18.7      19.8      20.4     19.9
# 2     Arizona                 62     18.6      19.8      20.1     19.8
# 3    Arkansas                100     18.9      19.0      19.7     19.5
# 4  California                 31     22.5      22.7      23.1     22.2
#
#    composite_act  participation_sat  evidence_based_read_write  math_sat  \
# 0           19.2                  5                        593       572
# 1           19.8                 38                        547       533
# 2           19.7                 30                        563       553
# 3           19.4                  3                        614       594
# 4           22.8                 53                        531       524
#
#    total
# 0   1165
# 1   1080
# 2   1116
# 3   1208
# 4   1055

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
pd_merge_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# [Content Page](#Contents:)

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#Code for sat_2018:
pd_sat2018 = pd.read_csv('../data/sat_2018.csv')
#Code for act_2018:
pd_act2018 = pd.read_csv('../data/act_2018_updated.csv')

# %%
pd_sat2018['Participation'] = pd_sat2018['Participation'].apply(toNumeric)    #code to convert participation to numeric type
pd_sat2018.columns = ['state','participation_sat','evidence_based_read_write','math_sat',
                      'total']                 #code to rename columns
pd_sat2018.head()
# Out:
#         state  participation_sat  evidence_based_read_write  math_sat  total
# 0     Alabama                  6                        595       571   1166
# 1      Alaska                 43                        562       544   1106
# 2     Arizona                 29                        577       572   1149
# 3    Arkansas                  5                        592       576   1169
# 4  California                 60                        540       536   1076

# %%
pd_sat2018.dtypes        #checking dtypes of sat2018 dataframe
# Out:
# state                        object
# participation_sat             int64
# evidence_based_read_write     int64
# math_sat                      int64
# total                         int64
# dtype: object

# %%
#code to rename columns
pd_act2018.columns = ['state','participation_act','composite_act','eng_act','math_act',
                      'read_act','sci_act',]
pd_act2018.head()
# Out:
#         state  participation_act  composite_act  eng_act  math_act  read_act  \
# 0     Alabama                100           19.1     18.9      18.3      19.6
# 1      Alaska                 33           20.8     19.8      20.6      21.6
# 2     Arizona                 66           19.2     18.2      19.4      19.5
# 3    Arkansas                100           19.4     19.1      18.9      19.7
# 4  California                 27           22.7     22.5      22.5      23.0
#
#    sci_act
# 0     19.0
# 1     20.7
# 2     19.2
# 3     19.4
# 4     22.1

# %%
pd_act2018.dtypes            #checking dtypes of act2018 dataframe
# Out:
# state                 object
# participation_act      int64
# composite_act        float64
# eng_act              float64
# math_act             float64
# read_act             float64
# sci_act              float64
# dtype: object

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#Code for merging 2018 ACT and SAT dataframes
pd_merge_2018 = pd.merge(left = pd_act2018, right = pd_sat2018, on='state')
pd_merge_2018.head()
# Out:
#         state  participation_act  composite_act  eng_act  math_act  read_act  \
# 0     Alabama                100           19.1     18.9      18.3      19.6
# 1      Alaska                 33           20.8     19.8      20.6      21.6
# 2     Arizona                 66           19.2     18.2      19.4      19.5
# 3    Arkansas                100           19.4     19.1      18.9      19.7
# 4  California                 27           22.7     22.5      22.5      23.0
#
#    sci_act  participation_sat  evidence_based_read_write  math_sat  total
# 0     19.0                  6                        595       571   1166
# 1     20.7                 43                        562       544   1106
# 2     19.2                 29                        577       572   1149
# 3     19.4                  5                        592       576   1169
# 4     22.1                 60                        540       536   1076

# %%
#Code for combining 2017 and 2018 dataframes
pd_final = pd.merge(left = pd_merge_2017, right = pd_merge_2018, on='state')

# %%
pd_final.columns = ['state', 'participation_act_17', 'eng_act_17', 'math_act_17', 'read_act_17',
       'sci_act_17', 'composite_act_17', 'participation_sat_17',
       'evidence_based_read_write_17', 'math_sat_17', 'total_17',
       'participation_act_18', 'composite_act_18', 'eng_act_18', 'math_act_18',
       'read_act_18', 'sci_act_18', 'participation_sat_18',
       'evidence_based_read_write_18', 'math_sat_18', 'total_18']
pd_final.head()
# Out:
#         state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 0     Alabama                   100        18.9         18.4         19.7
# 1      Alaska                    65        18.7         19.8         20.4
# 2     Arizona                    62        18.6         19.8         20.1
# 3    Arkansas                   100        18.9         19.0         19.7
# 4  California                    31        22.5         22.7         23.1
#
#    sci_act_17  composite_act_17  participation_sat_17  \
# 0        19.4              19.2                     5
# 1        19.9              19.8                    38
# 2        19.8              19.7                    30
# 3        19.5              19.4                     3
# 4        22.2              22.8                    53
#
#    evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 0                           593          572  ...                   100
# ...

# %%
#code
pd_final.to_csv('../data/final.csv')

# %% [markdown]
# ## [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# [Content Page](#Contents:)
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
pd_final.describe()
# Out:
#        participation_act_17  eng_act_17  math_act_17  read_act_17  sci_act_17  \
# count             51.000000   51.000000    51.000000    51.000000   51.000000
# mean              65.254902   20.931373    21.182353    22.013725   21.450980
# std               32.140842    2.353677     1.981989     2.067271    1.739353
# min                8.000000   16.300000    18.000000    18.100000   18.200000
# 25%               31.000000   19.000000    19.400000    20.450000   19.950000
# 50%               69.000000   20.700000    20.900000    21.800000   21.300000
# 75%              100.000000   23.300000    23.100000    24.150000   23.200000
# max              100.000000   25.500000    25.300000    26.000000   24.900000
#
#        composite_act_17  participation_sat_17  evidence_based_read_write_17  \
# count         51.000000             51.000000                     51.000000
# mean          21.519608             39.803922                    569.117647
# ...

# %% [markdown]
# <font size = 3 color = red>You were supposed to **transpose** the `.describe()` output.</font>

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def calc_sd(data):
    mean = np.mean(data)
    data_mean = []
    for x in data:
        data_mean.append((data-mean)**2)
    for y in data_mean:    
        sd = np.sqrt(np.mean(data_mean))
        return sd

# %% [raw]
# #Another function for standard deviation
# def calc_sd(data):
#     mean = np.mean(data)
#     for x in data:
#         sd = np.sqrt(np.mean((x-mean)**2))
#         return sd

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final_dict = {}

for i in pd_final.columns:
    if pd_final.dtypes[i]=='int64' or pd_final.dtypes[i]=='float64':
        sd = round(calc_sd(pd_final[i]),6)
        final_dict[i] = sd
        
final_dict
# Out:
# {'participation_act_17': 31.824176,
#  'eng_act_17': 2.330488,
#  'math_act_17': 1.962462,
#  'read_act_17': 2.046903,
#  'sci_act_17': 1.722216,
#  'composite_act_17': 2.000786,
#  'participation_sat_17': 34.929071,
#  'evidence_based_read_write_17': 45.21697,
#  'math_sat_17': 46.657134,
#  'total_17': 91.583511,
#  'participation_act_18': 33.745195,
#  'composite_act_18': 2.096822,
#  'eng_act_18': 2.422254,
#  'math_act_18': 2.015707,
#  'read_act_18': 2.145892,
#  'sci_act_18': 1.851689,
#  'participation_sat_18': 37.639654,
#  'evidence_based_read_write_18': 44.871186,
#  'math_sat_18': 48.405899,
#  'total_18': 92.943725}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
print (str(calc_sd(pd_final['total_18'])) + ' - Manual count')
print (str(pd_final['total_18'].std()) + ' - pandas describe()')
print (str(np.std(pd_final['total_18'])) + ' - numpy\'s std')
# Out:
# 92.94372462792965 - Manual count
# 93.86856058695408 - pandas describe()
# 92.94372462792965 - numpy's std

# %% [markdown]
# Answer: No, it does not match up with pandas describe output. However it matches with numpy std method

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?

# %% [markdown]
# > <font size = 3 color = red>Please drop the unnecessary columns and show only the relevant columns e.g. Participation rate 2017, Highest Composite Score 2017 to improve the report presentation.</font>

# %%
#Code:
#lowest participate rate 2017 SAT - Iowa, Mississippi, North Dakota(2)
pd_final.sort_values(['participation_sat_17', 'state'],ascending=[True,True]).head(5)
# Out:
#            state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 15          Iowa                    67        21.2         21.3         22.6
# 24   Mississippi                   100        18.2         18.1         18.8
# 34  North Dakota                    98        19.0         20.4         20.5
# 3       Arkansas                   100        18.9         19.0         19.7
# 23     Minnesota                   100        20.4         21.5         21.8
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 15        22.1              21.9                     2
# 24        18.8              18.6                     2
# 34        20.6              20.3                     2
# 3         19.5              19.4                     3
# 23        21.6              21.5                     3
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 15                           641          635  ...                    68
# ...

# %%
#highest participate rate 2017 SAT - Connecticut, Delaware, District of Columbia, Michigan(100)
pd_final.sort_values(['participation_sat_17', 'state'],ascending=[False,True]).head(5)
# Out:
#                    state  participation_act_17  eng_act_17  math_act_17  \
# 6            Connecticut                    31        25.5         24.6
# 7               Delaware                    18        24.1         23.4
# 8   District of Columbia                    32        24.4         23.5
# 22              Michigan                    29        24.1         23.7
# 29         New Hampshire                    18        25.4         25.1
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 6          25.6        24.6              25.2                   100
# 7          24.8        23.6              24.1                   100
# 8          24.9        23.5              24.2                   100
# 22         24.5        23.8              24.1                   100
# 29         26.0        24.9              25.5                    96
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# ...

# %%
#lowest participate rate 2018 SAT - North Dakota(2), Iowa, Mississippi, Nebraska, South Dakota, Wisconsin, Wyoming(3)
pd_final.sort_values(['participation_sat_18', 'state'],ascending=[True,True]).head(10)
# Out:
#            state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 34  North Dakota                    98        19.0         20.4         20.5
# 15          Iowa                    67        21.2         21.3         22.6
# 24   Mississippi                   100        18.2         18.1         18.8
# 27      Nebraska                    84        20.9         20.9         21.9
# 41  South Dakota                    80        20.7         21.5         22.3
# 49     Wisconsin                   100        19.7         20.4         20.6
# 50       Wyoming                   100        19.4         19.8         20.8
# 16        Kansas                    73        21.1         21.3         22.3
# 17      Kentucky                   100        19.6         19.4         20.5
# 18     Louisiana                   100        19.4         18.8         19.8
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 34        20.6              20.3                     2
# ...

# %%
#highest participate rate 2018 SAT - Colorado, Connecticut, Delaware, Idaho, Michigan(100)
pd_final.sort_values(['participation_sat_18', 'state'],ascending=[False,True]).head(5)
# Out:
#           state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 5      Colorado                   100        20.1         20.3         21.2
# 6   Connecticut                    31        25.5         24.6         25.6
# 7      Delaware                    18        24.1         23.4         24.8
# 12        Idaho                    38        21.9         21.8         23.0
# 22     Michigan                    29        24.1         23.7         24.5
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 5         20.9              20.8                    11
# 6         24.6              25.2                   100
# 7         23.6              24.1                   100
# 12        22.1              22.3                    93
# 22        23.8              24.1                   100
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 5                            606          595  ...                    30
# ...

# %%
#lowest participate rate 2017 ACT - Maine(8), Delaware, New Hampshire(18)
pd_final.sort_values(['participation_act_17','state'],ascending=[True,True]).head(5)
# Out:
#             state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 19          Maine                     8        24.2         24.0         24.8
# 7        Delaware                    18        24.1         23.4         24.8
# 29  New Hampshire                    18        25.4         25.1         26.0
# 39   Rhode Island                    21        24.0         23.3         24.7
# 38   Pennsylvania                    23        23.4         23.4         24.2
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 19        23.7              24.3                    95
# 7         23.6              24.1                   100
# 29        24.9              25.5                    96
# 39        23.4              24.0                    71
# 38        23.3              23.7                    65
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 19                           513          499  ...                     7
# ...

# %%
#highest participate rate 2017 ACT - 17 states with 100% rate
pd_final.sort_values(['participation_act_17','state'],ascending=[False,True]).head(20)
# Out:
#              state  participation_act_17  eng_act_17  math_act_17  \
# 0          Alabama                   100        18.9         18.4
# 3         Arkansas                   100        18.9         19.0
# 5         Colorado                   100        20.1         20.3
# 17        Kentucky                   100        19.6         19.4
# 18       Louisiana                   100        19.4         18.8
# 23       Minnesota                   100        20.4         21.5
# 24     Mississippi                   100        18.2         18.1
# 25        Missouri                   100        19.8         19.9
# 26         Montana                   100        19.0         20.2
# 28          Nevada                   100        16.3         18.0
# 33  North Carolina                   100        17.8         19.3
# 36        Oklahoma                   100        18.5         18.8
# 40  South Carolina                   100        17.5         18.6
# ...

# %%
#lowest participate rate 2018 ACT - Maine(7), Rhode Island(15), New Hampshire(16), Delaware(17)
pd_final.sort_values(['participation_act_18','state'],ascending=[True,True]).head(5)
# Out:
#             state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 19          Maine                     8        24.2         24.0         24.8
# 39   Rhode Island                    21        24.0         23.3         24.7
# 29  New Hampshire                    18        25.4         25.1         26.0
# 7        Delaware                    18        24.1         23.4         24.8
# 38   Pennsylvania                    23        23.4         23.4         24.2
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 19        23.7              24.3                    95
# 39        23.4              24.0                    71
# 29        24.9              25.5                    96
# 7         23.6              24.1                   100
# 38        23.3              23.7                    65
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 19                           513          499  ...                     7
# ...

# %%
#highest participate rate 2018 ACT - 17 states with 100% rate
pd_final.sort_values(['participation_act_18','state'],ascending=[False,True]).head(20)
# Out:
#              state  participation_act_17  eng_act_17  math_act_17  \
# 0          Alabama                   100        18.9         18.4
# 3         Arkansas                   100        18.9         19.0
# 17        Kentucky                   100        19.6         19.4
# 18       Louisiana                   100        19.4         18.8
# 24     Mississippi                   100        18.2         18.1
# 25        Missouri                   100        19.8         19.9
# 26         Montana                   100        19.0         20.2
# 27        Nebraska                    84        20.9         20.9
# 28          Nevada                   100        16.3         18.0
# 33  North Carolina                   100        17.8         19.3
# 35            Ohio                    75        21.2         21.6
# 36        Oklahoma                   100        18.5         18.8
# 40  South Carolina                   100        17.5         18.6
# ...

# %% [markdown]
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?

# %%
#highest mean total scores in 2017 SAT - Minnesota, Wisconsin, Iowa, Missouri, Kansas
pd_final.sort_values(['total_17', 'state'],ascending=[False,True]).head(5)
# Out:
#         state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 23  Minnesota                   100        20.4         21.5         21.8
# 49  Wisconsin                   100        19.7         20.4         20.6
# 15       Iowa                    67        21.2         21.3         22.6
# 25   Missouri                   100        19.8         19.9         20.8
# 16     Kansas                    73        21.1         21.3         22.3
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 23        21.6              21.5                     3
# 49        20.9              20.5                     3
# 15        22.1              21.9                     2
# 25        20.5              20.4                     3
# 16        21.7              21.7                     4
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 23                           644          651  ...                    99
# ...

# %%
#lowest mean total scores in 2017 SAT - District of Columbia, Delaware, Idaho, Michigan, Maine
pd_final.sort_values(['total_17', 'state'],ascending=[True,True]).head(5)
# Out:
#                    state  participation_act_17  eng_act_17  math_act_17  \
# 8   District of Columbia                    32        24.4         23.5
# 7               Delaware                    18        24.1         23.4
# 12                 Idaho                    38        21.9         21.8
# 22              Michigan                    29        24.1         23.7
# 19                 Maine                     8        24.2         24.0
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 8          24.9        23.5              24.2                   100
# 7          24.8        23.6              24.1                   100
# 12         23.0        22.1              22.3                    93
# 22         24.5        23.8              24.1                   100
# 19         24.8        23.7              24.3                    95
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# ...

# %%
#highest mean total scores in 2018 SAT - Minnesota, Wisconsin, North Dakota, Iowa, Kansas
pd_final.sort_values(['total_18', 'state'],ascending=[False,True]).head(5)
# Out:
#            state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 23     Minnesota                   100        20.4         21.5         21.8
# 49     Wisconsin                   100        19.7         20.4         20.6
# 34  North Dakota                    98        19.0         20.4         20.5
# 15          Iowa                    67        21.2         21.3         22.6
# 16        Kansas                    73        21.1         21.3         22.3
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 23        21.6              21.5                     3
# 49        20.9              20.5                     3
# 34        20.6              20.3                     2
# 15        22.1              21.9                     2
# 16        21.7              21.7                     4
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 23                           644          651  ...                    99
# ...

# %%
#lowest mean total scores in 2018 SAT - District of Columbia, Delaware, West Virginia, Idaho, Michigan
pd_final.sort_values(['total_18', 'state'],ascending=[True,True]).head(5)
# Out:
#                    state  participation_act_17  eng_act_17  math_act_17  \
# 8   District of Columbia                    32        24.4         23.5
# 7               Delaware                    18        24.1         23.4
# 48         West Virginia                    69        20.0         19.4
# 12                 Idaho                    38        21.9         21.8
# 22              Michigan                    29        24.1         23.7
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 8          24.9        23.5              24.2                   100
# 7          24.8        23.6              24.1                   100
# 48         21.2        20.5              20.4                    14
# 12         23.0        22.1              22.3                    93
# 22         24.5        23.8              24.1                   100
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# ...

# %%
#highest mean composite scores in 2017 ACT - New Hampshire, Massachusetts, Connecticut, Maine, District of Columbia
pd_final.sort_values(['composite_act_17', 'state'],ascending=[False,True]).head(5)
# Out:
#                    state  participation_act_17  eng_act_17  math_act_17  \
# 29         New Hampshire                    18        25.4         25.1
# 21         Massachusetts                    29        25.4         25.3
# 6            Connecticut                    31        25.5         24.6
# 19                 Maine                     8        24.2         24.0
# 8   District of Columbia                    32        24.4         23.5
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 29         26.0        24.9              25.5                    96
# 21         25.9        24.7              25.4                    76
# 6          25.6        24.6              25.2                   100
# 19         24.8        23.7              24.3                    95
# 8          24.9        23.5              24.2                   100
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# ...

# %%
#lowest mean composite scores in 2017 ACT - Nevada, Mississippi, South Carolina, Hawaii, North Carolina
pd_final.sort_values(['composite_act_17', 'state'],ascending=[True,True]).head(5)
# Out:
#              state  participation_act_17  eng_act_17  math_act_17  \
# 28          Nevada                   100        16.3         18.0
# 24     Mississippi                   100        18.2         18.1
# 40  South Carolina                   100        17.5         18.6
# 11          Hawaii                    90        17.8         19.2
# 33  North Carolina                   100        17.8         19.3
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 28         18.1        18.2              17.8                    26
# 24         18.8        18.8              18.6                     2
# 40         19.1        18.9              18.7                    50
# 11         19.2        19.3              19.0                    55
# 33         19.6        19.3              19.1                    49
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 28                           563          553  ...                   100
# ...

# %%
#highest mean composite scores in 2018 ACT - Connecticut, Massachusetts, New Hampshire, New York, Michigan
pd_final.sort_values(['composite_act_18', 'state'],ascending=[False,True]).head(5)
# Out:
#             state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 6     Connecticut                    31        25.5         24.6         25.6
# 21  Massachusetts                    29        25.4         25.3         25.9
# 29  New Hampshire                    18        25.4         25.1         26.0
# 32       New York                    31        23.8         24.0         24.6
# 22       Michigan                    29        24.1         23.7         24.5
#
#     sci_act_17  composite_act_17  participation_sat_17  \
# 6         24.6              25.2                   100
# 21        24.7              25.4                    76
# 29        24.9              25.5                    96
# 32        23.9              24.2                    67
# 22        23.8              24.1                   100
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 6                            530          512  ...                    26
# ...

# %%
#lowest mean composite scores in 2018 ACT - Nevada, South Carolina, Mississippi, Hawaii, Alabama
pd_final.sort_values(['composite_act_18', 'state'],ascending=[True,True]).head(5)
# Out:
#              state  participation_act_17  eng_act_17  math_act_17  \
# 28          Nevada                   100        16.3         18.0
# 40  South Carolina                   100        17.5         18.6
# 24     Mississippi                   100        18.2         18.1
# 11          Hawaii                    90        17.8         19.2
# 0          Alabama                   100        18.9         18.4
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 28         18.1        18.2              17.8                    26
# 40         19.1        18.9              18.7                    50
# 24         18.8        18.8              18.6                     2
# 11         19.2        19.3              19.0                    55
# 0          19.7        19.4              19.2                     5
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 28                           563          553  ...                   100
# ...

# %% [markdown]
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# #### Colorado have a drastic rate change for both test.
# #### In 2017, ACT rate was 100% and SAT rate was 11%. In 2018, ACT rate was 30% and SAT rate was 100%.

# %%
pd_final[((pd_final['participation_act_17'] == 100) & (pd_final['participation_act_18'] < 100)) | ((pd_final['participation_sat_17'] == 100) & (pd_final['participation_sat_18'] < 100))]
# Out:
#                    state  participation_act_17  eng_act_17  math_act_17  \
# 5               Colorado                   100        20.1         20.3
# 8   District of Columbia                    32        24.4         23.5
# 23             Minnesota                   100        20.4         21.5
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 5          21.2        20.9              20.8                    11
# 8          24.9        23.5              24.2                   100
# 23         21.8        21.6              21.5                     3
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 5                            606          595  ...                    30
# 8                            482          468  ...                    32
# 23                           644          651  ...                    99
#
#     composite_act_18  eng_act_18  math_act_18  read_act_18  sci_act_18  \
# ...

# %% [markdown]
# - Do any states show have >50% participation on *both* tests either year?

# %%
pd_final[((pd_final['participation_act_17'] > 50) & (pd_final['participation_sat_17'] > 50)) | ((pd_final['participation_act_18'] > 50) & (pd_final['participation_sat_18'] > 50))]
# Out:
#              state  participation_act_17  eng_act_17  math_act_17  \
# 9          Florida                    73        19.0         19.4
# 10         Georgia                    55        21.0         20.9
# 11          Hawaii                    90        17.8         19.2
# 33  North Carolina                   100        17.8         19.3
# 40  South Carolina                   100        17.5         18.6
#
#     read_act_17  sci_act_17  composite_act_17  participation_sat_17  \
# 9          21.0        19.4              19.8                    83
# 10         22.0        21.3              21.4                    61
# 11         19.2        19.3              19.0                    55
# 33         19.6        19.3              19.1                    49
# 40         19.1        18.9              18.7                    50
#
#     evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 9                            520          497  ...                    66
# ...

# %% [markdown]
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
pd_final[pd_final['state'] == 'Colorado']
# Out:
#       state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 5  Colorado                   100        20.1         20.3         21.2
#
#    sci_act_17  composite_act_17  participation_sat_17  \
# 5        20.9              20.8                    11
#
#    evidence_based_read_write_17  math_sat_17  ...  participation_act_18  \
# 5                           606          595  ...                    30
#
#    composite_act_18  eng_act_18  math_act_18  read_act_18  sci_act_18  \
# 5              23.9        23.9         23.2         24.4        23.5
#
#    participation_sat_18  evidence_based_read_write_18  math_sat_18  total_18
# 5                   100                           519          506      1025
#
# [1 rows x 21 columns]

# %% [markdown]
# #### The state 'Colorado' interest me because of the drastic change in both years' test participation rate. The increase in SAT participation rate has increase from a low value of 11% in 2017 to a 100% participation rate in 2018.
#
# #### Further research online shows that there were 25 percent increase in SAT test-takers and those can be attributed to the growth of SAT School Day. It is a program which students take the SAT in their own school on a weekday, rather than taking it on a Saturday in a different school than the one they attend.
#
# #### Also, in 2018, the state 'Colorado' covered the cost of the SAT for all their public school students. Three years ago, only three states and the District of Columbia did so.

# %% [markdown]
# ## [Data Visualization](#Data-Visualization)
# [Content Page](#Contents:)
#
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(14,10))
sns.heatmap(pd_final.corr(), annot=True)
plt.title('Correlation between Columns\n', size = 18)
# Out:
# Text(0.5, 1, 'Correlation between Columns\n')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(16,14)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings        
        ax[i].set_title(list_of_titles[i]) # Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[i])
    return ax

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Participation rates for SAT & ACT
lst_columns = ['participation_act_17', 'participation_sat_17', 'participation_act_18', 'participation_sat_18']
lst_title = ['ACT 2017','SAT 2017', 'ACT 2018', 'SAT 2018']
xlabel = ['Participation, ACT', 'Participation, SAT', 'Participation, ACT', 'Participation, SAT']
subplot_histograms(pd_final, lst_columns, lst_title, xlabel);

# %%
# Math scores for SAT & ACT
lst_columns = ['math_act_17', 'math_sat_17', 'math_act_18', 'math_sat_18']
lst_title = ['ACT 2017','SAT 2017', 'ACT 2018', 'SAT 2018']
xlabel = ['Maths, ACT', 'Maths, SAT', 'Maths, ACT', 'Maths, SAT']
subplot_histograms(pd_final, lst_columns, lst_title, xlabel);

# %%
# Reading/verbal scores for SAT & ACT
lst_columns = ['read_act_17', 'evidence_based_read_write_17', 'read_act_18', 'evidence_based_read_write_18']
lst_title = ['ACT 2017','SAT 2017', 'ACT 2018', 'SAT 2018']
xlabel = ['Reading, ACT', 'Evidence-Based Reading and Writing, SAT', 'Reading, ACT', 'Evidence-Based Reading and Writing, SAT']
subplot_histograms(pd_final, lst_columns, lst_title, xlabel);

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# > <font size = 3 color = red>Your custom subplot_scatter function creates a plot that links all the points with a line. This produces a very messy scatter plot. You may just want to use sns.scatterplot or plt.scatter</font>

# %%
# Code
def subplot_scatter(dataframe, x_value, y_value, title, xlabel, ylabel, color):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.plot(dataframe[x_value], dataframe[y_value], marker='o', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    return ax

# %%
lst_title = ['SAT vs ACT Math 2017', 'SAT vs ACT Reading 2017', 'SAT vs ACT total/composite scores for 2017',
             'Total scores for SAT 2017 vs 2018','Composite scores for ACT 2017 vs 2018']
lst_xlabel = ['SAT Math', 'SAT Evidence-Based Reading and Writing', 'SAT Total Score', 'SAT 2017', 'ACT 2017']
lst_ylabel = ['ACT Math', 'ACT Reading', 'ACT Composite Score', 'SAT 2018', 'ACT 2018']
x_value = ['math_sat_17', 'evidence_based_read_write_17', 'total_17', 'total_17', 'composite_act_17']
y_value = ['math_act_17', 'read_act_17', 'composite_act_17', 'total_18', 'composite_act_18']
color = ['blue', 'red', 'purple', 'green', 'black']

# %%
#SAT vs. ACT math scores for 2017
subplot_scatter(pd_final, x_value[0], y_value[0], lst_title[0], lst_xlabel[0], lst_ylabel[0], color[0])

# %%
#SAT vs. ACT verbal/reading scores for 2017
subplot_scatter(pd_final, x_value[1], y_value[1], lst_title[1], lst_xlabel[1], lst_ylabel[1], color[1])

# %%
#SAT vs. ACT total/composite scores for 2017
subplot_scatter(pd_final, x_value[2], y_value[2], lst_title[2], lst_xlabel[2], lst_ylabel[2], color[2])

# %%
#Total scores for SAT 2017 vs. 2018
subplot_scatter(pd_final, x_value[3], y_value[3], lst_title[3], lst_xlabel[3], lst_ylabel[3], color[3])

# %%
#Composite scores for ACT 2017 vs. 2018
subplot_scatter(pd_final, x_value[4], y_value[4], lst_title[4], lst_xlabel[4], lst_ylabel[4], color[4])

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# > <font size = 3 color = red>All your boxplots have vastly different axis scale. This gives a very inaccurate representation of the spread of data!! You should fix all boxplots onto the same y axis scale!</font>

# %%
# Code
fig,ax = plt.subplots(1, 11, figsize=(24, 8))
for i,name in enumerate(pd_merge_2017.columns):
    if pd_merge_2017.dtypes[i]=='int64' or pd_merge_2017.dtypes[i]=='float64':
        sns.boxplot(data=pd_merge_2017[name],ax=ax[i])
        
plt.show()

# %%
fig,ax = plt.subplots(1, 11, figsize=(24, 8))
for i,name in enumerate(pd_merge_2018.columns):
    if pd_merge_2018.dtypes[i]=='int64' or pd_merge_2018.dtypes[i]=='float64':
        sns.boxplot(data=pd_merge_2018[name],ax=ax[i])

plt.show()

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#SAT vs. ACT total/composite scores for 2018
subplot_scatter(pd_final, 'total_18', 'composite_act_18', 'SAT vs ACT total/composite scores for 2018', 'SAT Total Score',
                'ACT Composite Score', 'gold');
plt.show()

#SAT participation rate vs. ACT composite score 2018
subplot_scatter(pd_final, 'participation_sat_18', 'composite_act_18', 'SAT Participation Rate vs ACT Composite Score 2018', 'SAT Participation',
                'ACT Composite Score', 'black');
plt.show()

#ACT participation rate vs. SAT total score 2017
subplot_scatter(pd_final, 'participation_act_17', 'total_17', 'ACT participation rate vs. SAT total score 2017', 'ACT Participation',
                'SAT Total Score', 'gold');
plt.show()

# %%
#Cross referencing participation rate and composite score over the 2 years
sns.pairplot(data = pd_final[['participation_act_17','participation_act_18','composite_act_17','composite_act_18']]);

# %%
#Cross referencing participation rate and total score over the 2 years
sns.pairplot(data = pd_final[['participation_sat_17','participation_sat_18','total_17','total_18',]], markers = 'v');

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# [Content Page](#Contents:)

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
# #### Positive correlation between all the subjects' mean score and total/composite score of the same test
# #### Positive correlation between participation rate of SAT and the scores of ACT and vice versa
# #### Negative correlation between participation rate of both test
# #### Negative correlation between participation and scores of the same test

# %%
pd_merge_2017.corr()
# Out:
#                            participation_act   eng_act  math_act  read_act  \
# participation_act                   1.000000 -0.843501 -0.861114 -0.866620
# eng_act                            -0.843501  1.000000  0.967803  0.985999
# math_act                           -0.861114  0.967803  1.000000  0.979630
# read_act                           -0.866620  0.985999  0.979630  1.000000
# sci_act                            -0.836595  0.980042  0.986929  0.988034
# composite_act                      -0.858134  0.990856  0.990451  0.995069
# participation_sat                  -0.841234  0.686889  0.710697  0.705352
# evidence_based_read_write           0.716153 -0.461345 -0.486126 -0.488441
# math_sat                            0.682572 -0.420673 -0.420456 -0.442410
# total                               0.701477 -0.441947 -0.454116 -0.466558
#
#                             sci_act  composite_act  participation_sat  \
# participation_act         -0.836595      -0.858134          -0.841234
# ...

# %%
pd_merge_2018.corr()
# Out:
#                            participation_act  composite_act   eng_act  \
# participation_act                   1.000000      -0.860832 -0.850362
# composite_act                      -0.860832       1.000000  0.991615
# eng_act                            -0.850362       0.991615  1.000000
# math_act                           -0.856963       0.991032  0.972551
# read_act                           -0.869304       0.993831  0.983390
# sci_act                            -0.843234       0.995247  0.979142
# participation_sat                  -0.851195       0.731748  0.740756
# evidence_based_read_write           0.714229      -0.483985 -0.493910
# math_sat                            0.659689      -0.408907 -0.428700
# total                               0.688062      -0.446447 -0.461626
#
#                            math_act  read_act   sci_act  participation_sat  \
# participation_act         -0.856963 -0.869304 -0.843234          -0.851195
# ...

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %%
import scipy.stats as stats
def norm_dist(df,col):
    ct = df[col].describe()['count']
    mean = df[col].describe()['mean']
    std = df[col].describe()['std']
    skew = stats.skew(df[col])
    dis_skew = 6*(ct-1)/((ct+1)*(ct+3))
    kurtosis = stats.kurtosis(df[col])
    dis_kurtosis = 24*(ct-2)*(ct-3)*ct/((ct+3)*(ct+5)*(ct-1)**2)
    norm_dist = (np.abs(skew)<=np.sqrt(dis_skew)) and (np.abs(kurtosis)<=np.sqrt(dis_kurtosis))
    print('{} : {}normally distributed\nmean {:.2f}, std {:.2f}, skew {:.2f}\n'
          .format(col, '' if norm_dist else 'NOT ',mean,std,skew))
          
for i in pd_final.columns[1:]:
    norm_dist(pd_final,i)
# Out:
# participation_act_17 : NOT normally distributed
# mean 65.25, std 32.14, skew -0.19
#
# eng_act_17 : NOT normally distributed
# mean 20.93, std 2.35, skew 0.34
#
# math_act_17 : NOT normally distributed
# mean 21.18, std 1.98, skew 0.32
#
# read_act_17 : NOT normally distributed
# mean 22.01, std 2.07, skew 0.26
#
# sci_act_17 : NOT normally distributed
# mean 21.45, std 1.74, skew 0.21
#
# composite_act_17 : NOT normally distributed
# mean 21.52, std 2.02, skew 0.31
#
# participation_sat_17 : NOT normally distributed
# mean 39.80, std 35.28, skew 0.34
#
# evidence_based_read_write_17 : NOT normally distributed
# mean 569.12, std 45.67, skew 0.26
#
# math_sat_17 : NOT normally distributed
# mean 556.88, std 47.12, skew 0.35
#
# total_17 : NOT normally distributed
# mean 1126.10, std 92.49, skew 0.30
#
# participation_act_18 : NOT normally distributed
# mean 61.65, std 34.08, skew -0.02
#
# composite_act_18 : NOT normally distributed
# mean 21.50, std 2.12, skew 0.27
#
# ...

# %% [markdown]
# Answer: None of the columns are normally distributed.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math  (Not normally distributed)
#     - Reading  (Not normally distributed)
#     - Rates  (Not normally distributed)
#
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: This might be due to insufficient amount of data samples, if we can get more samples, the distribution might be more normally distributed.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: As mentioned above, the samples are insufficient causing the data to be not normally distributed. It will not make sense conducting inference statistical.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: We can compare SAT and ACT math scores and reading scores from the same year to determine whichever test is more difficult. We can also deduce that those states which have higher participation rate have lower scores than a state which have lower participation rate where only the top students took the test.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## [Outside Research](#Outside-Research)
# [Content Page](#Contents:)

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Colorado - Colorado have a drastic rate change for both test. In 2017, ACT rate was 100% and SAT rate was 11%. In 2018, ACT rate was 30% and SAT rate was 100%. This was due to the implementation of SAT School Day and government assistance.
#
# Oklahama - Despite Oklahoma having fee waiver for their public school students, Oklahoma state still see a low participation rate in SAT in both 2017 and 2018. From the website, I found out that Oklahoma was a non-mandatory state for SAT.
#
# District of Columbia - DC saw the largest decrease in SAT participation rates from 2017 to 2018, from 100% to 92%. In 2017, DC high school system posted a record high rate of 73 percent graduation, which was later cast into doubt amid a graduation scandal that jolted the city. In 2018, the decrease in SAT participation was made more obvious when the system faced scrutiny over whether students properly earn their diplomas.

# %% [markdown]
# ## [Conclusions and Recommendations](#Conclusions-and-Recommendations)
# [Content Page](#Contents:)

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
pd_final[(pd_final['participation_sat_17'] < 15) & (pd_final['participation_sat_18'] < 15)]
# Out:
#            state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 0        Alabama                   100        18.9         18.4         19.7
# 3       Arkansas                   100        18.9         19.0         19.7
# 15          Iowa                    67        21.2         21.3         22.6
# 16        Kansas                    73        21.1         21.3         22.3
# 17      Kentucky                   100        19.6         19.4         20.5
# 18     Louisiana                   100        19.4         18.8         19.8
# 23     Minnesota                   100        20.4         21.5         21.8
# 24   Mississippi                   100        18.2         18.1         18.8
# 25      Missouri                   100        19.8         19.9         20.8
# 26       Montana                   100        19.0         20.2         21.0
# 27      Nebraska                    84        20.9         20.9         21.9
# ...

# %% [markdown]
# In 2018, more than 2 million students took SAT as compared to 1.9million that took ACT. Among the 2 million students, an increase of 25% in the students were due to the SAT school day program. Referencing from the website, "The 25 percent increase in SAT test-takers can be attributed to the growth of SAT School Day, a program in which students take the SAT in their own school on a weekday, rather than taking it on a Saturday in a different school than the one they attend."
#
# Further reports stating the additional support from the states, "In 2017-18, 10 states (Colorado, Connecticut, Delaware, Idaho, Illinois, Maine, Michigan, New Hampshire, Rhode Island, and West Virginia) and the District of Columbia covered the cost of the SAT for all their public school students. Three years ago, only three states and the District of Columbia did so.
#
# The College Board has been pushing hard to win contracts with entire states or districts, but last December the organization also announced that schools can negotiate contracts to administer the SAT during the school day. The New York City-based organization appears to be winning the battle with the ACT for statewide contracts. The latter lost statewide contracts in Colorado, Illinois, and West Virginia, contributing to the big drop in its student participation. The College Board is also trying to increase SAT participation through fee waivers for low-income students, and by taking steps to identify eligible students and automatically giving them the fee waiver benefits.
#
# I will like to recommend the state of Oklahoma. As the state is already in SAT School Day, College Board may negotiate with the state government to offer an statewide contracts or fee waiver benefits to eligible students. The state might also be more proned to making SAT mandatory which will also see an increase in participation rates.
