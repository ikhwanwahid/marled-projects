# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# DEADLINE to push to repo (to share this link to GA via google link): 11NOV 8.45AM
# Keep to 15-20 slides
# Copy paste data dictionary into readme (see further below on data dictionary)
#
# Aim to include in all presentations:
# 1. Business context
# 2. Business objectives
# 3. Data objectives
# 4. Evaluation
#
# From readme:
# we're going to take a look at aggregate SAT and ACT scores and participation rates from each state in the United States. We'll seek to identify trends in the data and combine our data analysis with outside research to identify likely factors influencing participation rates and scores in various states.
# > The new format for the SAT was released in March 2016. As an employee of the College Board - the organization that administers the SAT - you are a part of a team that tracks statewide participation and recommends where money is best spent to improve SAT participation rates. Your presentation and report should be geared toward **non-technical** executives with the College Board and you will use the provided data and outside research to make recommendations about how the College Board might work to increase the participation rate in a **state of your choice**.
#
#
#
# Deliverables:
# - A Jupyter notebook that describes your data with visualizations & statistical analysis.
# - A README markdown file the provides an introduction to and overview of your project.
# - Your presentation slideshow rendered as a .pdf file.
# **NOTE**: Your entire Github repository will be evaluated as your technical report. Make sure that your files and directories are named appropriately, that all necessary files are included, and that no unnecessary or incomplete files are included.
#
# For your first presentation, you'll be presenting to a **non-technical** audience. You should prepare a slideshow with appropriately scaled visuals to complement a compelling narrative. **Presentation duration will differ by market, so check with your local instructor.**
#
# Your technical report will be hosted on Github Enterprise. Make sure it includes:
#
#
#
# Submission:
# - A README.md (that isn't this file)
# - Jupyter notebook(s) with your analysis (renamed to describe your project)
# - Data files
# - Presentation slides
# - Any other necessary files (images, etc.)
#
#
#
# Presentation structure:
# - **Must be within time limit established by local instructor.**
# - Use Google Slides or some other visual aid (Keynote, Powerpoint, etc).
# - Consider the audience. Assume you are presenting to non-technical executives with the College Board (the organization that administers the SATs).
# - Start with the **data science problem**.
# - Use visuals that are appropriately scaled and interpretable.
# - Talk about your procedure/methodology (high level, **CODE IS ALWAYS INAPPROPRIATE FOR A NON-TECHNICAL AUDIENCE**).
# - Talk about your primary findings.
# - Make sure you provide **clear recommendations** that follow logically from your analyses and narrative and answer your data science problem.
#
#
#
# Rubric:
# **Scores will be out of 21 points based on the 7 items in the rubric.** <br>
# *3 points per section*<br>
#
# | Score | Interpretation |
# | --- | --- |
# | **0** | *Project fails to meet the minimum requirements for this item.* |
# | **1** | *Project meets the minimum requirements for this item, but falls significantly short of portfolio-ready expectations.* |
# | **2** | *Project exceeds the minimum requirements for this item, but falls short of portfolio-ready expectations.* |
# | **3** | *Project meets or exceeds portfolio-ready expectations; demonstrates a thorough understanding of every outlined consideration.* |
#
# **Project Organization**
# - Are modules imported correctly (using appropriate aliases)?
# - Are data imported/saved using relative paths?
# - Does the README provide a good executive summary of the project?
# - Is markdown formatting used appropriately to structure notebooks?
# - Are there an appropriate amount of comments to support the code?
# - Are files & directories organized correctly?
# - Are there unnecessary files included?
# - Do files and directories have well-structured, appropriate, consistent names?
#
# **Clarity of Message**
# - Is the problem statement clearly presented?
# - Does a strong narrative run through the project?
# - Does the student provide appropriate context to connect individual steps back to the overall project?
# - Is it clear how the final recommendations were reached?
# - Are the conclusions/recommendations clearly stated?
#
# **Python Syntax and Control Flow**
# - Is care taken to write human readable code?
# - Is the code syntactically correct (no runtime errors)?
# - Does the code generate desired results (logically correct)?
# - Does the code follows general best practices and style guidelines?
# - Are Pandas functions used appropriately?
# - Does the student demonstrate mastery masking in Pandas?
# - Does the student demonstrate mastery sorting in Pandas?
#
# **Data Cleaning and EDA**
# - Does the student fix data entry issues?
# - Are data appropriately labeled?
# - Are data appropriately typed?
# - Are datasets combined correctly?
# - Are appropriate summary statistics provided?
# - Are steps taken during data cleaning and EDA framed appropriately?
#
# **Visualizations**
# - Are the requested visualizations provided?
# - Do plots accurately demonstrate valid relationships?
# - Are plots labeled properly?
# - Plots interpreted appropriately?
# - Are plots formatted and scaled appropriately for inclusion in a notebook-based technical report?
#
# **Research and Conceptual Understanding**
# - Were useful insights gathered from outside sources?
# - Are sources clearly identified?
# - Does the student provide appropriate interpretation with regards to descriptive and inferential statistics?
#
# **Presentation**
# - Is the problem statement clearly presented?
# - Does a strong narrative run through the presentation building toward a final conclusion?
# - Are the conclusions/recommendations clearly stated?
# - Is the level of technicality appropriate for the intended audience?
# - Is the student substantially over or under time?
# - Does the student appropriately pace their presentation?
# - Does the student deliver their message with clarity and volume?
# - Are appropriate visualizations generated for the intended audience?
# - Are visualizations necessary and useful for supporting conclusions/explaining findings?
#
# In order to pass the project, students must earn a minimum score of 1 for each category.
# - Earning below a 1 in one or more of the above categories would result in a failing project.
# - While a minimum of 1 in each category is the required threshold for graduation, students should aim to earn at least an average of 1.5 across each category. An average score below 1.5, while it may be passing, means students may want to solicit specific feedback in order to significantly improve the project before showcasing it as part of a portfolio or the job search.

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given:

# %% [markdown]
# Which states should money be best spent on, to improve SAT participation rates?

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
path='../data/'                              # Good
sat_2017=pd.read_csv(path+'sat_2017.csv')
act_2017=pd.read_csv(path+'act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
print('sat_2017')
print(sat_2017.head(10))
print()
print('act_2017')
print(act_2017.head(10))
# Out:
# sat_2017
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# ...

# %%
# see if there are any similar State names which are mispelt (eg. Ohio and Ohhio), for SAT and ACT files
for k,v in act_2017.groupby('State'): ### or act_2017.groupby('State').nunique().count(), expect 51 entries 
    print(k)                          ### corresponding to 50 states + Washington DC
# after trying both files, they seem correct
# Out:
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# National
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming

# %%
# check if SAT's columns are correct. 
# Used excel to Compare against: https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/
sat_2017                         ### Try not to do this if possible - doesn't work well with larger datasets
# seems that row 20 (524, not 52) is incorrect
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
# check if ACT's Composite column is correct
act_2017['English_round']=act_2017.English.round()
act_2017['Math_round']=act_2017.Math.round()
act_2017['Reading_round']=act_2017.Reading.round()
act_2017['Science_round']=act_2017.Science.round()
act_2017['Composite_round'] = act_2017[['English_round','Math_round','Reading_round','Science_round']].mean(axis=1)
act_2017['Composite_noround'] = act_2017[['English','Math','Reading','Science']].mean(axis=1)

act_2017
# looks like the original Composite column isnt calculated correctly
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
print(sat_2017.info())
print(sat_2017.describe())
act_2017=pd.read_csv(path+'act_2017.csv')
print(act_2017.info())
print(act_2017.describe())                 ### No need to print. Just act_2017.describe() is ok.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# ...

# %% [markdown]
# Answer:
#
# sat_2017 is a 51by5 dataframe, showing for each state, their participation rates, evidence based read/write scores, math scores, and the sum of the latter 2. The mean, std, median, min/max, 25th/75th percentiles for the latter 3 scores are as shown above. The std, as can be seen, are huge for the latter 3 columns
#
# act_2017 is a 52by7 dataframe, showing for each state, their participation rates, english, math, reading, science scores, and the composite/average of the latter 4. The mean, std, median, min/max, 25th/75th percentiles for the constituent 4 scores are as shown above. The std, as can be seen, are relatively smaller for these 4 columns, compared to sat_2017

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: yes, as there are no null data points

# %%
### might want to use act_17.isnull().sum() to confirm

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# SAT
# 1. The min score for each section is 200, hence the min total is 400. The max would be 800 each, hence the max total is 1600. In sat_2017, the min math score was 52, which is abnormal as it is <200
# 2. The Total score is incorrect for some rows (eg. row 22, 24)
#
# ACT
# 1. The min score for each section is 1, hence the min composite/average is 1. The max would be 36 each, hence the max composite/average is 36. Hence act_2017's data looks sensible at first glance
# 2. However, the last row in act_2017's composite column is '20.0x', which isn't a float, hence it is an error/anomaly
# 3. The Composite scores are incorrect (regardless whether they're averaged using rounded scores, or un-rounded scores)
# 4. There seems to be 1 more row than SAT (52 vs 51 rows)

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code

# SAT
# get online's 2017 SAT data (sat_2017_source.csv)
# Link: https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/
sat_2017.loc[20]['Math'] = 524
# or simply...Replace the given sat_2017.csv data, with the online source's, as it'll be more accurate (its the data source),
# plus we can efficiently replace all wrong values at 1 go.
sat_2017 = pd.read_csv(path+'sat_2017_source.csv')
print(sat_2017)

# ACT
# comparing in excel using EXACT function, against online source,
# Link: https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows
# row 21 scores should be 23.2, not 2.3
act_2017.loc[21,'Science'] =23.2
# row 51 composite score should be 20.2, not 20.2x
act_2017.loc[51,'Composite'] = 20.2
# alternatively, just get online's 2017 ACT data (act_2017_source.csv), as it'll be more accurate (its the data source),
# plus we can efficiently replace all wrong values at 1 go.
act_2017 = pd.read_csv(path+'act_2017_source.csv')
print(act_2017)

# looks correct after these fixes. Although the original (dubious looking) composite scores, seem to match
# those from the online source. So we'll stick with them
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
print(sat_2017.dtypes)
print()
print(act_2017.dtypes)
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# For sat_2017, 'Participation' should be of type int64/float64.
# For act_2017, 'Participation' should be of type int64/float64

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
def to_number(data):
    data=data.replace('%','')
#     data=data.replace('x','') #for the 'Composite' column in act_2017 
    data=pd.to_numeric(data)  #converts values to an appropriate numeric type
    return data
sat_2017['Participation']=sat_2017['Participation'].apply(to_number)    #apply function on Participation cols in both files
act_2017['Participation']=act_2017['Participation'].apply(to_number)
print(sat_2017['Participation'].head())
print(act_2017['Participation'].head())
# Out:
# 0     5
# 1    38
# 2    30
# 3     3
# 4    53
# Name: Participation, dtype: int64
# 0    100
# 1     65
# 2     62
# 3    100
# 4     31
# Name: Participation, dtype: int64

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# code
# all done above already

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
print(sat_2017.head(25))
print(act_2017.head())
# looks correct after the fixes
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama              5                                 593
# 1                 Alaska             38                                 547
# 2                Arizona             30                                 563
# 3               Arkansas              3                                 614
# 4             California             53                                 531
# 5               Colorado             11                                 606
# 6            Connecticut            100                                 530
# 7               Delaware            100                                 503
# 8   District of Columbia            100                                 482
# 9                Florida             83                                 520
# 10               Georgia             61                                 535
# ...

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
print(sat_2017.dtypes)
print()
print(act_2017.dtypes)
# Participation cols' types have indeed been changed to int64
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code

# create function to rename columns 
def rename_cols(data,prefix_test,suffix_year):
    data=data.rename(columns={'Participation':'Participation %'})
    data.columns = [prefix_test + '-' + str(col) + '-' + suffix_year for col in data.columns] #adds prefix (eg. SAT-, ACT-) to all column headers
    data.columns = map(str.lower, data.columns) #make all headers lowercase
    data.columns = data.columns.str.replace(' ', '_') #replace all spaces with _
    re = ['state' if k==0 else data.columns[k] for k in range(len(data.columns))]
    data.columns = re 
    return data
sat_2017=rename_cols(sat_2017,'sat','2017')
sat_2017.head()
# Out:
#         state  sat-participation_%-2017  \
# 0     Alabama                         5
# 1      Alaska                        38
# 2     Arizona                        30
# 3    Arkansas                         3
# 4  California                        53
#
#    sat-evidence-based_reading_and_writing-2017  sat-math-2017  sat-total-2017
# 0                                          593            572            1165
# 1                                          547            533            1080
# 2                                          563            553            1116
# 3                                          614            594            1208
# 4                                          531            524            1055

# %%
act_2017=rename_cols(act_2017,'ACT','2017')
act_2017.head()
# Out:
#         state  act-participation_%-2017  act-english-2017  act-math-2017  \
# 0     Alabama                       100              18.9           18.4
# 1      Alaska                        65              18.7           19.8
# 2     Arizona                        62              18.6           19.8
# 3    Arkansas                       100              18.9           19.0
# 4  California                        31              22.5           22.7
#
#    act-reading-2017  act-science-2017  act-composite-2017
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %%
data_dictionary=pd.DataFrame({
    'Feature':['state', 'sat-participation_%-2017',
       'sat-evidence-based_reading_and_writing-2017', 'sat-math-2017',
       'sat-total-2017', 'act-participation_%-2017', 'act-english-2017',
       'act-math-2017', 'act-reading-2017', 'act-science-2017',
       'act-composite-2017', 'sat-participation_%-2018',
       'sat-evidence-based_reading_and_writing-2018', 'sat-math-2018',
       'sat-total-2018', 'act-participation_%-2018', 'act-composite-2018'],
    'Type':['O',
        'int64',
        'int64',
        'float64',
        'float64',
        'int64',
        'float64',
        'float64',
        'float64',
        'float64',
        'float64',
        'int64',
        'int64',
        'int64',
        'int64',
        'int64',
        'float64'],
    'Dataset':['ACT/SAT',
               'SAT',
               'SAT',
               'SAT',
               'SAT',
               'ACT',
               'ACT',
               'ACT',
               'ACT',
               'ACT',
               'ACT',
               'SAT',
               'SAT',
               'SAT',
               'SAT',
               'ACT',
               'ACT'],
    'Description_eg.':['US state. eg. Alabama',
                   'SAT 2017 participation rate (%). eg. 100',
                   'SAT 2017 scores for evidence-based read&write. eg. 400',
                   'SAT 2017 scores for math eg. 400',
                   'SAT 2017 sum of scores for evidence-based read&write + math eg. 800',
                   'ACT 2017 participation rate (%). eg. 100',
                   'ACT 2017 scores for english. eg. 20',
                   'ACT 2017 scores for math. eg. 20',
                   'ACT 2017 scores for reading. eg. 20',
                   'ACT 2017 scores for science. eg. 20',
                   'ACT 2017 average scores for english+math+reading+science. eg. 20',
                   'SAT 2018 participation rate (%). eg. 100',
                   'SAT 2018 scores for evidence-based read&write. eg. 400',
                   'SAT 2018 scores for math. eg. 400',
                   'SAT 2018 sum of scores for evidence-based read&write + math. eg. 800',
                   'ACT 2018 participation rate (%). eg. 100',
                   'ACT 2018 average scores for english+math+reading+science. eg. 20']
    })
data_dictionary
# Out:
#                                         Feature     Type  Dataset  \
# 0                                         state        O  ACT/SAT
# 1                      sat-participation_%-2017    int64      SAT
# 2   sat-evidence-based_reading_and_writing-2017    int64      SAT
# 3                                 sat-math-2017  float64      SAT
# 4                                sat-total-2017  float64      SAT
# 5                      act-participation_%-2017    int64      ACT
# 6                              act-english-2017  float64      ACT
# 7                                 act-math-2017  float64      ACT
# 8                              act-reading-2017  float64      ACT
# 9                              act-science-2017  float64      ACT
# 10                           act-composite-2017  float64      ACT
# 11                     sat-participation_%-2018    int64      SAT
# 12  sat-evidence-based_reading_and_writing-2018    int64      SAT
# ...

# %%
### 'State' should have data type Object.

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
# act_2017=act_2017.drop(0)    #drop 1st row, which is the National score
# act_2017

# no need for this step, as i copied over the 50row data directly from online source

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
# state                       51 non-null object
# act-participation_%-2017    51 non-null int64
# act-english-2017            51 non-null float64
# act-math-2017               51 non-null float64
# act-reading-2017            51 non-null float64
# act-science-2017            51 non-null float64
# act-composite-2017          51 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
sat_act_2017=sat_2017.merge(act_2017)
sat_act_2017
# Out:
#                    state  sat-participation_%-2017  \
# 0                Alabama                         5
# 1                 Alaska                        38
# 2                Arizona                        30
# 3               Arkansas                         3
# 4             California                        53
# 5               Colorado                        11
# 6            Connecticut                       100
# 7               Delaware                       100
# 8   District of Columbia                       100
# 9                Florida                        83
# 10               Georgia                        61
# 11                Hawaii                        55
# 12                 Idaho                        93
# 13              Illinois                         9
# 14               Indiana                        63
# 15                  Iowa                         2
# 16                Kansas                         4
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
sat_act_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_2018=pd.read_csv(path+'sat_2018.csv')
# compare with source
# Link: https://ipsr.ku.edu/ksdata/ksah/education/6ed16.pdf
sat_2018_source=pd.read_csv(path+'sat_2018_source.csv')

# looks like:
# row 9 scores should be 522,493,1014, not 550,549,1099
sat_2018.loc[9,'Evidence-Based Reading and Writing']=522
sat_2018.loc[9,'Math']=493
sat_2018.loc[9,'Total'] =1014
# row 11 scores should be 550,549,1099, not 480,530,1010
sat_2018.loc[11,'Evidence-Based Reading and Writing']=550
sat_2018.loc[11,'Math']=549
sat_2018.loc[11,'Total'] =1099
# row 14 scores should be 546,539,1086, not 542,532,1074
sat_2018.loc[14,'Evidence-Based Reading and Writing']=546
sat_2018.loc[14,'Math']=539
sat_2018.loc[14,'Total'] =1086
# row 41 total score should be 1241, not 1240
sat_2018.loc[41,'Total'] = 1241
# row 44 scores should be 618,612,1230, not 480,530,1010
sat_2018.loc[44,'Evidence-Based Reading and Writing']=618
sat_2018.loc[44,'Math']=612
sat_2018.loc[44,'Total'] =1230

sat_2018 #display the outcome. Looks correct!
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 522
# 10               Georgia           70%                                 542
# ...

# %%
# but alternatively, just use SAT 2018 data from online source. Which is the original source (hence most accurate),
# and this is more efficient than iloc replacing individual values. 
# Link: https://ipsr.ku.edu/ksdata/ksah/education/6ed16.pdf
sat_2018=pd.read_csv(path+'sat_2018_source.csv')    #read and save csv files into dataframes

# but for act_2018, there's no online source to check against, hence use originally given dataset
act_2018=pd.read_csv(path+'act_2018.csv') 
# ASSUMPTION: note that although act_2018_updated (which contains english/math/science/rdg scores)
# was given in the dataset folder, but since the Project instructions stated below that 
# "We only have composite (and not subtest scores) for the 2018 ACT.",
# hence I will be using the original dataset act_2018 here. If needed, I could still read in the updated dataset via:
# act_2018=pd.read_csv(path+'act_2018_updated.csv')

print(sat_2018.head())                       #quick view of both new sets of data
print(sat_2018.info())
print(sat_2018.describe())
print(sat_2018.dtypes)
print()
print(act_2018.head())
print(act_2018.info())
print(act_2018.describe())
print(act_2018.dtypes)

# sat_2018's, act_2018's Participation cols' types also need to be corrected
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
# ...

# %%
# data all cleaned from previous step:
# SAT
## no need to replace <200 scores, as the min scores arent below 200
print(sat_2018)

# ACT
print(act_2018)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 522
# 10               Georgia           70%                                 542
# ...

# %%
# convert those columns to numeric type
sat_2018['Participation']=sat_2018['Participation'].apply(to_number)
act_2018['Participation']=act_2018['Participation'].apply(to_number)

# %%
# rename columns
sat_2018=rename_cols(sat_2018,'sat','2018')
act_2018=rename_cols(act_2018,'act','2018')

# %%
print(sat_2018.head())
print(act_2018.head())
# Out:
#         state  sat-participation_%-2018  \
# 0     Alabama                         6
# 1      Alaska                        43
# 2     Arizona                        29
# 3    Arkansas                         5
# 4  California                        60
#
#    sat-evidence-based_reading_and_writing-2018  sat-math-2018  sat-total-2018
# 0                                          595            571            1166
# 1                                          562            544            1106
# 2                                          577            572            1149
# 3                                          592            576            1169
# 4                                          540            536            1076
#         state  act-participation_%-2018  act-composite-2018
# 0     Alabama                       100                19.1
# 1      Alaska                        33                20.8
# 2     Arizona                        66                19.2
# ...

# %%
# drop duplicate rows (there are at least 2x rows of Maine)
act_2018.drop_duplicates(subset ="state", inplace = True)
print(act_2018)
# Out:
#                    state  act-participation_%-2018  act-composite-2018
# 0                Alabama                       100                19.1
# 1                 Alaska                        33                20.8
# 2                Arizona                        66                19.2
# 3               Arkansas                       100                19.4
# 4             California                        27                22.7
# 5               Colorado                        30                23.9
# 6            Connecticut                        26                25.6
# 7               Delaware                        17                23.8
# 8   District of columbia                        32                23.6
# 9                Florida                        66                19.9
# 10               Georgia                        53                21.4
# 11                Hawaii                        89                18.9
# ...

# %%
# finally, check all no. of rows, datatypes again
print(sat_2018.dtypes)
print(sat_2018.info())
print()
print(act_2018.dtypes)
print(act_2018.info())
# everything looks correct now
# Out:
# state                                          object
# sat-participation_%-2018                        int64
# sat-evidence-based_reading_and_writing-2018     int64
# sat-math-2018                                   int64
# sat-total-2018                                  int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# state                                          51 non-null object
# sat-participation_%-2018                       51 non-null int64
# sat-evidence-based_reading_and_writing-2018    51 non-null int64
# sat-math-2018                                  51 non-null int64
# sat-total-2018                                 51 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB
# None
#
# state                        object
# act-participation_%-2018      int64
# act-composite-2018          float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
sat_act_2018 = sat_2018.merge(act_2018)    #merge SAT 2018 and ACT 2018 dataframes 
final = sat_act_2017.merge(sat_act_2018)   #merge 2017 and 2018 dataframes
final.to_csv('../data/final.csv')                  #save to a csv file

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
np.transpose(final.describe())      ### or just final.describe().T
# Out:
#                                              count      mean        std  \
# sat-participation_%-2017                      50.0    38.600  34.560211
# sat-evidence-based_reading_and_writing-2017   50.0   570.860  44.385146
# sat-math-2017                                 50.0   558.660  45.839832
# sat-total-2017                                50.0  1129.620  89.913085
# act-participation_%-2017                      50.0    65.920  32.110676
# act-english-2017                              50.0    20.862   2.324307
# act-math-2017                                 50.0    21.136   1.973990
# act-reading-2017                              50.0    21.956   2.046317
# act-science-2017                              50.0    21.410   1.731962
# act-composite-2017                            50.0    21.466   2.004241
# sat-participation_%-2018                      50.0    44.820  37.097604
# sat-evidence-based_reading_and_writing-2018   50.0   568.700  44.640171
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def standard_dev(data):
    total = 0                                         #initialise total value of (x(i)-miu)^2
    for i in range(len(data)):                        #sum up total value of the above
        total = total + (data[i]-np.mean(data))**2     ### += would also work here
    std = np.sqrt(total/len(data))                     ### interestingly, math.sqrt runs pretty slowly compared to just 
                                                       ### simply exponentiating by 0.5. To test, try
    return std                                         ### import timeit
                                                       ### %timeit math.sqrt(100)
                                                       ### replace with 100 ** 0.5 to see the difference.

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
{final.columns[i]:standard_dev(list(final.iloc[:,i])) for i in range(1,len(final.columns))} #Good
# Out:
# {'sat-participation_%-2017': 34.21286307808804,
#  'sat-evidence-based_reading_and_writing-2017': 43.9390532442382,
#  'sat-math-2017': 45.37911854586864,
#  'sat-total-2017': 89.00941298536914,
#  'act-participation_%-2017': 31.787947401491657,
#  'act-english-2017': 2.3009467616613817,
#  'act-math-2017': 1.9541504548012678,
#  'act-reading-2017': 2.025750231395766,
#  'act-science-2017': 1.7145553359399048,
#  'act-composite-2017': 1.9840977798485642,
#  'sat-participation_%-2018': 36.72475459414263,
#  'sat-evidence-based_reading_and_writing-2018': 44.1915150226828,
#  'sat-math-2018': 47.62604329565915,
#  'sat-total-2018': 91.4684404589911,
#  'act-participation_%-2018': 33.7712540483767,
#  'act-composite-2018': 2.090091864009809}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
final.describe() 
# std of 'sat-participation_%-2017' = 34.56
# Out:
#        sat-participation_%-2017  sat-evidence-based_reading_and_writing-2017  \
# count                 50.000000                                    50.000000
# mean                  38.600000                                   570.860000
# std                   34.560211                                    44.385146
# min                    2.000000                                   503.000000
# 25%                    4.000000                                   535.250000
# 50%                   34.000000                                   559.500000
# 75%                   65.000000                                   613.500000
# max                  100.000000                                   644.000000
#
#        sat-math-2017  sat-total-2017  act-participation_%-2017  \
# count      50.000000       50.000000                 50.000000
# mean      558.660000     1129.620000                 65.920000
# std        45.839832       89.913085                 32.110676
# ...

# %%
### if you had instead called final.describe().T (the transpose of the DataFrame), the results would have 
### been much easier to read

# %%
np.std(final['sat-participation_%-2017'])
# Out:
# 34.21286307808804

# %% [markdown]
# Answer:
#
# Pandas' describe has a default ddof of 1, hence the variance is divided by N-1, hence yielding a larger std (34.56).
#
# Numpy's std has a default ddof of 0, hence the variance is divided by N-0=N, hence yielding a smaller std (34.21).

# %%
### To be very exact, the squared deviations summa[(y-y_bar)^2] are the dividend and not the variance. 
### The variance is the expectation value of this object, but depending on the degrees of freedom you
### divide it by N or N-1.
### Taking ddof = 0  results in an underestimation of the variance since you miss the extra degree of freedom

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ##### Wait! Extra features we will add in!
#
# Before proceeding with the EDA on the original data, it was hypothesized that the number of students that haven't taken the SATs, would also be an interesting feature to look at: the larger the number of untested students (total high sch grads X (1-% of test takers)), the greater the "untapped potential" for us, College Board.
#
# This additional data was hence added in, from external research. We will see below that California, Texas, and Ohio, have the greatest untapped potential, given their high (absolute) numbers of untested students in both 2017 and 2018 SATs.

# %%
### I'm a bit worried about defining this USP metric. It seems quite arbitrary and should be much more
### rigerously justified before using it to measure anything.

# %%
sat_2017_withstudpop = pd.read_csv(path+'sat_2017_withstudpop.csv')
sat_2017_withstudpop['Untapped Student Potential'] = sat_2017_withstudpop['High School Graduates']*(1-sat_2017_withstudpop['Percentage'])
sat_2017_withstudpop = rename_cols(sat_2017_withstudpop,'sat','2017')
sat_2017_withstudpop.sort_values('sat-untapped_student_potential-2017',ascending=False)
# Out:
#                    state sat-participation_%-2017  \
# 4             California                      53%
# 43                 Texas                      62%
# 35                  Ohio                      12%
# 32              New York                      67%
# 25              Missouri                       3%
# 42             Tennessee                       5%
# 49             Wisconsin                       3%
# 23             Minnesota                       3%
# 33        North Carolina                      49%
# 5               Colorado                      11%
# 38          Pennsylvania                      65%
# 2                Arizona                      30%
# 0                Alabama                       5%
# 17              Kentucky                       4%
# 18             Louisiana                       4%
# 10               Georgia                      61%
# 36              Oklahoma                       7%
# 44                  Utah                       3%
# ...

# %%
sat_2018_withstudpop = pd.read_csv(path+'sat_2018_withstudpop.csv')
sat_2018_withstudpop['Untapped Student Potential'] = sat_2018_withstudpop['High School Graduates']*(1-sat_2018_withstudpop['Percentage'])
sat_2018_withstudpop = rename_cols(sat_2018_withstudpop,'sat','2018')
sat_2018_withstudpop.sort_values('sat-untapped_student_potential-2018',ascending=False)
# Out:
#                    state sat-participation_%-2018  \
# 4             California                      60%
# 43                 Texas                      66%
# 36                  Ohio                      18%
# 25              Missouri                       4%
# 49             Wisconsin                       3%
# 42             Tennessee                       6%
# 23             Minnesota                       4%
# 33        North Carolina                      52%
# 2                Arizona                      29%
# 0                Alabama                       6%
# 17              Kentucky                       4%
# 32              New York                      79%
# 18             Louisiana                       4%
# 38          Pennsylvania                      70%
# 35              Oklahoma                       8%
# 44                  Utah                       4%
# 15                  Iowa                       3%
# 16                Kansas                       4%
# ...

# %% [markdown]
# Indeed, California, Texas, and Ohio (in descending order), have the greatest untapped potential, for us to focus our efforts on to raise participation levels. In other words, a 1% increase in participation rates in these 3 states, would yield a larger (absolute) number of test-takers, relative to other states.
#
# Hence, using this extra piece of information, we will focus on these 3 states more relative to the other states, in the EDA below (to see if their participation rates/scores might give us even more reason to focus our efforts on them).

# %% [markdown]
# # HIGHEST/LOWEST PARTICIPATION RATES

# %%
#code
# 2017 SAT (highest, lowest participation rate)
sat_2017.sort_values(by=['sat-participation_%-2017','state'],ascending=False) #also sort by alphabetical order for state, for easier comparison of states with other years
# print(sat_2017.sort_values(by=['sat-participation_%-2017','state'],ascending=True))#True, for ascending order
# Ans: as seen below
# Out:
#                    state  sat-participation_%-2017  \
# 22              Michigan                       100
# 8   District of Columbia                       100
# 7               Delaware                       100
# 6            Connecticut                       100
# 29         New Hampshire                        96
# 19                 Maine                        95
# 12                 Idaho                        93
# 9                Florida                        83
# 21         Massachusetts                        76
# 39          Rhode Island                        71
# 30            New Jersey                        70
# 20              Maryland                        69
# 32              New York                        67
# 46              Virginia                        65
# 38          Pennsylvania                        65
# 47            Washington                        64
# 14               Indiana                        63
# ...

# %%
#code
# 2017 ACT (highest, lowest participation rate)
act_2017.sort_values(by=['act-participation_%-2017','state'],ascending=False)
# print(act_2017.sort_values(by=['act-participation_%-2017','state'],ascending=True))
# Ans: as seen below
# Out:
#                    state  act-participation_%-2017  act-english-2017  \
# 50               Wyoming                       100              19.4
# 49             Wisconsin                       100              19.7
# 44                  Utah                       100              19.5
# 42             Tennessee                       100              19.5
# 40        South Carolina                       100              17.5
# 36              Oklahoma                       100              18.5
# 33        North Carolina                       100              17.8
# 28                Nevada                       100              16.3
# 26               Montana                       100              19.0
# 25              Missouri                       100              19.8
# 24           Mississippi                       100              18.2
# 23             Minnesota                       100              20.4
# 18             Louisiana                       100              19.4
# ...

# %%
#code
# 2018 SAT (highest, lowest participation rate)
sat_2018.sort_values(by=['sat-participation_%-2018','state'],ascending=False)
# print(sat_2018.sort_values(by=['sat-participation_%-2018','state'],ascending=True))
# Ans: as seen below
# Out:
#                    state  sat-participation_%-2018  \
# 22              Michigan                       100
# 12                 Idaho                       100
# 7               Delaware                       100
# 6            Connecticut                       100
# 5               Colorado                       100
# 19                 Maine                        99
# 13              Illinois                        99
# 39          Rhode Island                        97
# 29         New Hampshire                        96
# 8   District of Columbia                        92
# 30            New Jersey                        82
# 21         Massachusetts                        80
# 32              New York                        79
# 20              Maryland                        76
# 38          Pennsylvania                        70
# 10               Georgia                        70
# 47            Washington                        69
# ...

# %%
#code
# 2018 ACT (highest, lowest participation rate)
act_2018.sort_values(by=['act-participation_%-2018','state'],ascending=False)
# print(act_2018.sort_values(by=['act-participation_%-2018','state'],ascending=True))
# Ans: as seen below
# Out:
#                    state  act-participation_%-2018  act-composite-2018
# 51               Wyoming                       100                20.0
# 50             Wisconsin                       100                20.5
# 45                  Utah                       100                20.4
# 43             Tennessee                       100                19.6
# 41        South Carolina                       100                18.3
# 37              Oklahoma                       100                19.3
# 36                  Ohio                       100                20.3
# 34        North Carolina                       100                19.1
# 29                Nevada                       100                17.7
# 28              Nebraska                       100                20.1
# 27               Montana                       100                20.0
# 26              Missouri                       100                20.0
# ...

# %% [markdown]
# Observations:
# 1. Highest participating rates for SAT are consistently from (across 2017-2018): Michigan, Deleware, Connecticut (all 100%)
#
# 2. Lowest participating rates for SAT are consistently from (across 2017-2018): North Dakota, Iowa, Mississippi, Nebraska, South Dakota, Wisconsin, Wyoming, Kansas (all 2-4%).
#
# 3. SAT participation rates for California, Texas, Ohio are:
#
# 2017: 52%, 62%, 12% respectively
#
# 2018: 60%, 66%, 8% respectively
#
# 4. ACT participation rates for California, Texas, Ohio are:
#
# 2017: 31%, 45%, 75% respectively
#
# 2018: 27%, 45%, 100% respectively (Ohio's ACT participation rates, increased from 75% to 100%, hence it might be difficult to boost their SAT participation rates, as their 100% ACT rates suggest state policies driving that)

# %% [markdown]
# # HIGHEST/LOWEST TOTAL/COMPOSITE SCORES

# %% [markdown]
# ##### 2017 SAT

# %%
#code
# 2017 SAT (highest, lowest total/composite scores)
sat_2017.sort_values(by=['sat-total-2017','state'],ascending=False)         ### Just the first few entries should be enough
# print(sat_2017.sort_values(by=['sat-total-2017','state'],ascending=True)) ### try not to keep loading the DataFrame
# Ans: as seen below
# Out:
#                    state  sat-participation_%-2017  \
# 23             Minnesota                         3
# 49             Wisconsin                         3
# 15                  Iowa                         2
# 25              Missouri                         3
# 16                Kansas                         4
# 34          North Dakota                         2
# 27              Nebraska                         3
# 17              Kentucky                         4
# 24           Mississippi                         2
# 44                  Utah                         3
# 50               Wyoming                         3
# 42             Tennessee                         5
# 41          South Dakota                         3
# 3               Arkansas                         3
# 5               Colorado                        11
# 18             Louisiana                         4
# 26               Montana                        10
# ...

# %%
print('SAT 2017 mean total score = ',sat_2017['sat-total-2017'].mean())
print('SAT 2017 California total score = ',sat_2017['sat-total-2017'][sat_2017['state']=='California'].max(),', lower than mean')
print('SAT 2017 Texas total score = ',sat_2017['sat-total-2017'][sat_2017['state']=='Texas'].max(),', lower than mean')
print('SAT 2017 Ohio total score = ',sat_2017['sat-total-2017'][sat_2017['state']=='Ohio'].max())
# Out:
# SAT 2017 mean total score =  1126.0980392156862
# SAT 2017 California total score =  1055 , lower than mean
# SAT 2017 Texas total score =  1020 , lower than mean
# SAT 2017 Ohio total score =  1149

# %% [markdown]
# ##### 2017 ACT

# %%
#code
# 2017 ACT (highest, lowest total/composite scores)
act_2017.sort_values(by=['act-composite-2017','state'],ascending=False)
# print(act_2017.sort_values(by=['act-composite-2017','state'],ascending=True).head())
# Ans: as seen below
# Out:
#                    state  act-participation_%-2017  act-english-2017  \
# 29         New Hampshire                        18              25.4
# 21         Massachusetts                        29              25.4
# 6            Connecticut                        31              25.5
# 19                 Maine                         8              24.2
# 32              New York                        31              23.8
# 8   District of Columbia                        32              24.4
# 22              Michigan                        29              24.1
# 7               Delaware                        18              24.1
# 39          Rhode Island                        21              24.0
# 30            New Jersey                        34              23.8
# 46              Virginia                        29              23.5
# 38          Pennsylvania                        23              23.4
# 45               Vermont                        29              23.3
# ...

# %%
print('ACT 2017 mean composite score = ',act_2017['act-composite-2017'].mean())
print('ACT 2017 California composite score = ',act_2017['act-composite-2017'][act_2017['state']=='California'].max())
print('ACT 2017 Texas composite score = ',act_2017['act-composite-2017'][act_2017['state']=='Texas'].max(),', lower than mean')
print('ACT 2017 Ohio composite score = ',act_2017['act-composite-2017'][act_2017['state']=='Ohio'].max())
# Out:
# ACT 2017 mean composite score =  21.519607843137255
# ACT 2017 California composite score =  22.8
# ACT 2017 Texas composite score =  20.7 , lower than mean
# ACT 2017 Ohio composite score =  22.0

# %% [markdown]
# ##### 2018 SAT

# %%
#code
# 2018 SAT (highest, lowest total/composite scores)
sat_2018.sort_values(by=['sat-total-2018','state'],ascending=False)
# print(sat_2018.sort_values(by=['sat-total-2018','state'],ascending=True))
# Ans: as seen below
# Out:
#                    state  sat-participation_%-2018  \
# 23             Minnesota                         4
# 49             Wisconsin                         3
# 34          North Dakota                         2
# 16                Kansas                         4
# 15                  Iowa                         3
# 25              Missouri                         4
# 50               Wyoming                         3
# 27              Nebraska                         3
# 17              Kentucky                         4
# 41          South Dakota                         3
# 24           Mississippi                         3
# 42             Tennessee                         6
# 44                  Utah                         4
# 18             Louisiana                         4
# 26               Montana                        10
# 3               Arkansas                         5
# 0                Alabama                         6
# ...

# %%
print('SAT 2018 mean total score = ',sat_2018['sat-total-2018'].mean())
print('SAT 2018 California total score = ',sat_2018['sat-total-2018'][sat_2018['state']=='California'].max(),', lower than mean')
print('SAT 2018 Texas total score = ',sat_2018['sat-total-2018'][sat_2018['state']=='Texas'].max(),', lower than mean')
print('SAT 2018 Ohio total score = ',sat_2018['sat-total-2018'][sat_2018['state']=='Ohio'].max(),', lower than mean')
# Out:
# SAT 2018 mean total score =  1124.6666666666667
# SAT 2018 California total score =  1076 , lower than mean
# SAT 2018 Texas total score =  1032 , lower than mean
# SAT 2018 Ohio total score =  1099 , lower than mean

# %% [markdown]
# ##### 2018 ACT

# %%
#code
# 2018 ACT (highest, lowest total/composite scores)
act_2018.sort_values(by=['act-composite-2018','state'],ascending=False)
# print(act_2018.sort_values(by=['act-composite-2018','state'],ascending=True))
# Ans: as seen below
# Out:
#                    state  act-participation_%-2018  act-composite-2018
# 6            Connecticut                        26                25.6
# 22         Massachusetts                        25                25.5
# 30         New Hampshire                        16                25.1
# 33              New York                        27                24.5
# 40          Rhode Island                        15                24.2
# 23              Michigan                        22                24.2
# 46               Vermont                        24                24.1
# 19                 Maine                         7                24.0
# 47              Virginia                        24                23.9
# 13              Illinois                        43                23.9
# 5               Colorado                        30                23.9
# 7               Delaware                        17                23.8
# ...

# %%
print('ACT 2018 mean composite score = ',act_2018['act-composite-2018'].mean())
print('ACT 2018 California composite score = ',act_2018['act-composite-2018'][act_2018['state']=='California'].max())
print('ACT 2018 Texas composite score = ',act_2018['act-composite-2018'][act_2018['state']=='Texas'].max(),', lower than mean')
print('ACT 2018 Ohio composite score = ',act_2018['act-composite-2018'][act_2018['state']=='Ohio'].max(),', lower than mean')
# Out:
# ACT 2018 mean composite score =  21.49607843137255
# ACT 2018 California composite score =  22.7
# ACT 2018 Texas composite score =  20.7 , lower than mean
# ACT 2018 Ohio composite score =  20.3 , lower than mean

# %% [markdown]
# Observations:
# 1. Top scoring states for SAT are consistently (across 2017-2018): Minessota, Wisconsin, Iowa, Kansas.
# However, they also are amongst the states with the lowest participation rates (2-4% across 2017,2018)! Maybe they have just a few elite schools that focus on SAT trainings?
#
# 2. Top scoring states for ACT are consistently (across 2017-2018): Connecticut, Massachusetts, New Hampshire, New York. Like point 1, New Hampshire also has 1 of the lowest participation rates (16-18%) even though they score high for ACTs. Maybe they also have elite schools?
#
# 3. California and Texas' SATs generally are lower than the mean for both years. Perhaps support for them in the test subjects may raise their results, and hence their confidence, and hence raise participation rates.

# %% [markdown]
# # RATE CHANGE YR-ON-YR, FOR BOTH TESTS, FOR STATES WITH 100% PARTICIPATION RATES

# %% [markdown]
# ##### SAT

# %%
sat_2017_p100_states = sat_2017['state'][sat_2017['sat-participation_%-2017']==100] #filter out states with 100% participation
print('states with 100% participation rates for SAT 2017:')
print(sat_2017_p100_states)
print()
print('the same states for SAT 2018:')
sat_2018[sat_2018['state'].isin(sat_2017_p100_states)]      #to see 2018 participation rates of states with 100% in 2017
# Out:
# states with 100% participation rates for SAT 2017:
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 22                Michigan
# Name: state, dtype: object
#
# the same states for SAT 2018:
#                    state  sat-participation_%-2018  \
# 6            Connecticut                       100
# 7               Delaware                       100
# 8   District of Columbia                        92
# 22              Michigan                       100
#
#     sat-evidence-based_reading_and_writing-2018  sat-math-2018  sat-total-2018
# 6                                           535            519            1053
# 7                                           505            492             998
# 8                                           497            480             977
# 22                                          511            499            1011

# %% [markdown]
# Ans: For SAT, only District of Columbia had a drop in participation rate from 100% to 92%. The rest remained at 100%

# %% [markdown]
# ##### ACT

# %%
act_2017_p100_states = act_2017['state'][act_2017['act-participation_%-2017']==100]#filter out states with 100% participation
print('states with 100% participation rates for ACT 2017:')
print(act_2017_p100_states)
print()
print('the same states for ACT 2018:')
act_2018[act_2018['state'].isin(act_2017_p100_states)]     #to see 2018 participation rates of states with 100% in 2017
# Out:
# states with 100% participation rates for ACT 2017:
# 0            Alabama
# 3           Arkansas
# 5           Colorado
# 17          Kentucky
# 18         Louisiana
# 23         Minnesota
# 24       Mississippi
# 25          Missouri
# 26           Montana
# 28            Nevada
# 33    North Carolina
# 36          Oklahoma
# 40    South Carolina
# 42         Tennessee
# 44              Utah
# 49         Wisconsin
# 50           Wyoming
# Name: state, dtype: object
#
# the same states for ACT 2018:
#              state  act-participation_%-2018  act-composite-2018
# 0          Alabama                       100                19.1
# 3         Arkansas                       100                19.4
# 5         Colorado                        30                23.9
# 17        Kentucky                       100                20.2
# 18       Louisiana                       100                19.2
# 24       Minnesota                        99                21.3
# ...

# %% [markdown]
# Ans:
#
# For ACT, only Colorado had a significant drop in participation rate from 100% to 30%. The rest remained at 99-100%.
#
# Nothing noteworthy was noticed for the 3 states.

# %% [markdown]
# # STATES THAT HAD >50% PARTICIPATION RATES FOR EACH YEAR, FOR BOTH TESTS

# %% [markdown]
# ##### 2017

# %%
sat_2017_p50_states = sat_2017['state'][sat_2017['sat-participation_%-2017']>50] #filter states which have >50% participation
act_2017_p50_states = act_2017['state'][act_2017['act-participation_%-2017']>50]
print('states with >50% participation rates for both SAT & ACT 2017:')
pd.merge(sat_2017_p50_states,act_2017_p50_states,how='inner')       #states with >50% participation in both 2017 tests
# Out:
# states with >50% participation rates for both SAT & ACT 2017:
#      state
# 0  Florida
# 1  Georgia
# 2   Hawaii

# %% [markdown]
# ##### 2018

# %%
sat_2018_p50_states = sat_2018['state'][sat_2018['sat-participation_%-2018']>50] #filter states which have >50% participation
act_2018_p50_states = act_2018['state'][act_2018['act-participation_%-2018']>50]
print('states with >50% participation rates for both SAT & ACT 2018:')
pd.merge(sat_2018_p50_states,act_2018_p50_states,how='inner')      #states with >50% participation in both 2018 tests
# Out:
# states with >50% participation rates for both SAT & ACT 2018:
#             state
# 0         Florida
# 1         Georgia
# 2          Hawaii
# 3  North Carolina
# 4  South Carolina

# %% [markdown]
# Observations:
#
# Nothing noteworthy for the 3 states.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(10,10))
sns.heatmap(final.corr(), annot=True)    #annot=True to display correlation values in heatmap
plt.title('Correlation btw all numeric features of SAT/ACT, for years 2017-2018', fontsize =20);

# %% [markdown]
# Interpretation:
# 1. SAT total scores are highly driven by/correlated with both its constituent tests (reading, math), as seen in the high corr scores in both years.
# 2. Likewise for ACT composite scores.
# 3. SAT and ACT scores tend to be negatively correlated with their participation rates.
# 4. SAT and ACT participation rates tend to be negatively correlated.
# 5. Doing well in SAT math, doesn't correlate to doing well in ACT math (see 2017's -0.4 corr score)
# 6. Likewise, doing well in SAT reading/verbal, doesn't correlate to doing well in ACT english or reading (see 2017's -0.43 and -0.46 corr scores)
# 7. For both years, states that do well in 2017, tend to do well also in 2018. Likewise for states that do poorly. (see strong corr between both years, for the SAT total and constituent scores, as well as the ACT composite scores)

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels=''):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows. Divide by 2, cos 2 diff yrs
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].title.set_text(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels)
        ax[i].set_ylabel(list_of_ylabels)
        plt.tight_layout() #space out subplots so they don't overlap

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %% [markdown]
# ##### Participation rates for SAT & ACT

# %%
dataframe = final
list_of_columns = ['sat-participation_%-2017','sat-participation_%-2018','act-participation_%-2017','act-participation_%-2018']
list_of_titles = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']
list_of_xlabels = 'Participation Rates'
list_of_ylabels = 'No. of states'
subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels)

# %%
### It's difficult to compare across SAT scores when the two plots don't share the same y-axis scaling.
### Scaling should be consistent for comparison to be meaningful.
### The additional kwarg (keyword argument) that needs to be specified in the function
### should be plt.subplots(..., sharey='row') for it to share the y-axes across subplot rows.

# %% [markdown]
# ##### Math scores for SAT & ACT

# %%
dataframe = final
list_of_columns = ['sat-math-2017','sat-math-2018','act-math-2017']
list_of_titles = ['SAT math 2017','SAT math 2018','ACT math 2017']
list_of_xlabels = 'Math Scores'
list_of_ylabels = 'No. of states'
subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels)

# %%
### Same issue with y-axis scaling here. Don't plot subplots if you don't need them.

# %% [markdown]
# ##### Reading/verbal scores for SAT & ACT

# %%
dataframe = final
list_of_columns = ['sat-evidence-based_reading_and_writing-2017','sat-evidence-based_reading_and_writing-2018','act-reading-2017']
list_of_titles = ['SAT reading 2017','SAT reading 2018','ACT reading 2017']
list_of_xlabels = 'Reading/verbal Scores'
list_of_ylabels = 'No. of states'
subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code for function
def plot_scatter(dataframe, x, y, title):
    plt.scatter(final[x], final[y], color='cyan')
    plt.scatter(final[x][final['state']=='California'], final[y][final['state']=='California'], color="red")
    plt.scatter(final[x][final['state']=='Texas'], final[y][final['state']=='Texas'], color="blue")
    plt.scatter(final[x][final['state']=='Ohio'], final[y][final['state']=='Ohio'], color="grey")
    plt.title(title)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.legend(['All other states','California','Texas','Ohio'])

# %% [markdown]
# ##### SAT vs. ACT math scores for 2017

# %%
dataframe = final                                 ### Not necessary
x = 'sat-math-2017'
y = 'act-math-2017'
plot_scatter(final,x,y,'SAT vs ACT math scores - 2017, for each state')

# %% [markdown]
# For California and Texas, their low SAT total scores are clearly partially due to their poor math scores relative to other states.

# %%
### Underperformers/overperformers are not immediately obvious from the plot. 
### Maybe a bar plot would be better in this case. But don't go overboard with 50+ bars.

# %% [markdown]
# ##### SAT vs. ACT verbal/reading scores for 2017

# %%
dataframe = final
x = 'sat-evidence-based_reading_and_writing-2017'
y = 'act-reading-2017'
plot_scatter(final,x,y,'SAT vs ACT reading scores - 2017, for each state')

# %% [markdown]
# Again, for California and Texas, their low SAT total scores are also clearly partially due to their poor reading/verbal scores relative to other states. Looks like if we want to raise their participation rates, we might have to first help boost their math and reading/verbal scores, and hence their confidence in taking the SAT tests.

# %% [markdown]
# ##### SAT vs. ACT total/composite scores for 2017

# %%
dataframe = final
x = 'sat-total-2017'
y = 'act-composite-2017'
plot_scatter(final,x,y,'SAT vs ACT total/composite scores - 2017, for each state')

# %% [markdown]
# For California and Texas, they seem to do better in ACTs than in SATs. Much work needs to be done to improve their SAT scores, if we want to poach them over to take SATs.

# %% [markdown]
# ##### Total scores for SAT 2017 vs. 2018

# %%
dataframe = final
x = 'sat-total-2017'
y = 'sat-total-2018'
plot_scatter(final,x,y,'SAT total scores 2017 vs 2018, for each state')
plt.scatter(final[x].mean(), final[y].mean(), color="orange");
plt.legend(['All other states','California','Texas','Ohio','Mean']);

# %% [markdown]
# Nothing noteworthy to mention here about the 3 states.

# %%
### Generally correct, but drawing a sat_total_2018 = sat_total_2017 y=x line and annotating the outliers would help with 
### the visualisation. States in the region above would have sat_total_2018 > sat_total_2017. Annotation can be
### done using matplotlib.pyplot.annotate (see documentation).

# %% [markdown]
# ##### Composite scores for ACT 2017 vs. 2018

# %%
dataframe = final
x = 'act-composite-2017'
y = 'act-composite-2018'
plot_scatter(final,x,y,'ACT composite scores 2017 vs 2018, for each state')
plt.scatter(final[x].mean(), final[y].mean(), color="orange");
plt.legend(['All other states','California','Texas','Ohio','Mean']);

# %% [markdown]
# Nothing noteworthy to mention here about the 3 states.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# ##### SAT, ACT Participation rates 2017-2018

# %%
columns = ['sat-participation_%-2017','sat-participation_%-2018','act-participation_%-2017','act-participation_%-2018']
ax = sns.boxplot(x="variable", y="value", data=pd.melt(final.loc[:,columns]))  #concats all columns into 1 dataframe
plt.setp(ax.get_xticklabels(), rotation=90);
plt.ylabel('Participation rates (%)');

# %% [markdown]
# Interpretation:
#
# 1. ACTs tend to have higher participation rates than SATs (see higher medians).
#
# 2. Also, SAT 2018 saw a rise in participation rates, as seen from the much higher median and 75th percentile.
#
# Nothing noteworthy to mention here about the 3 states.

# %% [markdown]
# ##### SAT constituent scores 2017-2018

# %%
columns = ['sat-evidence-based_reading_and_writing-2017','sat-math-2017',
           'sat-evidence-based_reading_and_writing-2018','sat-math-2018']
ax = sns.boxplot(x="variable", y="value", data=pd.melt(final.loc[:,columns]))
plt.setp(ax.get_xticklabels(), rotation=90);
plt.ylabel('Scores');

# %%
### Looks like the variable names could have been chosen better. 'variable' title at the bottom not necessary 
### and should have been removed

# %% [markdown]
# Interpretation:
#
# 1. SAT Math tests tend to be harder than the reading/verbal tests (see lower medians).
#
# 2. Comparing between both years, the respective tests seem to be similar in difficulty, as seen from the consistent medians, 25th & 75th percentiles, and the max scores.
#
# Nothing noteworthy to mention here about the 3 states.

# %% [markdown]
# ##### SAT total scores 2017-2018

# %%
columns = ['sat-total-2017','sat-total-2018']
ax = sns.boxplot(x="variable", y="value", data=pd.melt(final.loc[:,columns]))
plt.setp(ax.get_xticklabels(), rotation=90);
plt.ylabel('Scores');

# %% [markdown]
# Interpretation:
#
# 1. For the total SAT scores, most students score around 1110, and between 1050-1200, for both years (see medians, and IQ range).
#
# 2. Difficulty level was about the same for both years, as seen from the consistent medians, 25th & 75th percentiles, min/max scores.
#
# Nothing noteworthy to mention here about the 3 states.

# %% [markdown]
# ##### ACT constituent scores 2017 (nil for 2018)

# %%
columns = ['act-english-2017','act-math-2017','act-reading-2017','act-science-2017']
ax = sns.boxplot(x="variable", y="value", data=pd.melt(final.loc[:,columns]))
plt.setp(ax.get_xticklabels(), rotation=90);
plt.ylabel('Scores');

# %% [markdown]
# Interpretation:
#
# All ACT constituent tests seem somewhat equal in difficulty, though Reading is relatively easier, and English is slightly harder.
#
# Nothing noteworthy to mention here about the 3 states.

# %% [markdown]
# ##### ACT composite scores 2017, 2018

# %%
columns = ['act-composite-2017','act-composite-2018']
ax = sns.boxplot(x="variable", y="value", data=pd.melt(final.loc[:,columns]))
plt.setp(ax.get_xticklabels(), rotation=90);
plt.ylabel('Scores');

# %% [markdown]
# Intepretation:
#
# Most students score ~21 for ACTs in both years (see median).
#
# Nothing noteworthy to mention here about the 3 states.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### I decided to examine changes over the 2 years in:
# -Participation rates
#
# -Scores
#
# (For SAT and ACT each)

# %% [markdown]
# #### Changes in participation rates

# %% [markdown]
# ##### SAT

# %%
plt.figure(figsize=(15,5))
final['diff'] = (final['sat-participation_%-2018']-final['sat-participation_%-2017'])#difference in participation rates over 2yrs
final = final.sort_values(by=['diff'], ascending = False)    #sort by difference, descending order
plt.bar(final['state'], final['diff'],color='cyan');
plt.bar(final['state'][final['state']=='California'], final['diff'][final['state']=='California'], color="red")
plt.bar(final['state'][final['state']=='Texas'], final['diff'][final['state']=='Texas'], color="blue")
plt.bar(final['state'][final['state']=='Ohio'], final['diff'][final['state']=='Ohio'], color="grey")
plt.xticks(rotation=90);    #semicolon is to suppress xtixk label outputs
plt.title('Participation rate change (2018 minus 2017) for SAT');
plt.legend(['All other states','California','Texas','Ohio'])

# %%
### Please don't produce visualisations like these. Select the things you want to highlight and discard the rest,
### otherwise the plot becomes extremely cluttered. Maybe Min/Max/Median/Mean + 2/3 states of interest.
### You definitely don't want to plot everything here.

# %% [markdown]
# ##### ACT

# %%
plt.figure(figsize=(15,5))
final['diff'] = (final['act-participation_%-2018']-final['act-participation_%-2017'])
final = final.sort_values(by=['diff'], ascending = False)
plt.bar(final['state'], final['diff'],color='cyan');
plt.bar(final['state'][final['state']=='California'], final['diff'][final['state']=='California'], color="red")
plt.bar(final['state'][final['state']=='Texas'], final['diff'][final['state']=='Texas'], color="blue")
plt.bar(final['state'][final['state']=='Ohio'], final['diff'][final['state']=='Ohio'], color="grey")
plt.xticks(rotation=90);    #semicolon is to suppress xtixk label outputs
plt.title('Participation rate change (2018 minus 2017) for ACT');
plt.legend(['All other states','California','Texas','Ohio'])

# %% [markdown]
# Observation for SAT:
#
# 1. Largest rise in participation rates: Illinois, Colorado.
#
# 2. Largest drop in participation rates: Florida.
#
# 3. Slight increase in participation rates for California and Texas, but a drop for Ohio.
#
# Observation for ACT:
#
# 1. Largest rise in participation rates: Ohio, Nebraska.
#
# 2. Largest drop in participation rates: Colorado, Illinois, Alaska.
#
# 3. Slight drop in participation rates for California (yay for us!), no change for Texas, and sharp increase for Ohio (maybe we should just give Ohio up)
#
# Other Hypotheses:
#
# 1. Illinois, Colorado, diverted funding from ACTs to SATs? Change in states' focus from ACTs towards SATs?
#
# 2. Ohio, Nebraska, diverted more funds to ACT tests?

# %% [markdown]
# #### Changes in SAT scores

# %% [markdown]
# ##### Total score

# %%
plt.figure(figsize=(15,5))
final['diff'] = (final['sat-total-2018']-final['sat-total-2017'])
final = final.sort_values(by=['diff'], ascending = False)
plt.bar(final['state'], final['diff'],color='cyan');
plt.bar(final['state'][final['state']=='California'], final['diff'][final['state']=='California'], color="red")
plt.bar(final['state'][final['state']=='Texas'], final['diff'][final['state']=='Texas'], color="blue")
plt.bar(final['state'][final['state']=='Ohio'], final['diff'][final['state']=='Ohio'], color="grey")
plt.xticks(rotation=90);    #semicolon is to suppress xtixk label outputs
plt.title('SAT total score change (2018 minus 2017)');
plt.legend(['All other states','California','Texas','Ohio'])

# %% [markdown]
# ##### Reading score

# %%
plt.figure(figsize=(15,5))
final['diff'] = (final['sat-evidence-based_reading_and_writing-2018']-final['sat-evidence-based_reading_and_writing-2017'])
final = final.sort_values(by=['diff'], ascending = False)
plt.bar(final['state'], final['diff'],color='cyan');
plt.bar(final['state'][final['state']=='California'], final['diff'][final['state']=='California'], color="red")
plt.bar(final['state'][final['state']=='Texas'], final['diff'][final['state']=='Texas'], color="blue")
plt.bar(final['state'][final['state']=='Ohio'], final['diff'][final['state']=='Ohio'], color="grey")
plt.xticks(rotation=90);    #semicolon is to suppress xtixk label outputs
plt.title('SAT reading score change (2018 minus 2017)');
plt.legend(['All other states','California','Texas','Ohio'])

# %% [markdown]
# ##### Math score

# %%
plt.figure(figsize=(15,5))
final['diff'] = (final['sat-math-2018']-final['sat-math-2017'])
final = final.sort_values(by=['diff'], ascending = False)
plt.bar(final['state'], final['diff'],color='cyan');
plt.bar(final['state'][final['state']=='California'], final['diff'][final['state']=='California'], color="red")
plt.bar(final['state'][final['state']=='Texas'], final['diff'][final['state']=='Texas'], color="blue")
plt.bar(final['state'][final['state']=='Ohio'], final['diff'][final['state']=='Ohio'], color="grey")
plt.xticks(rotation=90);    #semicolon is to suppress xtixk label outputs
plt.title('SAT math score change (2018 minus 2017)');
plt.legend(['All other states','California','Texas','Ohio'])

# %% [markdown]
# Observations for SAT:
#
# 1. Largest rise in total, reading, math: New Jersey, Arizona.
#
# 2. Largest drop in total, reading, math: Colorado, Illinois, West Virginia.
#
# 3. Good increase in total, reading, math for California and then Texas (we can ride on this momentum!), but sizeable drops for Ohio (really should give up Ohio).
#
# Other Hypotheses:
#
# 1. New Jersey, Arizona might have had a renewed focus on academics?
#
# 2. Colorado, Illinois, West Virginia, might have had a change in education policy to cause the score dips?
#
# 3. Colorado, Illinois, also had sharp rises in participation rates. Perhaps more non-college-age-ready students, took the 2018 tests (due to state subsidies?), hence lowering the scores? This is possibly the case with West Virginia too

# %% [markdown]
# #### Changes in ACT scores

# %% [markdown]
# ##### Composite score

# %%
plt.figure(figsize=(15,5))
final['diff'] = (final['act-composite-2018']-final['act-composite-2017'])
final = final.sort_values(by=['diff'], ascending = False)
plt.bar(final['state'], final['diff'],color='cyan');
plt.bar(final['state'][final['state']=='California'], final['diff'][final['state']=='California'], color="red")
plt.bar(final['state'][final['state']=='Texas'], final['diff'][final['state']=='Texas'], color="blue")
plt.bar(final['state'][final['state']=='Ohio'], final['diff'][final['state']=='Ohio'], color="grey")
plt.xticks(rotation=90);    #semicolon is to suppress xtixk label outputs
plt.title('ACT composite score change (2018 minus 2017)');
plt.legend(['All other states','California','Texas','Ohio'])

# %% [markdown]
# Observations for ACT:
#
# 1. Largest rise in composite scores: Colorado, Illinois.
#
# 2. Largest drop in composite scores: Ohio, Nebraska.
#
# 3. Nothing noteworthy for the 3 states. Small drop in composite score for California, no change for Texas, sharp drop for Ohio.
#
# Other Hypothesis:
#
# 1. Illinois, Colorado, had a change in focus (eg. educational policies) from ACTs to SATs? Hence fewer students took ACTs, leaving only serious ACT takers taking ACTs, hence raising the scores? Corroborates with drop in participation rates above.
#
# 2. Ohio, Nebraska, had many more less-prepared schools taking ACTs? Their ACT participation rates rose as seen above.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe()
# Out:
#        sat-participation_%-2017  sat-evidence-based_reading_and_writing-2017  \
# count                 50.000000                                    50.000000
# mean                  38.600000                                   570.860000
# std                   34.560211                                    44.385146
# min                    2.000000                                   503.000000
# 25%                    4.000000                                   535.250000
# 50%                   34.000000                                   559.500000
# 75%                   65.000000                                   613.500000
# max                  100.000000                                   644.000000
#
#        sat-math-2017  sat-total-2017  act-participation_%-2017  \
# count      50.000000       50.000000                 50.000000
# mean      558.660000     1129.620000                 65.920000
# std        45.839832       89.913085                 32.110676
# ...

# %%
final.skew()
# Out:
# sat-participation_%-2017                       0.372844
# sat-evidence-based_reading_and_writing-2017    0.341324
# sat-math-2017                                  0.438667
# sat-total-2017                                 0.382887
# act-participation_%-2017                      -0.243889
# act-english-2017                               0.396624
# act-math-2017                                  0.382885
# act-reading-2017                               0.312151
# act-science-2017                               0.265099
# act-composite-2017                             0.367470
# sat-participation_%-2018                       0.178311
# sat-evidence-based_reading_and_writing-2018    0.367986
# sat-math-2018                                  0.441673
# sat-total-2018                                 0.403495
# act-participation_%-2018                      -0.067772
# act-composite-2018                             0.318689
# diff                                           2.234397
# ...

# %%
final.kurtosis()
# Out:
# sat-participation_%-2017                      -1.349284
# sat-evidence-based_reading_and_writing-2017   -1.347425
# sat-math-2017                                 -1.018211
# sat-total-2017                                -1.221185
# act-participation_%-2017                      -1.601869
# act-english-2017                              -0.777817
# act-math-2017                                 -0.904315
# act-reading-2017                              -0.900166
# act-science-2017                              -0.891445
# act-composite-2017                            -0.898029
# sat-participation_%-2018                      -1.537555
# sat-evidence-based_reading_and_writing-2018   -1.276746
# sat-math-2018                                 -0.935033
# sat-total-2018                                -1.131292
# act-participation_%-2018                      -1.727036
# act-composite-2018                            -1.058241
# diff                                           9.761754
# ...

# %% [markdown]
# Answers:
#
# Most numerical features are positively skewed, with some more/less skewed. Except for act-participation_%-2017, which is negatively skewed (-0.24), and act-participation_%-2018, which has almost no skew (-0.06).
#
# All numerical features have low kurtosis (<0), hence they have light tails, and hence few to no outliers.
#
# All numerical features have high std (>3), except for ACT 2017 & 2018 scores (<3).
#
# SAT Participation Rates for 2017, 2018 range from a min of 2%, to max of 100%, IQ range of 62.25% and 73% respectively, means of 40.54% and 46.6% respectively, medians of 40.5, 53.5 respecively.
#
# SAT constituent Scores for 2017, 2018 range from a min of 468, to max of 655, IQ range of 80 and 70 respectively for reading and math for both years, means of 566 and 556 respectively for reading and math for both years, medians of 550+, 540+ respectively for reading and math for both years.
#
# SAT Total Scores for 2017, 2018 range from a min of 950, to max of 1207, IQ range of 151 and 145 respectively, means of 1124 and 1122 respectively, medians of 1104.5, 1098.5 respecively.
#
# ACT Participation Rates for 2017, 2018 range from a min of 7%, to max of 100%, IQ range of 69% and 72.25% respectively, means of 65.92% and 62.32% respectively, medians of 71%, 66% respecively.
#
# ACT constituent Scores for 2017 range from a min of 16.3, to max of 26.0, IQ range of ~4 for all 4 tests, means of ~21 for all 4 tests, medians of ~21 for all 4 tests.
#
# ACT Composite Scores for 2017, 2018 range from a min of 17.7, to max of 25.6, IQ range of 4 and 4 respectively, means of 21.5 and 21.5 respectively, medians of 21.4, 21.3 respecively.
#
# It might seem that they all follow a normal distribution, but we will see below that they all tend towards a multimodal distribution.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %%
# quick view of all data columns, to see if they have a normal distribution
fig, axes = plt.subplots(4,4, figsize=(16,8));
fig.tight_layout()
for i in range(4):
        for j in range(4):
            final.iloc[:,(i)*4+j+1].hist(ax=axes[i][j]);    #plot all 16 columns of data, to see if they're norm distributed
            axes[i][j].title.set_text(final.columns[(i)*4+j+1])

# %%
### Could attempt a KDE plot on top of the histogram to make it more explict

# %% [markdown]
# Answer:
#
# None of the data columns are normally distributed. They all seem more like multimodal distributions.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# As mentioned/plotted above, none of the data columns are normally distributed.
# If not normally distributed, assumptions such as 1/2/3 sigma of std, null hypothesis with p=0.01/0.05 etc, would be invalid. So instead of the normal distribution, perhaps the "Chebyshev Bound" distribution (link below) might be more appropriate. It applies to virtually unlimited types of probability distributions and works on a much more relaxed assumption than Normality.
#
# https://towardsdatascience.com/what-if-your-data-is-not-normal-d7293f7b8f0

# %%
### No such thing as a "Chebyshev Bound" distribution. Otherwise correct to say that Chebyshev's Inequality can
### be used in general to fit loose bounds to arbitrary non-normal distribution

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# No, makes little sense, as there is a clear -ve correlation between Population size vs participation rates. This implies (and verified by sources below) that many non-college-age-ready students took the tests and pulled down the scores, which would affect the true scores of those who are actually college-ready.
#
# Data can be better, in terms of eg.
#
# Granularity...
# 1. Data from States can be more granular (next lower level is Counties). That could give us more detailed info about which counties may have affected each state's results
# 2. 2018 ACT scores can be more granular (no constituent scores compared to 2017 ACT's)
#
# Sample size...
# 1. only 2 years worth of data were analysed. Could have more years to have a longer trend comparison

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# Not appropriate.
# As seen in the earlier seaborn heatmap, doing well in SAT math, doesn't correlate to doing well in ACT math (see 2017's low -0.41 corr score). There isn't a high correlation between them (in fact its a -ve correlation, when it seems logical to assume that if one does well in a test, one should do well in the other), hence not appropriate to compare them.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# H0: SAT 2017 and SAT 2018 Total scores were the same, hence equal in difficulty for both years
#
# H1: SAT 2017 and SAT 2018 Total scores were not the same, hence different difficulties for both years
#
# Conduct a 2 tailed t-test, with $\alpha=0.05$

# %%
# Code:
print('SAT 2017 mean =',final['sat-total-2017'].mean())
print('SAT 2018 mean =',final['sat-total-2018'].mean())
# Print the difference of the sample means, too.
print('difference =',final['sat-total-2018'].mean()-final['sat-total-2017'].mean())
print()

import scipy.stats
t_stat, p_value = scipy.stats.ttest_ind(final['sat-total-2017'], final['sat-total-2018'], equal_var=False)    #False: uses Welch's distribution, where var is diff for both samples
print('t_stat = '+str(t_stat))
print('p_value = '+str(p_value))
print()

# Generate 500 points on the x axis between -4 and 4:
xpoints = np.linspace(-4,4,500)

# Use `stats.t.pdf` to get values on the probability density function for the t-distribution.
# The second argument is the degrees of freedom: n1 + n2 - 2.
n_sat_total_2017 = len(final['sat-total-2017'])
n_sat_total_2018 = len(final['sat-total-2018'])
ypoints = scipy.stats.t.pdf(xpoints, (n_sat_total_2017+n_sat_total_2018-2), 0, 1)

# Initialize a `matplotlib` "figure."
fig = plt.figure(figsize=(8,5))

# Get the current "axis" out of the figure.
ax = fig.gca()

# Plot the lines using `matplotlib`'s plot function:
ax.plot(xpoints, ypoints, linewidth=3, color='darkred');

# Plot 2 vertical lines for our measured difference in rates' t-statistic.
ax.axvline(t_stat, color='black', linestyle='--', lw=3);
ax.axvline(-t_stat, color='black', linestyle='--', lw=3);

lower_tail = scipy.stats.t.cdf(-abs(t_stat), n_sat_total_2017 + n_sat_total_2018 - 2)
upper_tail = 1 - scipy.stats.t.cdf(abs(t_stat), n_sat_total_2017 + n_sat_total_2018 - 2)
p_value_man = lower_tail + upper_tail

print('p_value =',p_value)
print('p_value_man =',p_value_man)
print()

print('Because our p-value is larger than alpha=0.05, and is statistically insignificant, \
hence H0 cannot be rejected. There is insufficient evidence to say that the difference is non-zero, hence we \
cannot conclude that the difficuties of both tests were different.')
# Out:
# SAT 2017 mean = 1129.62
# SAT 2018 mean = 1127.62
# difference = -2.0
#
# t_stat = 0.109692973280764
# p_value = 0.9128773495528468
#
# p_value = 0.9128773495528468
# p_value_man = 0.9128771832681615
#
# Because our p-value is larger than alpha=0.05, and is statistically insignificant, hence H0 cannot be rejected. There is insufficient evidence to say that the difference is non-zero, hence we cannot conclude that the difficuties of both tests were different.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Answers:
#
# [States: Illinois, Colorado, Ohio]
#
# -
#
# Observation 1:
# Largest rise in SAT participation rates: Illinois, Colorado. (Plots seen in earlier section)
#
# Hypothesis 1:
# Illonois, Colorado, diverted funding from ACTs to SATs?
#
# Conclusion 1:
# Yes indeed for Illinois.
# July2018 - "Illinois has embraced the SAT, and the ACT is mad about it"
# (https://www.chalkbeat.org/posts/chicago/2018/07/27/act-protests-state-boards-embrace-of-rival-test-provider/).
# It actually started even earlier back in 2016. Feb2016 - "Illinois moves ahead with new testing plan, replacing ACT with SAT"
# (https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html).
#
# Yes indeed too, for Colorado.
# Oct2018 - "SAT usage also spiked in Colorado because of a contract with the College Board. There, 58,790 in the Class of 2018 took the test, 10 times the total of the previous year." (https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/)
#
# Additionally, these states have SATs offered for free (link: https://magoosh.com/hs/sat/2017/states-provide-sat-free/)
#
# -
#
# Observation 2:
# Largest rise in participation rates: Ohio (Plots seen in earlier section)
#
# Hypothesis 2:
# Ohio diverted more funds to ACT tests?
#
# Conclusion 2:
# Oct 2018 - "the Class of 2018 was the first where the state paid for all students to take the exam. That means thousands of non-college-bound students who were not tested in the past were tested" (https://www.daytondailynews.com/news/historically-low-act-scores-red-flag-for-our-country/djfx9Urp719WyEaMfykyxL/)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answers:
#
# [Focusing only on SAT]
#
# # Key takeaways across 2017-2018
#
# ### Overall...
# 1. Highest SAT participation rates: Consistently Michigan, Deleware, Connecticut (all 100%)
# 2. Lowest SAT participation rates: Consistently North Dakota, Iowa, Mississippi, Nebraska, South Dakota, Wisconsin, Wyoming, Kansas (all 2-4%).
# 3. Largest rise in SAT participation rates: Illinois, Colorado.
# 4. Largest drop in SAT participation rates: Florida.
# 5. SAT Participation rates tend to be inversely correlated to SAT Total scores (from sns.heatmap, 2017: -0.86, 2018: -0.84).
#
# ### For the 3 states...
# 6. Untapped potential (number of students who didn't take the SATs in both years) in 3 states: California (1773k, 199k), Texas (124k, 115k), then Ohio (108k, 101k). Note that the smallest untapped potential was in the hundreds, ~118
# 7. Good increase in SAT total, reading, math scores from 2017 to 2018, for California and then Texas (yay we can ride on this momentum!). But sizeable drops for Ohio (probably should give up on Ohio).
# 8. Slight increase in SAT participation rates for California and then Texas (again yay for us, ride on momentum!), but a drop for Ohio (sigh...should we give it up?)
# 9. Slight drop in ACT participation rates for California (yay for us!), no change for Texas, and sharp increase for Ohio (maybe we should just give Ohio up)
#
# # Recommendations
# 1. From Key Takeaway 6-9, invest more marketing/training efforts on the states with the largest untapped potential, and with potential for higher SAT participation rates. California would be the best due to their rising SAT participation rates, and dropping ACT participation rates.
# 2. From Key Takeaways 1 & 3, these states did well for us, hence we could look at what we have been doing there, and replicate those efforts in California. eg. offer subsidised/free SAT tests, like in Colorado? (as verified here: https://magoosh.com/hs/sat/2017/states-provide-sat-free/)
# 3. We could support the students in California, to improve their math and verbal/reading abilities, so as to raise their scores, and hence confidence levels, and hence their SAT participation rates. But for impartiality, it might not be good to do so
#
# # Additional data that would be desired
# 1. Constituent scores for ACT 2018, to compare against other years better
# 2. Each State's popuation pyramids, and projected birth rates, to get a short and long term estimation of college-age ready students, so that we can focus our longer-term efforts on these states
# 3. More SAT, ACT scores across more years, to have a better view of the overall trend over the years
# 4. Test-takers' ages, since there has been a trend of non-college-ready-age students taking the tests, which skews the results (https://www.wsj.com/articles/sat-scores-fall-as-more-students-take-the-test-11569297660)
# 5. State funding in education across the years, to see how that has affected SAT & ACT scores, and perhaps participation rates (likely is true, as seen from "Both states have relatively large education budgets. Massachusetts (home state of PrepScholar) and Connecticut have some of the best colleges in the USA, and both have a strong emphasis on high school education and test prep". Link:https://blog.prepscholar.com/average-sat-and-act-scores-by-stated-adjusted-for-participation-rate)
# 6. Socio-economical/household income/crime rate data, to see how effective the newly introduced 'adversity score' (link: https://www.edsurge.com/news/2019-07-31-don-t-call-them-test-companies-how-the-college-board-and-act-have-shifted-focus. goal is to help college admissions officials put an applicant’s SAT score in perspective by showing whether the students come from a place of hardship or relative advantage), has helped to level the playing field for disadvantaged students in certain States, and to see whether this has been effective in incentivising SAT participation and raise participation rates in some of those states.
