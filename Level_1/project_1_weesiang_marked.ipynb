# %% [markdown]
# <div style="border: 1px solid thistle; padding: 5px 20px 10px 20px;">
#     <h2><font color = "77658f" style=";">Feedback</font></h2><br>
#     <font color = "77658f">Using a reference path variable is very important. Certain lines of code cannot be run as you did not upload the necessary data files onto your repository. Fortunately they are not crucial for the remaining parts of the project. Report presentation can be further improved upon, by reducing the number of rows shown when necessary. A few missing plots, but otherwise plots are generally ok. Good use of same axis for boxplots. <br><br>
#         • Project Organisation: <b>Meet Requirement</b> <br>
#         • Python Syntax and Control Flow: <b>Meet Mininum Requirement</b><br>
#         • Data Cleaning and EDA: <b>Meet Requirement</b><br>
#         • Visualisations: <b>Meet Minimum Requirement</b><br>
#         • Research and Conceptual Understanding: <b>Meet Requirement</b><br>
#     </font>
# </div>

# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %% [markdown]
# > <font size = 3 color = red>I'm unable to load the data from your csv files, because you did not upload the files into your repo. But to carry on with the marking, I have made the necessary changes in my machine to ensure that the data can be loaded. In the future please upload any reference data into your repository so that others who use your code can reproduce them.</font>

# %%
#Code:
sat2017_df = pd.read_csv('../data/sat_2017.csv')
act2017_df = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat2017_df.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act2017_df.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer

# %% [markdown]
# > <font size = 3 color = red>Please include some description of the data in your own words ("verbally describe data"). You can talk about the meaning of the columns, the shape of the dataframe, the number of rows, the size etc etc</font>

# %%
sat2017_df.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act2017_df.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:

# %% [markdown]
# The data looks complete as there are no missing/empty values.

# %% [markdown]
# > <font size = 3 color = red>Good use of isnull() to check for empty values</font>

# %%
sat2017_df.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act2017_df.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
act2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
df_all = pd.concat([sat2017_df.set_index('State'), act2017_df.set_index('State')], 
                   axis='columns', keys=['SAT', 'ACT'])
df_all
# Out:
# C:\Users\ym_ch\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                SAT                                            \
#                      Participation Evidence-Based Reading and Writing   Math
# Alabama                         5%                              593.0  572.0
# Alaska                         38%                              547.0  533.0
# Arizona                        30%                              563.0  553.0
# Arkansas                        3%                              614.0  594.0
# California                     53%                              531.0  524.0
# Colorado                       11%                              606.0  595.0
# ...

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:

# %% [markdown]
# The minimum possible value for SAT and ACT subtest is 400 and 1 respectively.
# The maximum possible value for SAT and ACT subtest is 800 and 36 respectively.
#
# The minimum possible value for SAT total score is 800, and minimum composite ACT score is 1.
# The maximum possible value for SAT total score is 1600, and maximum composite ACT score is 36.
#
# The SAT data appears questionable as the Math test minimum score is 52 which is below the minimum possible value of 400. It originates from Maryland entry.
# In the ACT data, one of the entries contains a stray character 'x' in the value of Wyoming composite score.

# %% [markdown]
# > <font size = 3 color = red>Same issue as above. I am unable to load the data from sat_2017_source.csv. This problem is exacerbated by the fact that this file is a custom file which is not provided for this project. I wont be able to extract the data you requested and hence unable to give marks for this.</font>

# %%
# https://stackoverflow.com/questions/20225110/comparing-two-dataframes-and-getting-the-differences
sat2017_source_df = pd.read_csv('../data/sat_2017_source.csv')

type(sat2017_source_df.describe())
compare_sat = pd.concat([sat2017_df.describe(), sat2017_source_df.describe()], 
                   axis='columns', keys=['actual', 'source'])
compare_sat
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-c0a05c921d95> in <module>
#       1 # https://stackoverflow.com/questions/20225110/comparing-two-dataframes-and-getting-the-differences
# ----> 2 sat2017_source_df = pd.read_csv('../data/sat_2017_source.csv')
#       3
#       4 type(sat2017_source_df.describe())
#       5 compare_sat = pd.concat([sat2017_df.describe(), sat2017_source_df.describe()],
#
# ...

# %%
act2017_source_df = pd.read_csv('../data/act_2017_source.csv')
type(sat2017_source_df.describe())
compare_act = pd.concat([act2017_df.describe(), act2017_source_df.describe()], 
                   axis='columns', keys=['actual', 'source'])
compare_act

# %%
compare_act = pd.concat([act2017_df.set_index('State'), act2017_source_df.set_index('State')], 
                   axis='columns', keys=['actual', 'source'])
compare_act

# %%
compare_act = pd.concat([sat2017_df.set_index('State'), sat2017_source_df.set_index('State')], 
                   axis='columns', keys=['actual', 'source'])
compare_act

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# > <font size = 3 color = red>You may use the df.head() function to just list the top 5 rows. Not necessary to list all the tables</font>

# %%
#Fix error in SAT2017 data where Maryland math score is incorrectly stated as 52. Correct score is 524
#sat2017_df.set_index('State').loc['Maryland','Math'] = 524
#sat2017_df.set_index('State').loc['Maryland','Math']

#http://queirozf.com/entries/pandas-dataframe-replace-examples
sat2017_df['Math'] = sat2017_df['Math'].replace([52],524)
sat2017_df
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
# correcting act2017 data
act2017_df['Composite'] = act2017_df['Composite'].replace(['20.2x'],20.2)
act2017_df.loc[act2017_df['State']=='Maryland','Science']=23.2
act2017_df
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat2017_df.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act2017_df.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Participation field should be a float, not object.
# The ACT Composite score should be a float, not object

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %% [markdown]
# > <font size = 3 color = red>Good use of lambda function! Improves the readability of the code<br>
# Please list only the first few rows, as per the previous comment</font>

# %%
#code
sat2017_df.Participation = sat2017_df.Participation.apply(lambda x: float(str(x).strip("%")))
sat2017_df
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5.0                                 593
# 1                 Alaska           38.0                                 547
# 2                Arizona           30.0                                 563
# 3               Arkansas            3.0                                 614
# 4             California           53.0                                 531
# 5               Colorado           11.0                                 606
# 6            Connecticut          100.0                                 530
# 7               Delaware          100.0                                 503
# 8   District of Columbia          100.0                                 482
# 9                Florida           83.0                                 520
# 10               Georgia           61.0                                 535
# ...

# %%
act2017_df.Participation = act2017_df.Participation.apply(lambda x: float(str(x).replace('%','')))
act2017_df
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National           60.0     20.3  20.7     21.4     21.0
# 1                Alabama          100.0     18.9  18.4     19.7     19.4
# 2                 Alaska           65.0     18.7  19.8     20.4     19.9
# 3                Arizona           62.0     18.6  19.8     20.1     19.8
# 4               Arkansas          100.0     18.9  19.0     19.7     19.5
# 5             California           31.0     22.5  22.7     23.1     22.2
# 6               Colorado          100.0     20.1  20.3     21.2     20.9
# 7            Connecticut           31.0     25.5  24.6     25.6     24.6
# 8               Delaware           18.0     24.1  23.4     24.8     23.6
# 9   District of Columbia           32.0     24.4  23.5     24.9     23.5
# 10               Florida           73.0     19.0  19.4     21.0     19.4
# 11               Georgia           55.0     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code

act2017_df.Composite = act2017_df.Composite.astype(float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
print(sat2017_df.dtypes)
print(act2017_df.dtypes)
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %% [markdown]
# > <font size = 3 color = red> You shouldn't manually rename the columns (as stated in the instructions:
#     no repeated singular name-changes').<br>
#     You have to write a function that rename all column names at once, by looping through all column names and replace " " with "_"</font>

# %%
#code
sat_columns = ['state','participation_sat','evidence-based-reading-writing_sat','math_sat','total_sat']

sat2017_df.columns = sat_columns
sat2017_df.columns
# Out:
# Index(['state', 'participation_sat', 'evidence-based-reading-writing_sat',
#        'math_sat', 'total_sat'],
#       dtype='object')

# %%
act_columns = ['state','participation_act','english_act','math_act', 'reading_act','science_act','composite_act']

act2017_df.columns = act_columns
act2017_df.columns
# Out:
# Index(['state', 'participation_act', 'english_act', 'math_act', 'reading_act',
#        'science_act', 'composite_act'],
#       dtype='object')

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|object|SAT_2017|State of the data|
# |participation_sat|float64|SAT_2017|Participation Rate of SAT Test in 2017|
# |evidence-based-reading-writing_sat|int64|SAT_2017|Evidence-Based Reading and Writing Score of SAT Test in 2017|
# |math_sat|int64|SAT_2017|Math Score of SAT Test in 2017|
# |total_sat|int64|SAT_2017|Total Score of SAT Test in 2017|
# |State|object|ACT_2017|State of the data|
# |participation_act|float64|SAT_2017|Participation Rate of ACT Test in 2017|
# |english_act|float64|ACT_2017|English Score of ACT Test in 2017|
# |math_act|float64|ACT_2017|Math Score of ACT in 2017|
# |science_act|float64|ACT_2017|Science Score of ACT in 2017|
# |composite_act|float64|ACT_2017|Composite Score of ACT in 2017|
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|object|SAT_2018|State of the data|
# |participation_sat_2018|float64|SAT_2018|Participation Rate of SAT Test in 2018|
# |evidence-based-reading-writing_sat_2018|int64|SAT_2018|Evidence-Based Reading and Writing Score of SAT Test in 2018|
# |math_sat_2018|int64|SAT_2018|Math Score of SAT Test in 2018|
# |total_sat_2018|int64|SAT_2018|Total Score of SAT Test in 2018|
# |State|object|ACT_2018|State of the data|
# |participation_act_2018|float64|SAT_2018|Participation Rate of ACT Test in 2018|
# |english_act_2018|float64|ACT_2018|English Score of ACT Test in 2018|
# |math_act_2018|float64|ACT_2018|Math Score of ACT in 2018|
# |science_act_2018|float64|ACT_2018|Science Score of ACT in 2018|
# |composite_act_2018|float64|ACT_2018|Composite Score of ACT in 2018|
#
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|object|final|State of the data|
# |participation_sat|float64|SAT_2017|Participation Rate of SAT Test in 2017|
# |evidence-based-reading-writing_sat|int64|final|Evidence-Based Reading and Writing Score of SAT Test in 2017|
# |math_sat|int64|final|Math Score of SAT Test in 2017|
# |total_sat|int64|final|Total Score of SAT Test in 2017|
# |State|object|final|State of the data|
# |participation_act|float64|final|Participation Rate of ACT Test in 2017|
# |english_act|float64|final|English Score of ACT Test in 2017|
# |math_act|float64|final|Math Score of ACT in 2017|
# |science_act|float64|final|Science Score of ACT in 2017|
# |composite_act|float64|final|Composite Score of ACT in 2017|
# |participation_sat_2018|float64|final|Participation Rate of SAT Test in 2018|
# |evidence-based-reading-writing_sat_2018|int64|final|Evidence-Based Reading and Writing Score of SAT Test in 20178
# |math_sat_2018|int64|final|Math Score of SAT Test in 2018|
# |total_sat_2018|int64|final|Total Score of SAT Test in 2018|
# |State|object|final|State of the data|
# |participation_act_2018|float64|final|Participation Rate of ACT Test in 2018|
# |english_act_2018|float64|final|English Score of ACT Test in 2018|
# |math_act_2018|float64|final|Math Score of ACT in 2018|
# |science_act_2018|float64|final8|Science Score of ACT in 2018|
# |composite_act_2018|float64|final|Composite Score of ACT in 2018|
# |sat_part_yoy_ch|float64|final| SAT Participation Rates in 2018 minus SAT Participation Rates in 2017|
# |act_part_yoy_ch|float64|final| ACT Participation Rates in 2018 minus ACT Participation Rates in 2017|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# https://chrisalbon.com/python/data_wrangling/pandas_dropping_column_and_rows/
act2017_df = act2017_df[act2017_df.state!='National']

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
#df_all = pd.concat([sat2017_df.set_index('state_sat'), act2017_df.set_index('state_act')], 
#                   axis='columns', keys=['SAT', 'ACT'])
df_all_2017 = pd.merge(sat2017_df, act2017_df, how = "outer", on = "state")
df_all_2017
# Out:
#                    state  participation_sat  \
# 0                Alabama                5.0
# 1                 Alaska               38.0
# 2                Arizona               30.0
# 3               Arkansas                3.0
# 4             California               53.0
# 5               Colorado               11.0
# 6            Connecticut              100.0
# 7               Delaware              100.0
# 8   District of Columbia              100.0
# 9                Florida               83.0
# 10               Georgia               61.0
# 11                Hawaii               55.0
# 12                 Idaho               93.0
# 13              Illinois                9.0
# 14               Indiana               63.0
# 15                  Iowa                2.0
# 16                Kansas                4.0
# 17              Kentucky                4.0
# 18             Louisiana                4.0
# 19                 Maine               95.0
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
df_all_2017.to_csv('..\data\combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#load files into DataFrame
sat2018_df = pd.read_csv('../data/sat_2018.csv')
act2018_df = pd.read_csv('../data/act_2018.csv')

# %%
print(sat2018_df.info())
print(act2018_df.info())

#convert participation to int
sat2018_df.Participation = sat2018_df.Participation.apply(lambda x: float(str(x).strip("%")))
act2018_df.Participation = act2018_df.Participation.apply(lambda x: float(str(x).strip("%")))
print(sat2018_df.info())
print(act2018_df.info())

#drop duplicates in act_2018_df
act2018_df.drop_duplicates()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
# State            51 non-null object
# Participation    51 non-null object
# Composite        51 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
sat2018_df.columns = ['state','participation_sat_2018','evidence-based-reading-writing_sat_2018','math_sat_2018','total_sat_2018']
sat2018_df.head()
act2018_df.columns = ['state','participation_act_2018','composite_act_2018']
act2018_df.head()

#replace "District of columbia" with "District of Columbia" in act2018_df
act2018_df['state']=act2018_df['state'].str.replace("District of columbia", "District of Columbia",case=True)
act2018_df
# Out:
#                    state  participation_act_2018  composite_act_2018
# 0                Alabama                   100.0                19.1
# 1                 Alaska                    33.0                20.8
# 2                Arizona                    66.0                19.2
# 3               Arkansas                   100.0                19.4
# 4             California                    27.0                22.7
# 5               Colorado                    30.0                23.9
# 6            Connecticut                    26.0                25.6
# 7               Delaware                    17.0                23.8
# 8   District of Columbia                    32.0                23.6
# 9                Florida                    66.0                19.9
# 10               Georgia                    53.0                21.4
# 11                Hawaii                    89.0                18.9
# 12                 Idaho                    36.0                22.3
# ...

# %%
#cleansing the errors in sat2018 after reviewing the pdf
sat2018_df[sat2018_df.state=="Florida"]=['Florida',97.0,522,493,1014]
sat2018_df[sat2018_df.state=="Florida"]
# Out:
#      state  participation_sat_2018  evidence-based-reading-writing_sat_2018  \
# 9  Florida                    97.0                                      522
#
#    math_sat_2018  total_sat_2018
# 9            493            1014

# %%
#cleansing the errors in sat2018 after reviewing the pdf
# Utah = 4%	618	612	1230

sat2018_df[sat2018_df.state=="Utah"]=['Utah',67.0,546,539,1066]
sat2018_df[sat2018_df.state=="Utah"]
# Out:
#    state  participation_sat_2018  evidence-based-reading-writing_sat_2018  \
# 44  Utah                    67.0                                      546
#
#     math_sat_2018  total_sat_2018
# 44            539            1066

# %%
#cleansing the errors in sat2018 after reviewing the pdf
# Indiana = 67%	546	539	1066
sat2018_df[sat2018_df.state=="Indiana"]=['Indiana',67.0,546,539,1066]
sat2018_df[sat2018_df.state=="Indiana"]
# Out:
#       state  participation_sat_2018  evidence-based-reading-writing_sat_2018  \
# 14  Indiana                    67.0                                      546
#
#     math_sat_2018  total_sat_2018
# 14            539            1066

# %%
#cleansing the errors in act2018 after reviewing the pdf
# Michigan's Composite = 24.4
act2018_df.loc[act2018_df.state=='Michigan',['composite_act_2018']] = 24.4
act2018_df[act2018_df.state=='Michigan']
# Out:
#        state  participation_act_2018  composite_act_2018
# 22  Michigan                    22.0                24.4

# %%
df_all_2018 = pd.merge(sat2018_df, act2018_df, how = "outer", on = "state")
df_all_2018.head()
# Out:
#         state  participation_sat_2018  \
# 0     Alabama                     6.0
# 1      Alaska                    43.0
# 2     Arizona                    29.0
# 3    Arkansas                     5.0
# 4  California                    60.0
#
#    evidence-based-reading-writing_sat_2018  math_sat_2018  total_sat_2018  \
# 0                                      595            571            1166
# 1                                      562            544            1106
# 2                                      577            572            1149
# 3                                      592            576            1169
# 4                                      540            536            1076
#
#    participation_act_2018  composite_act_2018
# 0                   100.0                19.1
# 1                    33.0                20.8
# 2                    66.0                19.2
# 3                   100.0                19.4
# 4                    27.0                22.7

# %%
df_all = pd.merge(df_all_2017, df_all_2018, how = "outer", on = "state")
df_all.head()
# Out:
#         state  participation_sat  evidence-based-reading-writing_sat  \
# 0     Alabama                5.0                                 593
# 1      Alaska               38.0                                 547
# 2     Arizona               30.0                                 563
# 3    Arkansas                3.0                                 614
# 4  California               53.0                                 531
#
#    math_sat  total_sat  participation_act  english_act  math_act  reading_act  \
# 0       572       1165              100.0         18.9      18.4         19.7
# 1       533       1080               65.0         18.7      19.8         20.4
# 2       553       1116               62.0         18.6      19.8         20.1
# 3       594       1208              100.0         18.9      19.0         19.7
# 4       524       1055               31.0         22.5      22.7         23.1
#
#    science_act  composite_act  participation_sat_2018  \
# ...

# %%
df_all.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
df_all.describe().T
# Out:
#                                          count         mean        std    min  \
# participation_sat                         51.0    39.803922  35.276632    2.0
# evidence-based-reading-writing_sat        51.0   569.117647  45.666901  482.0
# math_sat                                  51.0   556.882353  47.121395  468.0
# total_sat                                 51.0  1126.098039  92.494812  950.0
# participation_act                         51.0    65.254902  32.140842    8.0
# english_act                               51.0    20.931373   2.353677   16.3
# math_act                                  51.0    21.182353   1.981989   18.0
# reading_act                               51.0    22.013725   2.067271   18.1
# science_act                               51.0    21.450980   1.739353   18.2
# composite_act                             51.0    21.519608   2.020695   17.8
# participation_sat_2018                    51.0    47.862745  37.622876    2.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %% [markdown]
# > <font size = 3 color = red>Not necessary to calculate the mean by invoking a variable called "sum" and "count". Not a very efficient way of utilising resources. You can just use the mean() function.<br>
# Other than that, good use of += for cleaner code.</font>

# %%
#code
def stddev(sample):
    if len(sample) < 1:
        return 0
    
    sum = sample.sum()
    count = len(sample)
    mean = sum / count
    
    sumsq = 0.0
    for x in sample:
        sumsq += (x - mean)**2
        
    # Return the square root of the average square difference
    return (sumsq / (count-1)) ** (.5)

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
sd_all = {x: stddev(df_all[x]) for x in df_all.columns if df_all[x].dtypes != object}
sd_all
# Out:
# {'participation_sat': 35.276632270013046,
#  'evidence-based-reading-writing_sat': 45.66690138768932,
#  'math_sat': 47.12139516560329,
#  'total_sat': 92.49481172519046,
#  'participation_act': 32.14084201588683,
#  'english_act': 2.35367713980303,
#  'math_act': 1.9819894936505533,
#  'reading_act': 2.0672706264873146,
#  'science_act': 1.7393530462812443,
#  'composite_act': 2.020694891154341,
#  'participation_sat_2018': 37.62287581131625,
#  'evidence-based-reading-writing_sat_2018': 44.82528173199742,
#  'math_sat_2018': 48.317990803572506,
#  'total_sat_2018': 93.1874265691903,
#  'participation_act_2018': 34.08097623567245,
#  'composite_act_2018': 2.117686492007581}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer

# %%
sd_np_all = {x: np.std(df_all[x]) for x in df_all.columns if df_all[x].dtypes != object}
sd_np_all
# Out:
# {'participation_sat': 34.92907076664508,
#  'evidence-based-reading-writing_sat': 45.21697020437866,
#  'math_sat': 46.65713364485503,
#  'total_sat': 91.58351056778743,
#  'participation_act': 31.824175751231806,
#  'english_act': 2.3304876369363363,
#  'math_act': 1.9624620273436781,
#  'reading_act': 2.0469029314842646,
#  'science_act': 1.7222161451443676,
#  'composite_act': 2.000786081581989,
#  'participation_sat_2018': 37.25219804429134,
#  'evidence-based-reading-writing_sat_2018': 44.38364257017445,
#  'math_sat_2018': 47.84193987572686,
#  'total_sat_2018': 92.26930145380302,
#  'participation_act_2018': 33.745194881997506,
#  'composite_act_2018': 2.0968220768561987}

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# > <font size = 3 color = red>Avoid using print() for displaying the dataframe table. I've editted one cell below as a sample.</font>

# %%
#states have the highest and lowest participation rates for the 2017 SAT?
"""
Your original code:
print(df_all.sort_values(by='participation_sat',ascending=False).head(3)[['state','participation_sat']])
print(df_all.sort_values(by='participation_sat',ascending=False).tail(3)[['state','participation_sat']])
"""

df_all.sort_values(by='participation_sat',ascending=False).head(3)[['state','participation_sat']]
# Out:
#            state  participation_sat
# 34  North Dakota                2.0
# 24   Mississippi                2.0
# 15          Iowa                2.0

# %%
df_all.sort_values(by='participation_sat',ascending=False).tail(3)[['state','participation_sat']]
# Out:
#            state  participation_sat
# 34  North Dakota                2.0
# 24   Mississippi                2.0
# 15          Iowa                2.0

# %%
#states have the highest and lowest participation rates for the 2018 SAT?
print(df_all.sort_values(by='participation_sat_2018',ascending=False).head(5)[['state','participation_sat_2018']])
print(df_all.sort_values(by='participation_sat_2018',ascending=False).tail(1)[['state','participation_sat_2018']])
# Out:
#           state  participation_sat_2018
# 5      Colorado                   100.0
# 6   Connecticut                   100.0
# 7      Delaware                   100.0
# 22     Michigan                   100.0
# 12        Idaho                   100.0
#            state  participation_sat_2018
# 34  North Dakota                     2.0

# %%
#states have the highest and lowest participation rates for the 2017 ACT?
print(df_all.sort_values(by='participation_act',ascending=False).head(17)[['state','participation_act']])
print(df_all.sort_values(by='participation_act',ascending=False).tail(2)[['state','participation_act']])
# Out:
#              state  participation_act
# 0          Alabama              100.0
# 17        Kentucky              100.0
# 49       Wisconsin              100.0
# 44            Utah              100.0
# 42       Tennessee              100.0
# 40  South Carolina              100.0
# 36        Oklahoma              100.0
# 33  North Carolina              100.0
# 28          Nevada              100.0
# 26         Montana              100.0
# 24     Mississippi              100.0
# 23       Minnesota              100.0
# 18       Louisiana              100.0
# 25        Missouri              100.0
# 50         Wyoming              100.0
# 5         Colorado              100.0
# 3         Arkansas              100.0
#             state  participation_act
# 29  New Hampshire               18.0
# 19          Maine                8.0

# %%
#states have the highest and lowest participation rates for the 2018 ACT?
print(df_all.sort_values(by='participation_act_2018',ascending=False).head(17)[['state','participation_act_2018']])
print(df_all.sort_values(by='participation_act_2018',ascending=False).tail(2)[['state','participation_act_2018']])
# Out:
#              state  participation_act_2018
# 0          Alabama                   100.0
# 17        Kentucky                   100.0
# 49       Wisconsin                   100.0
# 44            Utah                   100.0
# 42       Tennessee                   100.0
# 40  South Carolina                   100.0
# 36        Oklahoma                   100.0
# 35            Ohio                   100.0
# 33  North Carolina                   100.0
# 28          Nevada                   100.0
# 27        Nebraska                   100.0
# 26         Montana                   100.0
# 24     Mississippi                   100.0
# 18       Louisiana                   100.0
# 25        Missouri                   100.0
# 50         Wyoming                   100.0
# 3         Arkansas                   100.0
#            state  participation_act_2018
# 39  Rhode Island                    15.0
# 19         Maine                     7.0

# %%
#Do any states with 100% participation on a given test have a rate change year-to-year? SAT
df_all[df_all['participation_sat']==100.0].loc[:,['state','participation_sat','evidence-based-reading-writing_sat',
                                                  'evidence-based-reading-writing_sat_2018',
                                                  'math_sat','math_sat_2018']]
# Out:
#                    state  participation_sat  \
# 6            Connecticut              100.0
# 7               Delaware              100.0
# 8   District of Columbia              100.0
# 22              Michigan              100.0
#
#     evidence-based-reading-writing_sat  \
# 6                                  530
# 7                                  503
# 8                                  482
# 22                                 509
#
#     evidence-based-reading-writing_sat_2018  math_sat  math_sat_2018
# 6                                       535       512            519
# 7                                       505       492            492
# 8                                       497       468            480
# 22                                      511       495            499

# %%
#Do any states with 100% participation on a given test have a rate change year-to-year? ACT
df_all[df_all['participation_act']==100.0].loc[:,['state','participation_act',
                                                  'composite_act',
                                                  'composite_act_2018']]
# Out:
#              state  participation_act  composite_act  composite_act_2018
# 0          Alabama              100.0           19.2                19.1
# 3         Arkansas              100.0           19.4                19.4
# 5         Colorado              100.0           20.8                23.9
# 17        Kentucky              100.0           20.0                20.2
# 18       Louisiana              100.0           19.5                19.2
# 23       Minnesota              100.0           21.5                21.3
# 24     Mississippi              100.0           18.6                18.6
# 25        Missouri              100.0           20.4                20.0
# 26         Montana              100.0           20.3                20.0
# 28          Nevada              100.0           17.8                17.7
# 33  North Carolina              100.0           19.1                19.1
# 36        Oklahoma              100.0           19.4                19.3
# ...

# %%
#Do any states show have >50% participation on both tests either year? SAT
df_all[(df_all['participation_sat']>50) & (df_all['participation_sat_2018']>50)].loc[:,['state',
                                                                                        'participation_sat',
                                                                                        'participation_sat_2018']]
# Out:
#                    state  participation_sat  participation_sat_2018
# 4             California               53.0                    60.0
# 6            Connecticut              100.0                   100.0
# 7               Delaware              100.0                   100.0
# 8   District of Columbia              100.0                    92.0
# 9                Florida               83.0                    97.0
# 10               Georgia               61.0                    70.0
# 11                Hawaii               55.0                    56.0
# 12                 Idaho               93.0                   100.0
# 14               Indiana               63.0                    67.0
# 19                 Maine               95.0                    99.0
# 20              Maryland               69.0                    76.0
# 21         Massachusetts               76.0                    80.0
# 22              Michigan              100.0                   100.0
# ...

# %%
#Do any states show have >50% participation on both tests either year? ACT
df_all[(df_all['participation_act']>50) & (df_all['participation_act_2018']>50)].loc[:,['state',
                                                                                        'participation_act',
                                                                                        'participation_act_2018']]
# Out:
#              state  participation_act  participation_act_2018
# 0          Alabama              100.0                   100.0
# 2          Arizona               62.0                    66.0
# 3         Arkansas              100.0                   100.0
# 9          Florida               73.0                    66.0
# 10         Georgia               55.0                    53.0
# 11          Hawaii               90.0                    89.0
# 15            Iowa               67.0                    68.0
# 16          Kansas               73.0                    71.0
# 17        Kentucky              100.0                   100.0
# 18       Louisiana              100.0                   100.0
# 23       Minnesota              100.0                    99.0
# 24     Mississippi              100.0                   100.0
# 25        Missouri              100.0                   100.0
# 26         Montana              100.0                   100.0
# ...

# %% [markdown]
# > <font size = 3 color = red>You did not tell me which states are the ones that fulfil the conditions stated in the questions (e.g. which states with 100% participation showed an improvement in XXX). You essentially list down all the data only. </font>

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# %matplotlib inline
plt.figure(figsize=(12,12))
sns.heatmap(df_all.corr(),annot=True)
plt.title("Correlations Between Numeric Features")
# Out:
# Text(0.5, 1, 'Correlations Between Numeric Features')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels,list_of_ylabels,figsize,x,y):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2,figsize = figsize) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i], fontsize = 10)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize = 10)
        ax[i].set_ylabel(list_of_ylabels[i], fontsize = 10)
        #ax[i].set_xlim(x)
        #ax[i].set_ylim(y)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code
# Participation rates for SAT & ACT

subplot_histograms(df_all,
                  ["participation_sat", "participation_sat_2018","participation_act", "participation_act_2018" ], 
                  ["SAT participation 2017", "SAT participation 2018","ACT participation 2017", "ACT participation 2018"],
                  ["Participation rate", "Participation rate","Participation rate", "Participation rate"],
                  ['State count','State count','State count','State count'],(10,10),
                  1,
                  1)

# %% [markdown]
# > <font size = 3 color = red>No ACT score 2018 histogram!!!!</font>

# %%
# Code
# Math scores for SAT & ACT

subplot_histograms(df_all,
                  ["math_sat", "math_sat_2018","math_act"], 
                  ["SAT Math 2017", "SAT Math 2018","ACT Math 2017"],
                  ["Test Score", "Test Score","Test Score"],
                  ['Score count','Score count','Score count'],(10,10),
                  1,
                  1)

# %%
# Code
# Reading/verbal scores for SAT & ACT

subplot_histograms(df_all,
                  ["evidence-based-reading-writing_sat", "evidence-based-reading-writing_sat_2018","reading_act" ], 
                  ["SAT Reading/verbal 2017", "SAT Reading/verbal 2018","ACT Reading/verbal 2017"],
                  ["Test Score", "Test Score","Test Score"],
                  ['State count','State count','State count','State count'],(10,10),
                  1,
                  1)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# SAT vs. ACT math scores for 2017
ax = df_all.plot(kind='scatter',x='math_sat',y='math_act',figsize=(14,14))
plt.title("SAT vs. ACT math scores for 2017")
plt.xlabel('SAT Math Scores for 2017');
plt.ylabel('ACT Math Scores for 2017');

# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.math_sat.iat[i],df_all.math_act.iat[i]))

# %%
#SAT vs. ACT verbal/reading scores for 2017
ax = df_all.plot(kind='scatter',x='evidence-based-reading-writing_sat',y='reading_act',figsize=(14,14))
plt.title("AT vs. ACT verbal/reading scores for 2017")
plt.xlabel('SAT verbal/reading scores for 2017');
plt.ylabel('ACT verbal/reading scores for 2017');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all['evidence-based-reading-writing_sat'].iat[i],df_all.reading_act.iat[i]))

# %%
# SAT vs. ACT total/composite scores for 2017
ax = df_all.plot(kind='scatter',x='total_sat',y='composite_act',figsize=(14,14))
plt.title("SAT vs. ACT total/composite scores for 2017")
plt.xlabel('SAT total/composite scores for 2017');
plt.ylabel('ACT total/composite scores for 2017');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.total_sat.iat[i],df_all.composite_act.iat[i]))

# %%
# Total scores for SAT 2017 vs. 2018
ax = df_all.plot(kind='scatter',x='total_sat',y='total_sat_2018',figsize=(14,14))
plt.title("SAT 2017 vs. 2018")
plt.xlabel('SAT total scores for 2017');
plt.ylabel('SAT total scores for 2018');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.total_sat.iat[i],df_all.total_sat_2018.iat[i]))

# %%
# Composite scores for ACT 2017 vs. 2018
ax = df_all.plot(kind='scatter',x='composite_act',y='composite_act_2018',figsize=(14,14))
plt.title("ACT 2017 vs. 2018")
plt.xlabel('ACT Composite scores for 2017');
plt.ylabel('ACT Composite scores for 2018');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.composite_act.iat[i],df_all.composite_act_2018.iat[i]))

# %% [markdown]
# > <font size = 3 color = red>I like how you annotate the states to each data point.</font>

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
df_participation = df_all[['participation_sat','participation_sat_2018',
       'participation_act','participation_act_2018']]
xlabel = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']
plt.figure(figsize=(16, 6))
sns.boxplot(data=df_participation, width=0.5,palette="colorblind")
plt.title("SAT & ACT Participation Rates in 2017 & 2018",fontsize=14)
plt.xticks(range(4),xlabel,fontsize=14);
plt.ylabel('Participation Rates',fontsize=14);

# %%
# Code
df_participation = df_all[['evidence-based-reading-writing_sat','evidence-based-reading-writing_sat_2018',
       'math_sat','math_sat_2018']]
xlabel = ['SAT Reading&Writing 2017','SAT Reading&Writing 2018','SAT Math 2017','SAT Math 2018']
plt.figure(figsize=(16, 6))
sns.boxplot(data=df_participation, width=0.5,palette="colorblind")
plt.title("SAT Subject Scores in 2017 & 2018",fontsize=14)
plt.xticks(range(4),xlabel,fontsize=14);
plt.ylabel('Scores',fontsize=14);

# %%
# Code
df_participation = df_all[['total_sat','total_sat_2018']]
xlabel = ['SAT Total 2017','SAT Total 2018']
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_participation, width=0.5,palette="colorblind")
plt.title("SAT Total Scores in 2017 & 2018",fontsize=14)
plt.xticks(range(2),xlabel,fontsize=14);
plt.ylabel('Scores',fontsize=14);

# %%
# Code
df_participation = df_all[['math_act','reading_act','science_act','composite_act','composite_act_2018']]
xlabel = ['ACT Math 2017','ACT Reading 2017','SAT Science 2017','ACT Composite 2017','ACT Composite 2018']
plt.figure(figsize=(16, 6))
sns.boxplot(data=df_participation, width=0.5,palette="colorblind")
plt.title("ACT Subjects Scores in 2017 And ACT Composite Scores in 2017 & 2018",fontsize=14)
plt.xticks(range(5),xlabel,fontsize=14);
plt.ylabel('Scores',fontsize=14);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# SAT vs. ACT Participation Rate 2017
ax = df_all.plot(kind='scatter',x='participation_sat',y='participation_act',figsize=(14,14))
plt.title("SAT vs. ACT Participation Rate 2017")
plt.xlabel('SAT Participation Rate 2017');
plt.ylabel('ACT Participation Rate 2017');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.participation_sat.iat[i],df_all.participation_act.iat[i]))
plt.plot(np.unique(df_all.participation_sat), 
         np.poly1d(np.polyfit(df_all.participation_sat, df_all.participation_act, 1))(np.unique(df_all.participation_sat)))

# %%
# SAT vs. ACT Participation Rate 2018
ax = df_all.plot(kind='scatter',x='participation_sat_2018',y='participation_act_2018',figsize=(14,14))
plt.title("SAT vs. ACT Participation Rate 2018")
plt.xlabel('SAT Participation Rate 2018');
plt.ylabel('ACT Participation Rate 2018');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.participation_sat_2018.iat[i],df_all.participation_act_2018.iat[i]))
plt.plot(np.unique(df_all.participation_sat_2018), 
         np.poly1d(np.polyfit(df_all.participation_sat_2018, 
                              df_all.participation_act_2018, 1))(np.unique(df_all.participation_sat_2018)))

# %%
# SAT vs. ACT Participation Rate YoY Change
df_all['sat_part_yoy_ch']=df_all['participation_sat_2018']-df_all['participation_sat']
df_all['act_part_yoy_ch']=df_all['participation_act_2018']-df_all['participation_act']
ax = df_all.plot(kind='scatter',x='sat_part_yoy_ch',y='act_part_yoy_ch',figsize=(14,14))
plt.title("SAT vs. ACT Participation Rate YoY Change")
plt.xlabel('SAT Participation Rate YoY Change from 2017 to 2018');
plt.ylabel('ACT Participation Rate YoY Change from 2017 to 2018');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.sat_part_yoy_ch.iat[i],df_all.act_part_yoy_ch.iat[i]))
#plt.plot(np.unique(df_all.sat_part_yoy_ch), 
#         np.poly1d(np.polyfit(df_all.sat_part_yoy_ch, 
#                              df_all.act_part_yoy_ch, 1))(np.unique(df_all.sat_part_yoy_ch)))

# %%
# SAT scores vs. SAT Participation Rate 2017
ax = df_all.plot(kind='scatter',x='total_sat',y='participation_sat',figsize=(14,14))
plt.title("# SAT scores vs. SAT Participation Rate in 2017")
plt.xlabel('SAT Scores 2017');
plt.ylabel('SAT Participation Rate 2017');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.total_sat.iat[i],df_all.participation_sat.iat[i]))
plt.plot(np.unique(df_all.total_sat), 
         np.poly1d(np.polyfit(df_all.total_sat, df_all.participation_sat, 1))(np.unique(df_all.total_sat)))

# %%
# SAT scores vs. SAT Participation Rate 2018
ax = df_all.plot(kind='scatter',x='total_sat_2018',y='participation_sat_2018',figsize=(14,14))
plt.title("# SAT scores vs. SAT Participation Rate in 2018")
plt.xlabel('SAT Scores 2018');
plt.ylabel('SAT Participation Rate 2018');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.total_sat_2018.iat[i],df_all.participation_sat_2018.iat[i]))
plt.plot(np.unique(df_all.total_sat_2018), 
         np.poly1d(np.polyfit(df_all.total_sat_2018, df_all.participation_sat_2018, 1))(np.unique(df_all.total_sat_2018)))

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %%
df_all_describe = df_all.iloc[:,:-2].describe()
df_all_describe.T
# Out:
#                                          count         mean        std    min  \
# participation_sat                         51.0    39.803922  35.276632    2.0
# evidence-based-reading-writing_sat        51.0   569.117647  45.666901  482.0
# math_sat                                  51.0   556.882353  47.121395  468.0
# total_sat                                 51.0  1126.098039  92.494812  950.0
# participation_act                         51.0    65.254902  32.140842    8.0
# english_act                               51.0    20.931373   2.353677   16.3
# math_act                                  51.0    21.182353   1.981989   18.0
# reading_act                               51.0    22.013725   2.067271   18.1
# science_act                               51.0    21.450980   1.739353   18.2
# composite_act                             51.0    21.519608   2.020695   17.8
# participation_sat_2018                    51.0    47.862745  37.622876    2.0
# ...

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %%
# https://stackoverflow.com/questions/23959207/advanced-describe-pandas
stats = df_all.describe() 
stats.loc['skew'] = df_all.skew().tolist()
stats.loc['kurt'] = df_all.kurtosis().tolist()
stats.T
# Out:
#                                          count         mean        std    min  \
# participation_sat                         51.0    39.803922  35.276632    2.0
# evidence-based-reading-writing_sat        51.0   569.117647  45.666901  482.0
# math_sat                                  51.0   556.882353  47.121395  468.0
# total_sat                                 51.0  1126.098039  92.494812  950.0
# participation_act                         51.0    65.254902  32.140842    8.0
# english_act                               51.0    20.931373   2.353677   16.3
# math_act                                  51.0    21.182353   1.981989   18.0
# reading_act                               51.0    22.013725   2.067271   18.1
# science_act                               51.0    21.450980   1.739353   18.2
# composite_act                             51.0    21.519608   2.020695   17.8
# participation_sat_2018                    51.0    47.862745  37.622876    2.0
# ...

# %%
# https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/
from scipy.stats import shapiro
for column, data in df_all.iteritems():
    if column == 'state': continue
    stat, p = shapiro(data)
    if p > 0.05:
        print (column," is likely to be normally distributed based on Shapiro-Wilk Test")
    else :
        print (column," is unlikely to be distributed based on Shapiro-Wilk Test")
# Out:
# participation_sat  is unlikely to be distributed based on Shapiro-Wilk Test
# evidence-based-reading-writing_sat  is unlikely to be distributed based on Shapiro-Wilk Test
# math_sat  is unlikely to be distributed based on Shapiro-Wilk Test
# total_sat  is unlikely to be distributed based on Shapiro-Wilk Test
# participation_act  is unlikely to be distributed based on Shapiro-Wilk Test
# english_act  is unlikely to be distributed based on Shapiro-Wilk Test
# math_act  is unlikely to be distributed based on Shapiro-Wilk Test
# reading_act  is likely to be normally distributed based on Shapiro-Wilk Test
# science_act  is likely to be normally distributed based on Shapiro-Wilk Test
# composite_act  is unlikely to be distributed based on Shapiro-Wilk Test
# participation_sat_2018  is unlikely to be distributed based on Shapiro-Wilk Test
# evidence-based-reading-writing_sat_2018  is unlikely to be distributed based on Shapiro-Wilk Test
# ...

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# The Shapiro-Wilk test evaluates a data sample and quantifies how likely it is that the data was drawn from a Gaussian distribution, named for Samuel Shapiro and Martin Wilk.
# In the SciPy implementation of these tests, the p value can be interpreted as follows.
#
# p <= alpha: reject H0, not normal.
# p > alpha: fail to reject H0, normal.
#
# The normality assumption does not hold for Math (SAT & ACT), Reading (SAT & ACT) and Participation Rates (SAT & ACT) based on the Shapiro-Wilk test.
#
# The kernel density estimation plots are also provided below to visualize the probability density for a given distribution. The kernel density plot provides vital display of information on data which include: <br>
# How the data is distributed around the measures of central tendency like mean and median <br>
# How the distribution is skewed <br>
# How the distribution is peaked <br>
# [link](https://pythontic.com/pandas/series-plotting/kernel%20density%20estimation%20plot)

# %%
for column, data in df_all.iteritems():
    if column == 'state': continue
    data.plot.kde(title=column+" Kernel density estimation")
    plt.show()

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# I believe it makes sense to evaluate the relationship between SAT and ACT particiption rates in 2017. <br>
# As seen below, SAT and ACT participation rates are generally negatively correlated. <br>
# It is likely that students will take either one or the other tests (but not both) due to the time and effort to prepare for these tests.

# %%
# SAT vs. ACT Participation Rate 2017
ax = df_all.plot(kind='scatter',x='participation_sat',y='participation_act',figsize=(14,14))
plt.title("SAT vs. ACT Participation Rate 2017")
plt.xlabel('SAT Participation Rate 2017');
plt.ylabel('ACT Participation Rate 2017');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.participation_sat.iat[i],df_all.participation_act.iat[i]))
plt.plot(np.unique(df_all.participation_sat), 
         np.poly1d(np.polyfit(df_all.participation_sat, df_all.participation_act, 1))(np.unique(df_all.participation_sat)))

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# It may not be appropriate to compare the SAT and ACT math scores as there is no strong relationship between SAT math scores and ACT math scores as observed in the scatter plot below. <br>
# One may speculate that SAT and ACT math scores of a state should be somewhat correlated since both tests are evaluating similar subject matter. However it is not the case as there may be other bias factors such as state sponsorship of a particular test and students self-selection to take a specific tests.

# %%
# SAT vs. ACT Math Scores 2017
ax = df_all.plot(kind='scatter',x='math_sat',y='math_act',figsize=(14,14))
plt.title("SAT vs. ACT Math Scores 2017")
plt.xlabel('SAT Math Score 2017');
plt.ylabel('ACT Math Score 2017');
# https://stackoverflow.com/questions/41481153/how-to-label-bubble-chart-scatter-plot-with-column-from-pandas-dataframe
for i, txt in enumerate(df_all.state):
    ax.annotate(txt, xy=(df_all.math_sat.iat[i],df_all.math_act.iat[i]))
plt.plot(np.unique(df_all.math_sat), 
         np.poly1d(np.polyfit(df_all.math_sat, df_all.math_act, 1))(np.unique(df_all.math_sat)))

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# The Shapiro-Wilk test is provided (see above section) whereby it evaluates a data sample and quantifies how likely it is that the data was drawn from a Gaussian distribution, named for Samuel Shapiro and Martin Wilk. In the SciPy implementation of these tests, the p value can be interpreted as follows.
#
# p <= alpha: reject H0, not normal. p > alpha: fail to reject H0, normal.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
df_all[['state','sat_part_yoy_ch']].sort_values('sat_part_yoy_ch',ascending=False).head(3)
# Out:
#        state  sat_part_yoy_ch
# 13  Illinois             90.0
# 5   Colorado             89.0
# 44      Utah             64.0

# %%
df_all[['state','act_part_yoy_ch']].sort_values('act_part_yoy_ch',ascending=False).head(3)
# Out:
#        state  act_part_yoy_ch
# 35      Ohio             25.0
# 27  Nebraska             16.0
# 2    Arizona              4.0

# %% [markdown]
# The top three states that demonstrate highest increase in SAT participation are as follows : Illinois (up 90%), Colorado (up 89%), Utah (64%). <br>
# The top three states that demonstrate highest increase in ACT participation are as follows : Ohio (up 25%), Nebraska (up 16%), Arizona (4%). <br>
#
# In particular, SAT test registered a much greater participation rate improvement as compared to ACT test when evaluating the top 3 states. <br>
#
# Further analysis revealed the following factors are the main driver in the SAT participation rates : <br>
# 1. State sponsorship <br>
# It has been report that "In 2017-18, 10 states (Colorado, Connecticut, Delaware, Idaho, Illinois, Maine, Michigan, New Hampshire, Rhode Island, and West Virginia) and the District of Columbia covered the cost of the SAT for all their public school students." (see [link](https://reports.collegeboard.org/archive/sat-suite-program-results/2018/sat-school-day) )
# 2. Mandatory requirement in taking SAT tests in certain states.<br>
# "Beginning with the 2016-17 school year, all Illinois juniors must take the SAT." (see [link](https://blog.prepscholar.com/which-states-require-the-sat ))

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Based on the exploration of the data, the key takeaways are: <br>
# - SAT and ACT participation rates are negatively correlated. This means that the students tend to take either one of the two tests. <br>
# - the test scores and the participation rates of each state are usually not normally distributed. There may be many influencing factors. <br>
# - the participation rates that shows the highest increase are driven by (1) State sponsorship, and (2) Mandatory requirement in taking the tests in the selected states. <br>
#
# Recommendations : <br>
# - the College Board should continue to advocate the merits of SAT testing to the state government so as to achieve the outcome of state sponsorship and SAT test mandatory requirement for state university entry <br>
#
# - the college Board could target California state given that (1) relatively low SAT and ACT participation rates as compared to other states, (2) largest population, (3) the state has neither mandated SAT nor ACT test as requirement, (4) no state sponsorship not yet instituted for standardized test. <br>
#
# Addition Data : <br>
# Addition data of the state fiscal health, demographics and social-economic factors could assist in developing a more targetted marketing plan.
